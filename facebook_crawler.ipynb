# %%
import facebook_crawler
pageurl= 'https://www.facebook.com/diudiu333'
facebook_crawler.Crawl_PagePosts(pageurl=pageurl, until_date='2021-01-01')
# Out:
# break_times: 1
# TimeStamp: 2021-06-09 20:29:06.
# TimeStamp: 2021-02-18 18:01:19.
# TimeStamp: 2020-11-13 17:53:41.
# There are 58 posts in DataFrame.
#    NAME                TIME  \
# 0   丟丟妹 2021-06-09 20:29:06
# 1   丟丟妹 2021-05-12 22:49:48
# 2   丟丟妹 2021-05-06 15:34:21
# 3   丟丟妹 2021-05-05 14:14:17
# 4   丟丟妹 2021-04-28 21:19:23
# 5   丟丟妹 2021-04-22 18:46:34
# 6   丟丟妹 2021-04-18 13:07:17
# 7   丟丟妹 2021-04-16 21:14:02
# 8   丟丟妹 2021-04-09 22:27:30
# 9   丟丟妹 2021-04-06 11:51:51
# 10  丟丟妹 2021-04-03 19:16:49
# 11  丟丟妹 2021-04-02 14:02:08
# 12  丟丟妹 2021-03-26 22:27:00
# 13  丟丟妹 2021-03-24 20:26:17
# 14  丟丟妹 2021-03-14 20:02:03
# 15  丟丟妹 2021-03-10 22:26:57
# 16  丟丟妹 2021-03-03 17:38:00
# 17  丟丟妹 2021-03-02 11:55:57
# 18  丟丟妹 2021-02-20 22:17:01
# 19  丟丟妹 2021-02-18 18:01:19
# 20  丟丟妹 2021-02-11 00:18:22
# 21  丟丟妹 2021-02-07 16:50:52
# 22  丟丟妹 2021-01-30 16:35:26
# 23  丟丟妹 2021-01-28 22:55:26
# 24  丟丟妹 2021-01-26 15:25:47
# 25  丟丟妹 2021-01-23 21:45:07
# 26  丟丟妹 2021-01-22 20:43:02
# ...

# %%
groupurl = 'https://www.facebook.com/groups/1409002019312069'
facebook_crawler.Crawl_GroupPosts(groupurl, until_date='2013-06-01')
# Out:
# break_times: 1
# break_times: 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-44404d7679d6> in <module>
#       1 groupurl = 'https://www.facebook.com/groups/1409002019312069'
# ----> 2 facebook_crawler.Crawl_GroupPosts(groupurl, until_date='2013-06-01')
#
# ~\anaconda3\lib\site-packages\facebook_crawler.py in Crawl_GroupPosts(groupurl, until_date)
#     220             }
#     221
# --> 222         resp = requests.get(groupurl, headers=headers, params=params)
#     223         try:
#     224             ndf = parse_group_content(resp)
#
# ~\AppData\Roaming\Python\Python38\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ...
