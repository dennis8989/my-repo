# %%
import requests
from bs4 import BeautifulSoup
result = requests.get('https://opendata.cwb.gov.tw/api/v1/rest/datastore/F-C0032-001?Authorization=CWB-5B414EA1-34DB-4168-8B56-7EBFE0BBACCF')

# %%
soup = BeautifulSoup(result.text, 'html.parser')

# %%
print(soup.prettify())
# Out:
# {"success":"true","result":{"resource_id":"F-C0032-001","fields":[{"id":"datasetDescription","type":"String"},{"id":"locationName","type":"String"},{"id":"parameterName","type":"String"},{"id":"parameterValue","type":"String"},{"id":"parameterUnit","type":"String"},{"id":"startTime","type":"Timestamp"},{"id":"endTime","type":"Timestamp"}]},"records":{"datasetDescription":"三十六小時天氣預報","location":[{"locationName":"嘉義縣","weatherElement":[{"elementName":"Wx","time":[{"startTime":"2021-05-05 00:00:00","endTime":"2021-05-05 06:00:00","parameter":{"parameterName":"多雲","parameterValue":"4"}},{"startTime":"2021-05-05 06:00:00","endTime":"2021-05-05 18:00:00","parameter":{"parameterName":"多雲時晴","parameterValue":"3"}},{"startTime":"2021-05-05 18:00:00","endTime":"2021-05-06 06:00:00","parameter":{"parameterName":"多雲時晴","parameterValue":"3"}}]},{"elementName":"PoP","time":[{"startTime":"2021-05-05 00:00:00","endTime":"2021-05-05 06:00:00","parameter":{"parameterName":"20","parameterUnit":"百分比"}},
# ...

# %%
type(list_of_dicts)
# Out:
# dict

# %%
list_of_dicts = result.json()

# %%
for i in list_of_dicts['records']['location']:
    print(i['weatherElement'])
# Out:
# [{'elementName': 'Wx', 'time': [{'startTime': '2021-05-05 00:00:00', 'endTime': '2021-05-05 06:00:00', 'parameter': {'parameterName': '多雲', 'parameterValue': '4'}}, {'startTime': '2021-05-05 06:00:00', 'endTime': '2021-05-05 18:00:00', 'parameter': {'parameterName': '多雲時晴', 'parameterValue': '3'}}, {'startTime': '2021-05-05 18:00:00', 'endTime': '2021-05-06 06:00:00', 'parameter': {'parameterName': '多雲時晴', 'parameterValue': '3'}}]}, {'elementName': 'PoP', 'time': [{'startTime': '2021-05-05 00:00:00', 'endTime': '2021-05-05 06:00:00', 'parameter': {'parameterName': '20', 'parameterUnit': '百分比'}}, {'startTime': '2021-05-05 06:00:00', 'endTime': '2021-05-05 18:00:00', 'parameter': {'parameterName': '20', 'parameterUnit': '百分比'}}, {'startTime': '2021-05-05 18:00:00', 'endTime': '2021-05-06 06:00:00', 'parameter': {'parameterName': '20', 'parameterUnit': '百分比'}}]}, {'elementName': 'MinT', 'time': [{'startTime': '2021-05-05 00:00:00', 'endTime': '2021-05-05 06:00:00', 'parameter': {'parame
# ...

# %%
list_of_dicts['records']['location'][1]
# Out:
# {'locationName': '新北市',
#  'weatherElement': [{'elementName': 'Wx',
#    'time': [{'startTime': '2021-05-05 00:00:00',
#      'endTime': '2021-05-05 06:00:00',
#      'parameter': {'parameterName': '多雲短暫陣雨', 'parameterValue': '8'}},
#     {'startTime': '2021-05-05 06:00:00',
#      'endTime': '2021-05-05 18:00:00',
#      'parameter': {'parameterName': '陰時多雲短暫陣雨', 'parameterValue': '10'}},
#     {'startTime': '2021-05-05 18:00:00',
#      'endTime': '2021-05-06 06:00:00',
#      'parameter': {'parameterName': '陰時多雲', 'parameterValue': '6'}}]},
#   {'elementName': 'PoP',
#    'time': [{'startTime': '2021-05-05 00:00:00',
#      'endTime': '2021-05-05 06:00:00',
#      'parameter': {'parameterName': '30', 'parameterUnit': '百分比'}},
#     {'startTime': '2021-05-05 06:00:00',
#      'endTime': '2021-05-05 18:00:00',
#      'parameter': {'parameterName': '70', 'parameterUnit': '百分比'}},
#     {'startTime': '2021-05-05 18:00:00',
#      'endTime': '2021-05-06 06:00:00',
# ...

# %%
for i in list_of_dicts['records']['location'][0]['weatherElement']:
    print(i['elementName'])
# Out:
# Wx
# PoP
# MinT
# CI
# MaxT

# %%
list_of_dicts['records']['location'][0]['weatherElement'][3]
# Out:
# {'elementName': 'CI',
#  'time': [{'startTime': '2021-05-05 00:00:00',
#    'endTime': '2021-05-05 06:00:00',
#    'parameter': {'parameterName': '舒適'}},
#   {'startTime': '2021-05-05 06:00:00',
#    'endTime': '2021-05-05 18:00:00',
#    'parameter': {'parameterName': '舒適至悶熱'}},
#   {'startTime': '2021-05-05 18:00:00',
#    'endTime': '2021-05-06 06:00:00',
#    'parameter': {'parameterName': '舒適'}}]}

# %% [markdown]
# ![image.png](attachment:d9921fa9-e28a-4dde-a764-7cb49280a658.png)

# %% [markdown]
# https://opendata.cwb.gov.tw/opendatadoc/MFC/D0047.pdf
