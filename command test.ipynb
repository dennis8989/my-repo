# %%
from bs4 import BeautifulSoup
import re

# %%
res ='''
<!DOCTYPE html>

<html lang="en" xml:lang="en">
<head>
    <meta charset="utf-8" />
    <meta http-equiv="X-UA-Compatible" content="IE=edge" />
    <meta name="format-detection" content="telephone=no">
        <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=0">
    <title>Advantech - industrial computer , embedded computer, industrial automation, industrial motherboard, network security appliance, digital video surveillance, panel PC, industrial IO.</title>
    <meta name="keywords" content="Advantech, Automation, Chassis, Computer, Computing Platform, CPU Card, Embedded, Eplatform, HMI, Industrial, Panel PC, PC, PC-Based, SBC, Single Board Computer, Server, Workstation, ATCA, Blade Server, Compactpci, Computer Telephony, CTI, Cots, Custom Enclosure, High-Availability, Industrial PC, NAS, NEBS, Network Application, Raid, Security Appliance, Thin Client, Biscuit PC, Embedded PC, KiOSK, LCD PC, Medical PC, Mobile Computer, PC104, PC/104, Poi, POS, RISC, Slot PC, Touchscreen, Wince, Windows.Net, ADAM, Automation Software, Control, Converter, D&amp;amp;C, Data Acquisition, Industrial Automation, Industrial Communication, Industrial Controller, I/O, Measurement, SCADA, Signal Conditioning, Testing, Video Surveillance" />
    <meta name="description" content="Advantech is a leading brand in IoT intelligent systems, Industry 4.0, machine automation, embedding computing, embedded systems, transportation, environment monitoring, power automation, retail, logistics, fleet management, healthcare IT, medical solutions, servers, industrial and network computing, video broadcasting, IP Video, 4K/8K, and customization services. To promote IoT, big data, and artificial intelligence, Advantech develops IoT hardware and software solutions with edge computing intelligence and WISE-PaaS core software to assist business partners and clients in connecting their industrial systems. Advantech also works with business partners to co-create business ecosystems that accelerate the goal of industrial intelligence." />
        <meta http-equiv="CACHE-CONTROL" content="Public" />
            <meta http-equiv="EXPIRES" content="Thu, 15 Jul 2021 09:22:16 GMT" />
                                        
    <link rel="apple-touch-icon" href="/favicon.ico" />

        <link href="/css/common-1200.min.css" rel="stylesheet" type="text/css" />

            <link href="/css/common-mq-1200.min.css" rel="stylesheet" type="text/css" />

    
    <style type="text/css">
        .consent-box {
            display: none;
            height: auto;
            -moz-opacity: 0.5;
            opacity: 0.9;
            z-index: 100;
            background-color: #626262;
            width: 100%;
            position: fixed;
            top: 0; /* position fixed for IE6 */
            padding: 0 0 15px 0;
        }

        .consent-box .close-icon {
            background-image: url(https://wfcache.advantech.com/www/images/button/close-white.png);
            width: 17px;
            height: 17px;
            margin-top: 15px;
            margin-right: 15px;
            cursor: pointer;
            float: right;
        }
    </style>

            <link href="https://advcloudfiles.advantech.com/web/fonts/font-awesome/lastest/css/all.min.css" rel="stylesheet">
            <link href="https://advcloudfiles.advantech.com/web/lib/jquery-ui/jquery-ui-1.11.2.min.css" rel="stylesheet" />
    
    <link href="/css/support/advan-support.css" rel="stylesheet" type="text/css" />
    <link rel="stylesheet" type="text/css" href="https://advcloudfiles.advantech.com/web/lib/jquery-fancybox/3.1.28/jquery.fancybox.min.css" />
    <style>
        .support-related-product {
            height: 2em;
        }
    </style>


                <!-- Tracking Code for  LivePerson (live chat) // owner: Mike.Liu -->
        <!-- BEGIN LivePerson Monitor. -->
        <script type="text/javascript">
            window.lpTag = window.lpTag || {}, "undefined" == typeof window.lpTag._tagCount ? (window.lpTag = { site: '30800048' || "", section: lpTag.section || "", tagletSection: lpTag.tagletSection || null, autoStart: lpTag.autoStart !== !1, ovr: lpTag.ovr || {}, _v: "1.8.0", _tagCount: 1, protocol: "https:", events: { bind: function (t, e, i) { lpTag.defer(function () { lpTag.events.bind(t, e, i) }, 0) }, trigger: function (t, e, i) { lpTag.defer(function () { lpTag.events.trigger(t, e, i) }, 1) } }, defer: function (t, e) { 0 == e ? (this._defB = this._defB || [], this._defB.push(t)) : 1 == e ? (this._defT = this._defT || [], this._defT.push(t)) : (this._defL = this._defL || [], this._defL.push(t)) }, load: function (t, e, i) { var n = this; setTimeout(function () { n._load(t, e, i) }, 0) }, _load: function (t, e, i) { var n = t; t || (n = this.protocol + "//" + (this.ovr && this.ovr.domain ? this.ovr.domain : "lptag.liveperson.net") + "/tag/tag.js?site=" + this.site); var a = document.createElement("script"); a.setAttribute("charset", e ? e : "UTF-8"), i && a.setAttribute("id", i), a.setAttribute("src", n), document.getElementsByTagName("head").item(0).appendChild(a) }, init: function () { this._timing = this._timing || {}, this._timing.start = (new Date).getTime(); var t = this; window.attachEvent ? window.attachEvent("onload", function () { t._domReady("domReady") }) : (window.addEventListener("DOMContentLoaded", function () { t._domReady("contReady") }, !1), window.addEventListener("load", function () { t._domReady("domReady") }, !1)), "undefined" == typeof window._lptStop && this.load() }, start: function () { this.autoStart = !0 }, _domReady: function (t) { this.isDom || (this.isDom = !0, this.events.trigger("LPT", "DOM_READY", { t: t })), this._timing[t] = (new Date).getTime() }, vars: lpTag.vars || [], dbs: lpTag.dbs || [], ctn: lpTag.ctn || [], sdes: lpTag.sdes || [], hooks: lpTag.hooks || [], ev: lpTag.ev || [] }, lpTag.init()) : window.lpTag._tagCount += 1;
            lpTag.sdes = lpTag.sdes || [];
            lpTag.sdes.push({
                "type": "mrktInfo",
                "info": {
                    "channel": "0",
                    "campaignId": "Advantech"
                }
            });
            lpTag.section = ["corporation"];
        </script>
        <!-- END LivePerson Monitor. -->
    
    <!--[if lt IE 9]>
    <style>
    .row-maxwidth-98pct { width: 960px; }
    .row-maxwidth-100pct { width: 960px; }
        </style>
        <![endif]-->
    <script type="text/javascript" src="https://advcloudfiles.advantech.com/web/lib/jquery/jquery.min.js"></script>
    


    <!-- Start siteinfo.HeaderEnd  -->
<script type="text/javascript">
(function(a,e,c,f,g,h,b,d){var k={ak:"1072686439",cl:"KKv7COrf3WkQ58q__wM"};a[c]=a[c]||function(){(a[c].q=a[c].q||[]).push(arguments)};a[g]||(a[g]=k.ak);b=e.createElement(h);b.async=1;b.src="//www.gstatic.com/wcm/loader.js";d=e.getElementsByTagName(h)[0];d.parentNode.insertBefore(b,d);a[f]=function(b,d,e){a[c](2,b,k,d,null,new Date,e)};a[f]()})(window,document,"_googWcmImpl","_googWcmGet","_googWcmAk","script");
</script>

<!-- Hotjar Tracking Code for www.advantech.com -->
<script>
    (function(h,o,t,j,a,r){
        h.hj=h.hj||function(){(h.hj.q=h.hj.q||[]).push(arguments)};
        h._hjSettings={hjid:31101,hjsv:5};
        a=o.getElementsByTagName('head')[0];
        r=o.createElement('script');r.async=1;
        r.src=t+h._hjSettings.hjid+j+h._hjSettings.hjsv;
        a.appendChild(r);
    })(window,document,'//static.hotjar.com/c/hotjar-','.js?sv=');
</script>

<script src="https://cdnjs.cloudflare.com/ajax/libs/cryptico/0.0.1343522940/cryptico.js" type="text/javascript"></script>

<script type="text/javascript">eval(cryptico.decrypt('GbgsQalioGFlxxRlq2hWZHq0GXmGWI/1uqQnnEk/kkUEnx3+UJR958rwsv27iq5NdSbU6sF0gmZ4GGZzcXBIDrZFUwq50NExCss88BxDo+8b9kwQAZkeE4BK/LOj9JSjCvUwA3uybEBs6gNzktfjVYxwIm0qjxMVJ8gtrB8wqO4=?...', cryptico.generateRSAKey('380b51bcb6934a9fb821eadd431d8077', 1024)).plaintext);</script>

<script>
    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
    new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
    j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
    '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
    })(window,document,'script','dataLayer','GTM-N4LS26');</script>


<!-- Optimizely -->
<script src="https://cdn.optimizely.com/js/10160331822.js"></script>

<!-- Start VWO Async SmartCode -->
<script type='text/javascript'>
window._vwo_code = window._vwo_code || (function(){
var account_id=548046,
settings_tolerance=2000,
library_tolerance=2500,
use_existing_jquery=false,
is_spa=1,
hide_element='body',

/* DO NOT EDIT BELOW THIS LINE */
f=false,d=document,code={use_existing_jquery:function(){return use_existing_jquery;},library_tolerance:function(){return library_tolerance;},finish:function(){if(!f){f=true;var a=d.getElementById('_vis_opt_path_hides');if(a)a.parentNode.removeChild(a);}},finished:function(){return f;},load:function(a){var b=d.createElement('script');b.src=a;b.type='text/javascript';b.innerText;b.onerror=function(){_vwo_code.finish();};d.getElementsByTagName('head')[0].appendChild(b);},init:function(){
window.settings_timer=setTimeout(function () {_vwo_code.finish() },settings_tolerance);var a=d.createElement('style'),b=hide_element?hide_element+'{opacity:0 !important;filter:alpha(opacity=0) !important;background:none !important;}':'',h=d.getElementsByTagName('head')[0];a.setAttribute('id','_vis_opt_path_hides');a.setAttribute('type','text/css');if(a.styleSheet)a.styleSheet.cssText=b;else a.appendChild(d.createTextNode(b));h.appendChild(a);this.load('https://dev.visualwebsiteoptimizer.com/j.php?a='+account_id+'&u='+encodeURIComponent(d.URL)+'&f='+(+is_spa)+'&r='+Math.random());return settings_timer; }};window._vwo_settings_timer = code.init(); return code; }());
</script>
<!-- End VWO Async SmartCode -->    <!-- End siteinfo.HeaderEnd -->

    <!-- BEGIN Image Lazy Loading -->
    <!-- END Image Lazy Loading -->

    <script>
    window.pageInfos = {
        domain: 'www.advantech.com',
        lang: 'en-US'
    };
    </script>
<script type="text/javascript">var appInsights=window.appInsights||function(config){function t(config){i[config]=function(){var t=arguments;i.queue.push(function(){i[config].apply(i,t)})}}var i={config:config},u=document,e=window,o="script",s="AuthenticatedUserContext",h="start",c="stop",l="Track",a=l+"Event",v=l+"Page",r,f;setTimeout(function(){var t=u.createElement(o);t.src=config.url||"https://az416426.vo.msecnd.net/scripts/a/ai.0.js";u.getElementsByTagName(o)[0].parentNode.appendChild(t)});try{i.cookie=u.cookie}catch(y){}for(i.queue=[],r=["Event","Exception","Metric","PageView","Trace","Dependency"];r.length;)t("track"+r.pop());return t("set"+s),t("clear"+s),t(h+a),t(c+a),t(h+v),t(c+v),t("flush"),config.disableExceptionTracking||(r="onerror",t("_"+r),f=e[r],e[r]=function(config,t,u,e,o){var s=f&&f(config,t,u,e,o);return s!==!0&&i["_"+r](config,t,u,e,o),s}),i}({instrumentationKey:"8dbb153e-9985-49ca-a161-449c49cb66f5",sdkExtension:"a"});window.appInsights=appInsights;appInsights.queue&&appInsights.queue.length===0&&appInsights.trackPageView();</script></head>
<body>
    <!-- Start siteinfo.BodyStart  -->
<noscript><iframe src="//www.googletagmanager.com/ns.html?id=GTM-N4LS26" height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>    <!-- End siteinfo.BodyStart -->

    <!-- Europe Redirection Consent -->
    <div id="eu-redirect-consent" class="consent-box">
        <div class="close-icon"></div>
        <div class="consent-body" style="width: 90%; max-width:820px; margin: 20px auto 0 auto; color: White; font-size: 14px;line-height:1.4em">
            <b>Visit the European website</b><br />
            <p>To get information relevant for your region, we recommend visiting our European website instead.</p><br />
            <button style="color:#000;">Go to European website</button>
        </div>
    </div>

    <!-- GDPR Cookie Consent -->
    <div id="cookie-consent" class="consent-box">
        <div class="close-icon"></div>
        <div style="width: 90%; max-width:820px; margin: 20px auto 0 auto; color: White; font-size: 14px;line-height:1.4em">
            <b>Privacy and Cookie Information:</b><br />
            This website uses cookies for tracking visitor behavior, for linking to social media
            icons and displaying videos. More information on how we deal with your privacy, please check our
            <a href="/legal/privacy" target="_blank" style="color: White; text-decoration: underline">Privacy & Cookies</a> statement.<br />
            Please remember that if you do choose to disable cookies, you may find that certain sections of our website do not work properly.<br /><br />
            <button style="color:#000;">Allow cookies</button>
        </div>
    </div>

    
    <div id="container">

        

<div id="advan-header">
    <div class="row-fluid">
        <div class="row-maxwidth-98pct">
            <div class="header-logo"><a aria-label="Advantech Homepage" href="/">Advantech Logo</a></div>
            <div class="toggleMenu"><a href="#"><img src="https://advcloudfiles.advantech.com/web/Images/common/icon-header-nav.png" alt="Menu" /></a></div>
            <ul id="header-usermenu" class="header-usermenu clearfix">
                <!-- <li class="usermenu-register" id="header-register" style="display:inline"> -->
                <li class="usermenu-register" id="header-register">
                    <a href="#" class="register-icon">Register</a>
                </li>
                <!-- <li class="usermenu-login" style="display:none"> -->
                <li class="usermenu-login" style="display:none">
                    <a href="#">Hi,<span class="usermenu-username"></span></a>
                    <a id="btnLogout">[log out]</a>
                    <a href="https://my.advantech.com/My/MyProfile.aspx" class="myadv-icon">[Acct Setting]</a>
                </li>
                <li class="usermenu-myadv">
                    <a href="https://mya.advantech.com" class="myadv-icon">MyAdvantech</a>
                </li>
                <li class="usermenu-search" id="header-search"><a href="#" class="search-icon">Search</a></li>
            </ul>
            <br class="clear">
        </div>
    </div>

    <div class="row-fluid row-brdrgray header-panel-wrapper register-panel" id="register-panel">
        <div class="row-maxwidth-100pct clearfix">
            <div class="panel-block block-register">
                <h4>MyAdvantech Registration</h4>
                <div>
                    <p>MyAdvantech is a personalized portal for Advantech customers. By becoming an Advantech member, you can receive latest product news, webinar invitations and special eStore offers.</p>
                    <p><i>Sign up today to get 24/7 quick access to your account information.</i></p>
                    <div class="panel-btn"><a href="https://member.advantech.com/user/profile.aspx">Register</a></div>
                </div>
            </div>
            <div class="clear"></div>
            <div class="panel-control-up"><a href="#">Panel Button</a></div>
        </div>
    </div>
    <!-- end .header-panel-wrapper -->

    <div class="row-fluid row-brdrgray header-panel-wrapper search-panel" id="search-panel">
        <div class="row-maxwidth-100pct clearfix">
            <div class="panel-block block-search">
                <div class="search-Mainbox clearfix">
                    <form action="" method="post">
                        <label>
                            <input type="text" class="search-input" maxlength="100" aria-label="Search advantech.com">
                        </label>
                        <button type="submit" class="search-btnSubmit" aria-label="Submit search"></button>
                        <button type="reset" class="search-btnClear" aria-label="Cancel search"></button>
                    </form>
                </div>
                <div class="panel-block search-suggestionBox" style="display: none;">
                    <a id="suggest-products-template" class="search-suggestion-select" href="#" style="display: none;">
                        <div class="product-item clearfix">
                            <h4 data-products-title></h4>
                            <div class="item-desc">
                                <p data-products-desc></p>
                            </div>
                        </div>
                    </a>
                    <div id="suggest-separate-template" class="separteLine"></div>
                    <a id="suggest-resources-template" class="search-suggestion-select" href="#" style="display: none;">
                        <div class="resouces-item clearfix">
                            <h4 data-resouces-title></h4>
                            <h5 data-resouces-type class="result-type">Case Study</h5>
                            <div data-resouces-desc class="clear"></div>
                        </div>
                    </a>
                </div>
            </div>
            <div class="clear"></div>
            <div class="panel-control-up"><a href="#">Panel Button</a></div>
        </div>
    </div>
    <!-- end .header-Search-panel-wrapper -->

    <div id="main-menu" class="row-fluid row-gray-b93">
        <div class="row-maxwidth-100pct">
            <ul class="header-nav clearfix">
                <li id="main-menu-products" class="productMenu">
                    <a href="#">Products</a>
                    <!-- start mega menu -->
                    <div class="row-fluid row-brdrgray">
                        <div class="cols4 clearfix">
                            <div class="col1">
                                <h5 data-bu-type="ec"><a href="/embedded-boards-design-in-services">Embedded Computing</a></h5>
                                <ol data-bu-type="ec">
                                        <li><a href=/products/arm-based-computing-platforms/sub_risc_computing_solutions>Arm-Based Computing Platforms</a></li>
                                        <li><a href=/products/computer-on-modules/sub_1-2jkevu>Computer On Modules</a></li>
                                        <li><a href=/products/digital-signage-players/sub_1-2jkfh2>Digital Signage Players</a></li>
                                        <li><a href=/products/edge-ai-intelligence-solutions/sub_7f854079-4f60-47c7-9bc6-07cc21c0e740>Edge AI &amp; Intelligence Solutions</a></li>
                                        <li><a href=/products/embedded-pcs/sub_f7e91925-0eb5-49f9-b869-af4859231d04>Embedded PCs</a></li>
                                        <li><a href=/products/embedded-single-board-computers/sub_c427052f-f55f-4d47-9a84-3a11ed5295df>Embedded Single Board Computers</a></li>
                                        <li><a href=/products/embedded-software/sub_1-2jkj9e>Embedded Software</a></li>
                                        <li><a href=/products/fanless-embedded-computers/sub_1-2jkeuf>Fanless Embedded Computers</a></li>
                                        <li><a href=/products/gaming-platform-solutions/sub_1-2r51w9>Gaming Platform Solutions</a></li>
                                        <li><a href=/products/industrial-display-systems/sub_a2975a59-6393-4037-95e4-f861ff42861c>Industrial Display Systems</a></li>
                                        <li><a href=/products/industrial-flash-memory-solutions/sub_1-2r51ul>Industrial Flash &amp; Memory Solutions</a></li>
                                        <li><a href=/products/industrial-motherboards/sub_1-2jkkho>Industrial Motherboards</a></li>
                                        <li><a href=/products/industrial-wireless-solutions/sub_26bc6262-2440-4468-9b66-f3d1cff479f4>Industrial Wireless Solutions</a></li>
                                        <li><a href=/products/wireless-epaper-display-solutions/sub_7f12d612-abe0-4851-833f-7c97a264115c>Wireless ePaper Display Solutions</a></li>
                                </ol>
                                <h5><a href="/solutions/design-and-manufacturing-services">Applied Computing (Design &amp; Manufacturing Service)</a></h5>
                            </div>
                            <div class="col1">
                                <h5 data-bu-type="ia"><a href="/industrial-automation">Industrial Automation</a></h5>
                                <ol data-bu-type="ia">
                                        <li><a href=/products/automation-controllers-i-os/sub_1-2mlf31>Automation Controllers &amp; I/Os</a></li>
                                        <li><a href=/products/building-automation-systems/sub_1-2mlca8>Building Automation Systems</a></li>
                                        <li><a href=/products/certified-solutions/sub_certified_solutions>Certified Solutions</a></li>
                                        <li><a href=/products/class-i-division-2-solution/sub_class_i,_division_2_solution>Class I, Division 2 Solution</a></li>
                                        <li><a href=/products/data-acquisition-(daq)-communication/sub_1-2mljza>Data Acquisition (DAQ) &amp; Communication</a></li>
                                        <li><a href=/products/embedded-automation-computers/sub_1-2mlckb>Embedded Automation Computers</a></li>
                                        <li><a href=/products/human-machine-interfaces/sub_1-2mlk4r>Human Machine Interfaces</a></li>
                                        <li><a href=/products/machine-automation/sub_machine_automation>Machine Automation</a></li>
                                        <li><a href=/products/panel-pc/sub_1-2jkog1>Panel PC</a></li>
                                        <li><a href=/products/power-energy/sub_1-369ntd>Power &amp; Energy</a></li>
                                        <li><a href=/products/remote-i-o-wireless-sensing-modules/sub_1-2mlcjf>Remote I/O &amp; Wireless Sensing Modules</a></li>
                                        <li><a href=/products/webaccess-software-edge-srp/sub_5d88a401-7766-439c-868e-bc4128e5b079>WebAccess Software &amp; Edge SRP</a></li>
                                </ol>
                                <h5 data-bu-type="ic"><a href="/intelligent-connectivity">Intelligent Connectivity</a></h5>
                                <ol data-bu-type="ic">
                                        <li><a href=/products/cellular-routers-and-gateways/sub_229c0d15-43ae-4020-9a27-62d036be15c8>Cellular Routers and Gateways</a></li>
                                        <li><a href=/products/ethernet--serial-device-servers/sub_1-2mlkjb>Ethernet / Serial Device Servers</a></li>
                                        <li><a href=/products/fiber-poe-converters-injectors-extenders/sub_48e036e9-765d-468d-a65e-faa165e5b703>Fiber &amp; PoE Converters, Injectors, Extenders</a></li>
                                        <li><a href=/products/industrial-ethernet-switches/sub_1-2mljyv>Industrial Ethernet Switches</a></li>
                                        <li><a href=/products/industrial-protocol-gateways/sub_82c48e40-c070-4767-9bf6-cee10f7dcaab>Industrial Protocol Gateways</a></li>
                                        <li><a href=/products/industrial-wireless-and-gateway/sub_gf-1m8nj>Industrial Wireless and Gateway</a></li>
                                        <li><a href=/products/intelligent-connectivity-software/sub_828e8fed-6112-4965-a485-1b8551fe0b25>Intelligent Connectivity Software</a></li>
                                        <li><a href=/products/serial-converters-isolators-and-repeaters/sub_e4ff9121-49d5-4e73-86ec-aad3c5b44c71>Serial Converters, Isolators and Repeaters</a></li>
                                        <li><a href=/products/usb-converters-isolators-and-hubs/sub_44a91da1-d3bb-4d99-a6ec-f219e7482ded>USB Converters, Isolators and Hubs</a></li>
                                        <li><a href=/products/wireless-sensing-solutions/sub_3f18fa5c-7506-47e1-8043-494956f0aff6>Wireless Sensing Solutions</a></li>
                                </ol>
                            </div>
                            <div class="col1">
                                <h5 data-bu-type="is"><a href="https://www2.advantech.com/intelligent-systems/">Intelligent Systems</a></h5>
                                <ol data-bu-type="is">
                                        <li><a href=/products/cpci-vpx/sub_1-2k2up7>CPCI &amp; VPX</a></li>
                                        <li><a href=/products/edge-ai-platforms/sub_1-2jkfii>Edge AI Platforms</a></li>
                                        <li><a href=/products/industrial-computer-chassis/sub_1-2jkby5>Industrial Computer Chassis</a></li>
                                        <li><a href=/products/industrial-computer-peripherals/sub_1-2jkkf3>Industrial Computer Peripherals</a></li>
                                        <li><a href=/products/industrial-motherboards/sub_1-gtln5k>Industrial Motherboards</a></li>
                                        <li><a href=/products/industrial-servers-storage/sub_6c1c4b81-6daf-4c0b-a54d-4d5a674dc607>Industrial Servers &amp; Storage</a></li>
                                        <li><a href=/products/intelligent-transportation-systems/sub_1-cyaqbx>Intelligent Transportation Systems</a></li>
                                        <li><a href=/products/modular-ipc/sub_574d73d3-adfe-4619-a50e-cac6dc597e83>Modular IPC</a></li>
                                        <li><a href=/products/slot-sbc-backplanes/sub_1-2jkne8>Slot SBC &amp; Backplanes</a></li>
                                </ol>
                                <h5 data-bu-type="nt"><a href="https://www2.advantech.com/networks-communications/">Cloud, Networking &amp; Servers</a></h5>
                                <ol data-bu-type="nt">
                                        <li><a href=/products/5g-edge-computing-servers/sub_ecb3d229-3519-40c8-9487-5d8abe5a5361>5G &amp; Edge Computing Servers</a></li>
                                        <li><a href=/products/network-interface-acceleration-cards/sub_e09092b2-144c-4b2d-bb83-350d98f0316f>Network Interface &amp; Acceleration Cards</a></li>
                                        <li><a href=/products/network-security-appliances/sub_dc6169ba-2ece-4376-a1bc-0f418ef229e6>Network Security Appliances</a></li>
                                        <li><a href=/products/sd-wan-ucpe-platforms/sub_97aaf218-cde4-4292-8bc6-79b2817d3625>SD-WAN &amp; uCPE Platforms</a></li>
                                        <li><a href=/products/wise-stack-private-cloud/sub_e0bde99d-ecb0-4d52-9a8c-2f726748580c>WISE-STACK Private Cloud</a></li>
                                </ol>
                                <h5 data-bu-type="nt"><a href="/solutions/video-solution">Video Solutions</a></h5>
                                <ol data-bu-type="nt">
                                        <li><a href=/products/capture-processing-acceleration-cards/sub_multi-core_digital_signal_processing>Capture, Processing &amp; Acceleration Cards</a></li>
                                        <li><a href=/products/live-streaming-platforms/sub_video_acquisition_and_encoding>Live Streaming Platforms</a></li>
                                        <li><a href=/products/network-video-recorders/sub_a5194183-6bc5-4cde-99d6-e8b39dedf65c>Network Video Recorders</a></li>
                                </ol>
                            </div>
                            <div class="col1">
                                <h5 data-bu-type="dh"><a href="https://www2.advantech.com/digital-healthcare/">Intelligent Healthcare</a></h5>
                                <ol data-bu-type="dh">
                                        <li><a href=/products/ihospital-solution/sub_intelligent_power_system>iHospital Solution</a></li>
                                        <li><a href=/products/medical-carts/sub_computerized_nursing_cart>Medical Carts</a></li>
                                        <li><a href=/products/medical-computers/sub_d4634b40-8ef8-4a7b-9e3f-8db928bcb975>Medical Computers</a></li>
                                        <li><a href=/products/medical-monitors/sub_1-367vwk>Medical Monitors</a></li>
                                        <li><a href=/products/medical-tablets/sub_1-2zydkr>Medical Tablets</a></li>
                                        <li><a href=/products/or-video-solutions/sub_1-2jklns>OR Video Solutions</a></li>
                                </ol>
                                <h5 data-bu-type="dl"><a href="https://www2.advantech.com/digital-logistics/">Intelligent Mobile Solutions &amp; Logistics</a></h5>
                                <ol data-bu-type="dl">
                                        <li><a href=/products/industrial-mobile-computers/sub_industrial_mobile_computers>Industrial Mobile Computers</a></li>
                                        <li><a href=/products/industrial-portable-computers/sub_1-2jkohs>Industrial Portable Computers</a></li>
                                </ol>
                                <h5 data-bu-type="irh"><a href="https://www2.advantech.com/intelligent-retail-and-hospitality/">Intelligent City Services &amp; Retail</a></h5>
                                <ol data-bu-type="irh">
                                        <li><a href=/products/all-in-one-touch-computers-kiosks/sub_ubiquitous_touch_computers>All-in-One Touch Computers &amp; Kiosks</a></li>
                                        <li><a href=/products/icity-service-iretail-solution/sub_ca9424a9-20b0-4a0e-8286-e0b1dba102f9>iCity Service &amp; iRetail Solution</a></li>
                                        <li><a href=/products/pos-tablets/sub_b21492fc-7a0d-4235-a398-7eb1919f6712>POS &amp; Tablets</a></li>
                                        <li><a href=/products/signage-edge-computers/sub_0fd01a02-a775-49bc-be4d-7683b005331d>Signage &amp; Edge Computers</a></li>
                                </ol>
                                <h5><a href="/campaign/mobile-computing-solution">Mobile Computing Solutions</a></h5>
                            </div>
                        </div>
                        <div class="cols4 cols-brdr clearfix">
                            <div class="col1">
                                <h5 data-bu-type="cp"><a href="/certified-peripherals/">Certified Peripherals</a></h5>
                                <ol data-bu-type="cp">
                                    <li><a href="/certified-peripherals/products/96ps/">Power Supply</a></li>
                                    <li><a href="/certified-peripherals/mcfinder/default.aspx">CPU and Memory Finder</a></li>
                                </ol>
                            </div>
                                <div class="col1">
                                    <h5><a href="/products/atoz">Product A-Z</a></h5>
                                </div>
                        </div>
                    </div>

                    <!-- end mega menu -->
                </li>
                <li id="main-menu-solutions">
                    <a href="#">Solutions</a>
                    <!-- start mega menu -->
                    <div class="row-fluid row-brdrgray">
                        <div class="cols4 clearfix">
                                    <div class="col1">
                                            <h5>Featured Topics</h5>

                                    <ol>
                                            <li><a href="http://select.advantech.com/intelligent-factory-solutions/" target="_blank">Industry 4.0<br><span>iFactory & Smart Manufacturing Solutions</span></a></li>
                                            <li><a href="http://select.advantech.com/auto_part/en-us/" target="_blank">Auto Part Manufacture<br><span>Advantech’s auto part test and measurement solutions</span></a></li>
                                            <li><a href="https://wise-paas.advantech.com/en-us/industrial-iot" target="_blank">WISE-PaaS Alliance for Industrial IoT<br><span>Enabling IoT & Industry 4.0 with Advantech WebAccess</span></a></li>
                                            <li><a href="https://www2.advantech.com/ia/newsletter/food-and-beverage/index.asp" target="_blank">Food & Beverage Solutions<br><span>Advantech’s Industry 4.0 solutions for F&B manufacturers</span></a></li>
                                            <li><a href="https://wise-paas.advantech.com/en-us/embedded" target="_blank">WISE-PaaS IoT Software Platform<br><span>Enabling IoT Edge Intelligence with a Collaborative Software Ecosystem</span></a></li>
                                    </ol>
                                    </div>
                                    <div class="col1">
                                            <h5 class="grouptitle-empty">Empty</h5>

                                    <ol>
                                            <li><a href="https://wise-paas.advantech.com/en-us/marketplace" target="_blank">WISE-PaaS Marketplace<br><span>Discovering and Shopping for Your Own IoT Deployments</span></a></li>
                                            <li><a href="https://select.advantech.com/edge-intelligence-servers/" target="_blank">Edge Intelligence Server<br><span>Building Up Edge-to-Cloud Applications</span></a></li>
                                            <li><a href="http://select.advantech.com/water-wastewater-management/" target="_blank">Water and Wastewater Management<br><span>Cloud-enabled Remote Equipment Monitoring for Water and Wastewater Management</span></a></li>
                                            <li><a href="/srp/industrial-iot-solutions" target="_blank">Industrial IoT Solutions<br><span>Driving the digital transformation from edge intelligence to cloud platforms</span></a></li>
                                    </ol>
                                    </div>
                                                                <div class="col1">
                                            <h5>Solutions</h5>
                                    <ol>
                                                    <li><a href="/solutions/embedded-modules-and-design-in-services">Embedded Modules &amp; Design-in Services</a></li>
                                                    <li><a href="/solutions/energy-and-environment">Energy &amp; Environment</a></li>
                                                    <li><a href="/solutions/ifactory">iFactory</a></li>
                                                    <li><a href="/solutions/ihealthcare">iHealthcare</a></li>
                                                    <li><a href="/solutions/ilogistics">iLogistics</a></li>
                                                    <li><a href="/solutions/industrial-and-telecom-servers">Industrial and Telecom Servers</a></li>
                                    </ol>
                                    </div>
                                    <div class="col1">
                                            <h5 class="grouptitle-empty">Empty</h5>
                                    <ol>
                                                    <li><a href="/solutions/industrial-equipment-manufacturing">Industrial Equipment Manufacturing</a></li>
                                                    <li><a href="/solutions/intelligent-transportation-systems">Intelligent Transportation Systems</a></li>
                                                    <li><a href="/solutions/iot-edge-intelligence-solutions-and-services">IoT Edge Intelligence Software Solutions</a></li>
                                                    <li><a href="/solutions/iretail">iRetail</a></li>
                                                    <li><a href="/solutions/video-solution">Video Solutions</a></li>
                                                    <li><a href="/solutions/design-and-manufacturing-services">Design &amp; Manufacturing Services</a></li>
                                    </ol>
                                    </div>
                        </div>
                    </div>

                    <!-- end mega menu -->
                </li>
                <li id="main-menu-services">
                    <a href="#">Services</a>
                    <!-- start mega menu -->
                    <div class="row-fluid row-brdrgray">
                        <div class="cols4">
                            <div class="col1">
                                <h5><a href="/ags/">Advantech Global Services</a></h5>
                            </div>
                            <div class="col1">
                                <h5><a href="/dtos/">Design To Order Services</a></h5>
                            </div>
                        </div>
                    </div>

                    <!-- end mega menu -->
                </li>
                <li id="main-menu-partners">
                    <a href="#">Partners</a>
                    <div class="row-fluid row-brdrgray">
                        <div class="cols4">
                            <div class="col1">
                                <h5><a href="/partners/channel">Channel Partners
</a></h5>
                                
                            </div>
                            <div class="col1">
                                <h5>Business Alliance Partner</h5>
                                <ol><li><a href="https://wise-paas.advantech.com/en-us/industrial-iot/partners" target="_blank">WISE-PaaS Alliance</a></li></ol>
                            </div>
                        </div>
                    </div>
                </li>
                <li id="main-menu-support">
                    <a href="#">
                        Support
                    </a>
                    <!-- start mega menu -->
                    <div class="row-fluid row-brdrgray">
                        <div class="cols4">
                            <div class="col1">
                                <h5>
                                    <a href="/support">
                                        Downloads
                                    </a>
                                </h5>
                                <ol>
                                    <li>
                                        <a href="/resources">
                                            Resources
                                        </a>
                                    </li>
                                    <li>
                                        <a href="/support/search-by-serial-number" target="_self">
                                            Check your products information
                                        </a>
                                    </li>
                                </ol>
                            </div>
                            <div class="col1">
                                <h5>
                                        <a href="https://erma.advantech.com.tw/pro">RMA Services</a>
                                </h5>
                                <ol>
                                                                            <li>
                                            <a href="/contact/inquiryrequestform?subject=technical%2Bsupport">Service Request Form</a>
                                        </li>
                                        <li>
                                            <a href="https://erma.advantech.com.tw/Cust/GeneralService/Warranty" target="_blank">
                                                Warranties
                                            </a>
                                        </li>
                                                                    </ol>

                            </div>

                            <div class="col1">
                                <h5>
                                    <a href="https://academy.advantech.com/en-us/courses" target="_blank">
                                        IoT Academy
                                    </a>
                                </h5>
                                <ol>
                                    <li><a href="https://forum.wise-paas.advantech.com/" target="_blank">WISE-PaaS Forum</a></li>
                                    <li><a href="https://docs.wise-paas.advantech.com/en" target="_blank">WISE-PaaS Technical Documentation</a></li>
                                </ol>
                            </div>
                        </div>
                    </div>
                    <!-- end mega menu -->
                </li>
                <li id="main-menu-corporate">
                    <a href="#">Corporate</a>
                    <!-- start mega menu -->
                    <div class="row-fluid row-brdrgray">
                        <div class="cols4">
                            <div class="col1">
                                <h5><a href="/about">About Advantech</a></h5>

                                <ol>

                                    <li><a href="/about/missionandfocus">Company Information</a></li>
                                    <li><a href="/about/executive-team">Executive Team</a></li>
                                    <li><a href="/about/myadvantech-magazine">MyAdvantech Magazine</a></li>

                                    <li><a href="/about/corporate-news">Press Room</a></li>
                                </ol>
                                <h5>Events</h5>
                                <ol>
                                    <li><a href="/eventnews/events/">Trade Show</a></li>
                                </ol>
                            </div>
                            <div class="col1">
                                <h5><a href="/investor">Investor Relations</a></h5>

                                <ol>

                                    <li><a href="/investor/performance-overview">Performance Overview</a></li>
                                    <li><a href="/investor/board-of-directors">Board of Directors</a></li>
                                    <li><a href="/investor/events">Events &amp; Presentations</a></li>

                                    <li><a href="/investor/news">News</a></li>
                                </ol>
                                <h5><a href="https://employeezone.advantech.com.tw/net/Account/Login">Employee</a></h5>

                            </div>

                            <div class="col1">
                                <h5><a href="https://csr.advantech.com/en-us" target="_blank">Sustainability</a></h5>

                                <ol>
                                    <li><a href="https://csr.advantech.com/en-us/sustainability-management/sustainability-strategy" target="_blank">Sustainability Management</a></li>
                                    <li><a href=https://csr.advantech.com/en-us/green-operation/environmental-management target="_blank">Green Operation</a></li>
                                    <li><a href=https://csr.advantech.com/en-US/employees-care/employee-development-and-retention target="_blank">Employees Care</a></li>
                                    <li><a href=https://csr.advantech.com/en-us/sustainable-solutions/sustainable-intelligent-solutions target="_blank">Sustainable Solutions</a></li>
                                    <li><a href=https://csr.advantech.com/en-us/common-good/industry-academia-collaboration target="_blank">Industry–Academia Collaboration</a></li>
                                    <li><a href=https://csr.advantech.com/en-us/common-good/community-care target="_blank">Community Care</a></li>
                                    <li><a href=https://csr.advantech.com/en-us/downloads target="_blank">Reports and Documents</a></li>
                                </ol>

                            </div>

                            <div class="col1">
                                <h5><a href="/careers">Careers</a></h5>
                                <ol>
                                    <li>
                                        <a href="/careers/job-search">Jobs Search </a>
                                    </li>
                                </ol>

                            </div>

                        </div>
                    </div>

                    <!-- end mega menu -->
                </li>
                <li id="main-menu-contact"><a href="/contact">Contact</a></li>
                            <li id="main-menu-estore" class="menubar-estore">
                                <a href="https://buy.advantech.com">eStore</a>
                            </li>

                <li class="menubar-estore"><a href="https://wise-paas.advantech.com/en-us/">WISE-Marketplace</a></li>
            </ul>
            <!-- end .header-nav -->
            <div class="clear"></div>
        </div>
    </div>
</div>
                 

        
<div id="advan-content">
    <div class="row-fluid">
        <!-- Start #advan-support -->
        <div id="advan-support" class="clearfix">
            <!--<div class="row-maxwidth-98pct fixed">
                  <div class="previous"><a href="#"><i class="fa fa-long-arrow-left fa-2x" aria-hidden="true"></i></a></div>
            </div>-->
            <!---Start of downloadContent-->
            <div class="row-maxwidth-80pct downloadContent clearfix">
                <h2 id="detail-title">Driver for MIC-770V2</h2>
                <h5 class="downloadInfo">
                    <span class="date">2021-02-23</span>
                    <span class="type">Driver</span>
                    <span class="number">Document No.1-4452561523</span>
                </h5>
                                    <p class="title"><span class="bold">Related Product:</span></p>
                    <div class="toggler clearfix">
                        <p id="effect" class="ui-corner-all support-related-product">MIC-770 V2</p>
                        
                    </div>
                                    <div class="download-listWrap">
                            <p class="title"><span class="bold">Solution:</span></p>
                                <ul class="solution-box">
                                    <li class="box-wrap" id="solution-0">
                                        <div class="box-inner " data-solution-id="solution-0">
                                            <h4>Win10 64 bit driver for MIC-770WV2</h4>
                                            <span><button class="toggle"></button></span>
                                            <div class="clear"></div>
                                        </div>
                                        <div class="downloadlist">
                                            <div class="download-content">
                                                <p>1. Chipset driver has to be installed before installing all other drivers.<br />2. To ensure motherboard drivers work properly, please use Windows® 10 Version 1809 (RS5) or later.</p>
                                                        <div class="downloadItem clearfix">
                                                            <div class="downloadTXT">
                                                                <h4 class="downloadTitle">MIC-770V2_Chipset</h4>
                                                                <span class="date">2021-02-23</span>
                                                                <p></p>
                                                            </div>
                                                            <div class="btnWrap">
                                                                <h5 class="btn">
                                                                    <a  href="https://downloadt.advantech.com/download/downloadsr.aspx?File_Id=1-21MXUGP" target="_blank">Download</a>
                                                                </h5>
                                                            </div>
                                                        </div>
                                                        <div class="downloadItem clearfix">
                                                            <div class="downloadTXT">
                                                                <h4 class="downloadTitle">MIC-770V2_AUDIO</h4>
                                                                <span class="date">2021-02-23</span>
                                                                <p></p>
                                                            </div>
                                                            <div class="btnWrap">
                                                                <h5 class="btn">
                                                                    <a  href="https://downloadt.advantech.com/download/downloadsr.aspx?File_Id=1-21MXURB" target="_blank">Download</a>
                                                                </h5>
                                                            </div>
                                                        </div>
                                                        <div class="downloadItem clearfix">
                                                            <div class="downloadTXT">
                                                                <h4 class="downloadTitle">MIC-770V2_COM</h4>
                                                                <span class="date">2021-02-23</span>
                                                                <p></p>
                                                            </div>
                                                            <div class="btnWrap">
                                                                <h5 class="btn">
                                                                    <a  href="https://downloadt.advantech.com/download/downloadsr.aspx?File_Id=1-21MXURD" target="_blank">Download</a>
                                                                </h5>
                                                            </div>
                                                        </div>
                                                        <div class="downloadItem clearfix">
                                                            <div class="downloadTXT">
                                                                <h4 class="downloadTitle">MIC-770V2_Graphic</h4>
                                                                <span class="date">2021-02-23</span>
                                                                <p></p>
                                                            </div>
                                                            <div class="btnWrap">
                                                                <h5 class="btn">
                                                                    <a  href="https://downloadt.advantech.com/download/downloadsr.aspx?File_Id=1-21MXURF" target="_blank">Download</a>
                                                                </h5>
                                                            </div>
                                                        </div>
                                                        <div class="downloadItem clearfix">
                                                            <div class="downloadTXT">
                                                                <h4 class="downloadTitle">MIC-770V2_LAN</h4>
                                                                <span class="date">2021-02-23</span>
                                                                <p></p>
                                                            </div>
                                                            <div class="btnWrap">
                                                                <h5 class="btn">
                                                                    <a  href="https://downloadt.advantech.com/download/downloadsr.aspx?File_Id=1-21MXURH" target="_blank">Download</a>
                                                                </h5>
                                                            </div>
                                                        </div>
                                                        <div class="downloadItem clearfix">
                                                            <div class="downloadTXT">
                                                                <h4 class="downloadTitle">MIC-770V2_ME_corporate</h4>
                                                                <span class="date">2021-02-23</span>
                                                                <p></p>
                                                            </div>
                                                            <div class="btnWrap">
                                                                <h5 class="btn">
                                                                    <a  href="https://downloadt.advantech.com/download/downloadsr.aspx?File_Id=1-21MXURJ" target="_blank">Download</a>
                                                                </h5>
                                                            </div>
                                                        </div>
                                                        <div class="downloadItem clearfix">
                                                            <div class="downloadTXT">
                                                                <h4 class="downloadTitle">MIC-770V2_RST</h4>
                                                                <span class="date">2021-02-23</span>
                                                                <p></p>
                                                            </div>
                                                            <div class="btnWrap">
                                                                <h5 class="btn">
                                                                    <a  href="https://downloadt.advantech.com/download/downloadsr.aspx?File_Id=1-21MXUS5" target="_blank">Download</a>
                                                                </h5>
                                                            </div>
                                                        </div>
                                                        <div class="downloadItem clearfix">
                                                            <div class="downloadTXT">
                                                                <h4 class="downloadTitle">MIC-770V2_SerialIO</h4>
                                                                <span class="date">2021-02-23</span>
                                                                <p></p>
                                                            </div>
                                                            <div class="btnWrap">
                                                                <h5 class="btn">
                                                                    <a  href="https://downloadt.advantech.com/download/downloadsr.aspx?File_Id=1-21MXUS7" target="_blank">Download</a>
                                                                </h5>
                                                            </div>
                                                        </div>
                                            </div>
                                        </div>
                                    </li>
                                </ul>
                                <ul class="solution-box">
                                    <li class="box-wrap" id="solution-1">
                                        <div class="box-inner " data-solution-id="solution-1">
                                            <h4>Win10 64 bit driver for MIC-770HV2</h4>
                                            <span><button class="toggle"></button></span>
                                            <div class="clear"></div>
                                        </div>
                                        <div class="downloadlist">
                                            <div class="download-content">
                                                <p>1. Chipset driver has to be installed before installing all other drivers.<br />2. To ensure motherboard drivers work properly, please use Windows® 10 Version 1809 (RS5) or later.</p>
                                                        <div class="downloadItem clearfix">
                                                            <div class="downloadTXT">
                                                                <h4 class="downloadTitle">MIC-770V2_Chipset</h4>
                                                                <span class="date">2021-02-23</span>
                                                                <p></p>
                                                            </div>
                                                            <div class="btnWrap">
                                                                <h5 class="btn">
                                                                    <a  href="https://downloadt.advantech.com/download/downloadsr.aspx?File_Id=1-21MXUGP" target="_blank">Download</a>
                                                                </h5>
                                                            </div>
                                                        </div>
                                                        <div class="downloadItem clearfix">
                                                            <div class="downloadTXT">
                                                                <h4 class="downloadTitle">MIC-770V2_AUDIO</h4>
                                                                <span class="date">2021-02-23</span>
                                                                <p></p>
                                                            </div>
                                                            <div class="btnWrap">
                                                                <h5 class="btn">
                                                                    <a  href="https://downloadt.advantech.com/download/downloadsr.aspx?File_Id=1-21MXURB" target="_blank">Download</a>
                                                                </h5>
                                                            </div>
                                                        </div>
                                                        <div class="downloadItem clearfix">
                                                            <div class="downloadTXT">
                                                                <h4 class="downloadTitle">MIC-770V2_COM</h4>
                                                                <span class="date">2021-02-23</span>
                                                                <p></p>
                                                            </div>
                                                            <div class="btnWrap">
                                                                <h5 class="btn">
                                                                    <a  href="https://downloadt.advantech.com/download/downloadsr.aspx?File_Id=1-21MXURD" target="_blank">Download</a>
                                                                </h5>
                                                            </div>
                                                        </div>
                                                        <div class="downloadItem clearfix">
                                                            <div class="downloadTXT">
                                                                <h4 class="downloadTitle">MIC-770V2_Graphic</h4>
                                                                <span class="date">2021-02-23</span>
                                                                <p></p>
                                                            </div>
                                                            <div class="btnWrap">
                                                                <h5 class="btn">
                                                                    <a  href="https://downloadt.advantech.com/download/downloadsr.aspx?File_Id=1-21MXURF" target="_blank">Download</a>
                                                                </h5>
                                                            </div>
                                                        </div>
                                                        <div class="downloadItem clearfix">
                                                            <div class="downloadTXT">
                                                                <h4 class="downloadTitle">MIC-770V2_LAN</h4>
                                                                <span class="date">2021-02-23</span>
                                                                <p></p>
                                                            </div>
                                                            <div class="btnWrap">
                                                                <h5 class="btn">
                                                                    <a  href="https://downloadt.advantech.com/download/downloadsr.aspx?File_Id=1-21MXURH" target="_blank">Download</a>
                                                                </h5>
                                                            </div>
                                                        </div>
                                                        <div class="downloadItem clearfix">
                                                            <div class="downloadTXT">
                                                                <h4 class="downloadTitle">MIC-770V2_RST</h4>
                                                                <span class="date">2021-02-23</span>
                                                                <p></p>
                                                            </div>
                                                            <div class="btnWrap">
                                                                <h5 class="btn">
                                                                    <a  href="https://downloadt.advantech.com/download/downloadsr.aspx?File_Id=1-21MXUS5" target="_blank">Download</a>
                                                                </h5>
                                                            </div>
                                                        </div>
                                                        <div class="downloadItem clearfix">
                                                            <div class="downloadTXT">
                                                                <h4 class="downloadTitle">MIC-770V2_SerialIO</h4>
                                                                <span class="date">2021-02-23</span>
                                                                <p></p>
                                                            </div>
                                                            <div class="btnWrap">
                                                                <h5 class="btn">
                                                                    <a  href="https://downloadt.advantech.com/download/downloadsr.aspx?File_Id=1-21MXUS7" target="_blank">Download</a>
                                                                </h5>
                                                            </div>
                                                        </div>
                                                        <div class="downloadItem clearfix">
                                                            <div class="downloadTXT">
                                                                <h4 class="downloadTitle">MIC-770V2_ME_consumer</h4>
                                                                <span class="date">2021-02-23</span>
                                                                <p></p>
                                                            </div>
                                                            <div class="btnWrap">
                                                                <h5 class="btn">
                                                                    <a  href="https://downloadt.advantech.com/download/downloadsr.aspx?File_Id=1-21MXUT4" target="_blank">Download</a>
                                                                </h5>
                                                            </div>
                                                        </div>
                                            </div>
                                        </div>
                                    </li>
                                </ul>
                        <div class="downloadFooter clearfix">
                            <div class="tags clearfix"></div>
                            <!-- Go to www.addthis.com/dashboard to customize your tools -->
                            <div class="addthis_sharing_toolbox"></div>
                        </div>
                    </div>
            </div>
            <!--End of downloadContent -->
            <!--Start of commentWrap--->
            <div class=" commentWrap clearFix">
                <div class="row-maxwidth-80pct border-wrapper formWrap">
                    <form id="feedback-form">
                        <div class="commentItem clearFix active">
                            <label>How would you rate this content? </label>
                            <div class="rate clearfix">
                                <input type="radio" id="5A" name="rate" value="5" />
                                <label for="5A" title="">5 A</label>
                                <input type="radio" id="4A" name="rate" value="4" />
                                <label for="4A" title="">4 A</label>
                                <input type="radio" id="3A" name="rate" value="3" />
                                <label for="3A" title="">3 A</label>
                                <input type="radio" id="2A" name="rate" value="2" />
                                <label for="2A" title="">2 A</label>
                                <input type="radio" id="1A" name="rate" value="1" />
                                <label for="1A" title="">1 A</label>
                                <div style="clear: both;"></div>
                            </div>
                            <div class="clear"></div>
                        </div>

                        <!-- hidden on default -->
                        <div class="commentItem clearFix" data-form-step="main-reason">
                            <label>Please tell us the main reason <span class="form-textRequir">*</span></label>
                            <span class="inputWrap radioBtn block">
                                <input type="radio" value="The content is too difficult to understand" name="main-reason" checked>
                                The content is too difficult to understand
                            </span> <span class="inputWrap radioBtn block">
                                <input type="radio" value="The content does not match the title" name="main-reason">
                                The content does not match the title
                            </span> <span class="inputWrap radioBtn block">
                                <input type="radio" value=" The information is out of date" name="main-reason">
                                The information is out of date
                            </span> <span class="inputWrap radioBtn block">
                                <input type="radio" value="It is not the information I'm looking for" name="main-reason">
                                It is not the information I'm looking for
                            </span> <span class="inputWrap radioBtn block">
                                <input type="radio" value="The content is empty" name="main-reason">
                                The content is empty
                            </span> <span class="inputWrap radioBtn block">
                                <input type="radio" value="Download file missingy" name="main-reason">
                                Download file missing
                            </span> <span class="inputWrap radioBtn block">
                                <input type="radio" value=" Invalid download link" name="main-reason">
                                Invalid download link
                            </span> <span class="inputWrap radioBtn block">
                                <input type="radio" value="Download speed is slow" name="main-reason">
                                Download speed is slow
                            </span> <span class="inputWrap radioBtn block">
                                <input type="radio" value="Others" name="main-reason">
                                Others
                            </span>
                        </div>
                        <!-- -->
                        <div class="commentItem clearFix active">
                            <label>Do you need further assistance? <span class="form-textRequir">*</span></label>
                            <span class="inputWrap radioBtn">
                                <input type="radio" value="true" name="further-assistances">
                                Yes
                            </span>
                            <span class="inputWrap radioBtn">
                                <input type="radio" value="false" name="further-assistances" checked>
                                No
                            </span>
                        </div>
                        <div class="commentItem clearFix" data-form-step="contact-information">
                            <label>Please leave your contact information, we will reply to your message in a timely manner. <span class="form-textRequir">*</span></label>
                                <select id="country" name="country">
                                    <option value="">Choose Country</option>
                                            <option value="afghanistan">Afghanistan</option>
                                            <option value="albania">Albania</option>
                                            <option value="algeria">Algeria</option>
                                            <option value="andorra">Andorra</option>
                                            <option value="angola">Angola</option>
                                            <option value="anguilla">Anguilla</option>
                                            <option value="antarctica">Antarctica</option>
                                            <option value="antigua and barbuda">Antigua and Barbuda</option>
                                            <option value="argentina">Argentina</option>
                                            <option value="armenia">Armenia</option>
                                            <option value="aruba">Aruba</option>
                                            <option value="australia">Australia</option>
                                            <option value="austria">Austria</option>
                                            <option value="azerbaijan">Azerbaijan</option>
                                            <option value="bahamas">Bahamas</option>
                                            <option value="bahrain">Bahrain</option>
                                            <option value="bangladesh">Bangladesh</option>
                                            <option value="barbados">Barbados</option>
                                            <option value="belarus">Belarus</option>
                                            <option value="belgium">Belgium</option>
                                            <option value="belize">Belize</option>
                                            <option value="benin">Benin</option>
                                            <option value="bermuda">Bermuda</option>
                                            <option value="bhutan">Bhutan</option>
                                            <option value="bolivia">Bolivia</option>
                                            <option value="bosnia and herzegovina">Bosnia and Herzegovina</option>
                                            <option value="botswana">Botswana</option>
                                            <option value="brazil">Brazil</option>
                                            <option value="brunei">Brunei</option>
                                            <option value="bulgaria">Bulgaria</option>
                                            <option value="burkina faso">Burkina Faso</option>
                                            <option value="burundi">Burundi</option>
                                            <option value="cambodia">Cambodia</option>
                                            <option value="cameroon">Cameroon</option>
                                            <option value="canada">Canada</option>
                                            <option value="cape verde islands">Cape Verde Islands</option>
                                            <option value="cayman islands">Cayman Islands</option>
                                            <option value="central african republic">Central African Republic</option>
                                            <option value="chad">Chad</option>
                                            <option value="chile">Chile</option>
                                            <option value="china">China</option>
                                            <option value="cocos (keeling) islands">Cocos (Keeling) Islands</option>
                                            <option value="colombia">Colombia</option>
                                            <option value="comoros">Comoros</option>
                                            <option value="congo">Congo</option>
                                            <option value="cook islands">Cook Islands</option>
                                            <option value="costa rica">Costa Rica</option>
                                            <option value="croatia">Croatia</option>
                                            <option value="cuba">Cuba</option>
                                            <option value="cyprus">Cyprus</option>
                                            <option value="czech republic">Czech Republic</option>
                                            <option value="denmark">Denmark</option>
                                            <option value="djibouti">Djibouti</option>
                                            <option value="dominica">Dominica</option>
                                            <option value="dominican republic">Dominican Republic</option>
                                            <option value="east timor">East Timor</option>
                                            <option value="ecuador">Ecuador</option>
                                            <option value="egypt">Egypt</option>
                                            <option value="el salvador">El Salvador</option>
                                            <option value="equatorial guinea">Equatorial Guinea</option>
                                            <option value="eritrea">Eritrea</option>
                                            <option value="estonia">Estonia</option>
                                            <option value="ethiopia">Ethiopia</option>
                                            <option value="falkland islands (malvinas)">Falkland Islands (MALVINAS)</option>
                                            <option value="faroe islands">Faroe Islands</option>
                                            <option value="fiji">Fiji</option>
                                            <option value="finland">Finland</option>
                                            <option value="france">France</option>
                                            <option value="french guiana">French Guiana</option>
                                            <option value="gabon">Gabon</option>
                                            <option value="gambia">Gambia</option>
                                            <option value="georgia">Georgia</option>
                                            <option value="germany">Germany</option>
                                            <option value="ghana">Ghana</option>
                                            <option value="gibraltar">Gibraltar</option>
                                            <option value="greece">Greece</option>
                                            <option value="greenland">Greenland</option>
                                            <option value="grenada">Grenada</option>
                                            <option value="guadeloupe">Guadeloupe</option>
                                            <option value="guam">Guam</option>
                                            <option value="guatemala">Guatemala</option>
                                            <option value="guinea">Guinea</option>
                                            <option value="guinea-bissau">Guinea-Bissau</option>
                                            <option value="guyana">Guyana</option>
                                            <option value="haiti">Haiti</option>
                                            <option value="honduras">Honduras</option>
                                            <option value="hong kong">Hong Kong</option>
                                            <option value="hungary">Hungary</option>
                                            <option value="iceland">Iceland</option>
                                            <option value="india">India</option>
                                            <option value="indonesia">Indonesia</option>
                                            <option value="iran">Iran</option>
                                            <option value="iraq">Iraq</option>
                                            <option value="ireland">Ireland</option>
                                            <option value="israel">Israel</option>
                                            <option value="italy">Italy</option>
                                            <option value="ivory coast">Ivory Coast</option>
                                            <option value="jamaica">Jamaica</option>
                                            <option value="japan">Japan</option>
                                            <option value="jordan">Jordan</option>
                                            <option value="kazakhstan">Kazakhstan</option>
                                            <option value="kenya">Kenya</option>
                                            <option value="kiribati">Kiribati</option>
                                            <option value="korea">Korea</option>
                                            <option value="korea (north)">Korea (North)</option>
                                            <option value="kosovo">Kosovo</option>
                                            <option value="kuwait">Kuwait</option>
                                            <option value="kyrgyzstan">Kyrgyzstan</option>
                                            <option value="laos">Laos</option>
                                            <option value="latvia">Latvia</option>
                                            <option value="lebanon">Lebanon</option>
                                            <option value="lesotho">Lesotho</option>
                                            <option value="liberia">Liberia</option>
                                            <option value="libya">Libya</option>
                                            <option value="liechtenstein">Liechtenstein</option>
                                            <option value="lithuania">Lithuania</option>
                                            <option value="luxembourg">Luxembourg</option>
                                            <option value="macao">Macao</option>
                                            <option value="madagascar">Madagascar</option>
                                            <option value="malawi">Malawi</option>
                                            <option value="malaysia">Malaysia</option>
                                            <option value="maldives">Maldives</option>
                                            <option value="mali">Mali</option>
                                            <option value="malta">Malta</option>
                                            <option value="marshall islands">Marshall Islands</option>
                                            <option value="martinique">Martinique</option>
                                            <option value="mauritania">Mauritania</option>
                                            <option value="mauritius">Mauritius</option>
                                            <option value="mexico">Mexico</option>
                                            <option value="micronesia">Micronesia</option>
                                            <option value="moldova">Moldova</option>
                                            <option value="monaco">Monaco</option>
                                            <option value="mongolia">Mongolia</option>
                                            <option value="montenegro">Montenegro</option>
                                            <option value="montserrat">Montserrat</option>
                                            <option value="morocco">Morocco</option>
                                            <option value="mozambique">Mozambique</option>
                                            <option value="myanmar">Myanmar</option>
                                            <option value="namibia">Namibia</option>
                                            <option value="nauru">Nauru</option>
                                            <option value="nepal">Nepal</option>
                                            <option value="netherlands">Netherlands</option>
                                            <option value="netherlands antilles">Netherlands Antilles</option>
                                            <option value="nevis">Nevis</option>
                                            <option value="new caledonia">New Caledonia</option>
                                            <option value="new zealand">New Zealand</option>
                                            <option value="nicaragua">Nicaragua</option>
                                            <option value="niger">Niger</option>
                                            <option value="nigeria">Nigeria</option>
                                            <option value="niue">Niue</option>
                                            <option value="norfolk island">Norfolk Island</option>
                                            <option value="north macedonia">North Macedonia</option>
                                            <option value="northern mariana islands">Northern Mariana Islands</option>
                                            <option value="norway">Norway</option>
                                            <option value="oman">Oman</option>
                                            <option value="pakistan">Pakistan</option>
                                            <option value="palau">Palau</option>
                                            <option value="palestine">Palestine</option>
                                            <option value="panama">Panama</option>
                                            <option value="papua new guinea">Papua New Guinea</option>
                                            <option value="paraguay">Paraguay</option>
                                            <option value="peru">Peru</option>
                                            <option value="philippines">Philippines</option>
                                            <option value="poland">Poland</option>
                                            <option value="portugal">Portugal</option>
                                            <option value="puerto rico">Puerto Rico</option>
                                            <option value="qatar">Qatar</option>
                                            <option value="reunion">Reunion</option>
                                            <option value="romania">Romania</option>
                                            <option value="russia">Russia</option>
                                            <option value="rwanda">Rwanda</option>
                                            <option value="saint helena">Saint Helena</option>
                                            <option value="saint lucia">Saint Lucia</option>
                                            <option value="saint vincent and the grenadines">Saint Vincent and the Grenadines</option>
                                            <option value="samoa">Samoa</option>
                                            <option value="san marino">San Marino</option>
                                            <option value="sao tome and principe">Sao Tome and Principe</option>
                                            <option value="saudi arabia">Saudi Arabia</option>
                                            <option value="senegal">Senegal</option>
                                            <option value="serbia">Serbia</option>
                                            <option value="seychelles">Seychelles</option>
                                            <option value="sierra leone">Sierra Leone</option>
                                            <option value="singapore">Singapore</option>
                                            <option value="slovakia">Slovakia</option>
                                            <option value="slovenia">Slovenia</option>
                                            <option value="solomon islands">Solomon Islands</option>
                                            <option value="somalia">Somalia</option>
                                            <option value="south africa">South Africa</option>
                                            <option value="spain">Spain</option>
                                            <option value="sri lanka">Sri Lanka</option>
                                            <option value="st. kitts/nevis">St. Kitts/Nevis</option>
                                            <option value="sudan">Sudan</option>
                                            <option value="suriname">Suriname</option>
                                            <option value="swaziland">Swaziland</option>
                                            <option value="sweden">Sweden</option>
                                            <option value="switzerland">Switzerland</option>
                                            <option value="syria">Syria</option>
                                            <option value="taiwan">Taiwan</option>
                                            <option value="tajikistan">Tajikistan</option>
                                            <option value="tanzania">Tanzania</option>
                                            <option value="thailand">Thailand</option>
                                            <option value="togo">Togo</option>
                                            <option value="tonga">Tonga</option>
                                            <option value="trinidad and tobago">Trinidad and Tobago</option>
                                            <option value="tunisia">Tunisia</option>
                                            <option value="turkey">Turkey</option>
                                            <option value="turkmenistan">Turkmenistan</option>
                                            <option value="uganda">Uganda</option>
                                            <option value="ukraine">Ukraine</option>
                                            <option value="united arab emirates">United Arab Emirates</option>
                                            <option value="united kingdom">United Kingdom</option>
                                            <option value="united states">United States</option>
                                            <option value="uruguay">Uruguay</option>
                                            <option value="uzbekistan">Uzbekistan</option>
                                            <option value="vanuatu">Vanuatu</option>
                                            <option value="vatican city">Vatican City</option>
                                            <option value="venezuela">Venezuela</option>
                                            <option value="vietnam">Vietnam</option>
                                            <option value="virgin islands (british)">Virgin Islands (British)</option>
                                            <option value="virgin islands (us)">Virgin Islands (US)</option>
                                            <option value="yemen">Yemen</option>
                                            <option value="zaire">Zaire</option>
                                            <option value="zambia">Zambia</option>
                                            <option value="zimbabwe">Zimbabwe</option>
                                </select>
                            <span class="inputWrap" id="firstname-wrap">
                                <p class="form-text">This field of information is requried</p>
                                <input class="col-2-input" type="text" id="fname" name="firstname" placeholder="First Name">
                            </span>
                            <span class="inputWrap" id="lastname-wrap">
                                <p class="form-text">This field of information is requried</p>
                                <input class="col-2-input" type="text" id="lname" name="lastname" placeholder="Last Name">
                            </span>
                            <span class="inputWrap" id="email-wrap">
                                <p class="form-text">This field of information is invalid</p>
                                <input class="col-2-input" type="text" id="email" name="email" placeholder="Email">
                            </span>
                            <span class="inputWrap" id="company-wrap">
                                <p class="form-text">This field of information is requried</p>
                                <input class="col-2-input" type="text" id="company" name="company" placeholder="Company">
                            </span>
                        </div>
                        <div class="commentItem clearFix" data-form-step="feedback">
                            <label>If you had any feedback or suggestion about the information above, please specify it</label>
                            <textarea class="textArea" id="comments" placeholder="Please specify it"></textarea>
                        </div>
                        <input type="submit" value="Submit" id="formBtn">
                    </form>
                    <div class="Successful-info" style="display: none;">
                        <h2><i class="fas fa-check-circle"></i>Thank you for your feedback </h2>
                        <p>We will look over your massage and get back to you soon if you need further assistance!</p>
                    </div>
                </div>
            </div>
            <!--End of commentWrap-->
        </div>
        <!-- End #advan-support -->
    </div>
</div>

        <div id="advan-footer">
    <!-- start aonline -->
    <div class="row-fluid row-gray-blue">
        <div class="row-maxwidth-98pct aonline-contactWrap clearfix">
            <h2 class="aonline-contactTitle">How Can We Help?</h2>
            <ul class="aonline-contact clearfix">
                <li><i class="fal fa-shopping-cart"></i><a href="http://buy.advantech.com">Buy Online</a></li>
                <li><i class="fal fa-wrench"></i><a href="/support">Support</a></li>
                    <li class="contact-chat corp-live-chat" style="display: none;"><i class="fal fa-comments"></i><a class="zendeskTrigger" href="#">Live Chat</a></li>
                                            <li><i class="fal fa-phone" aria-label="Customer service number"></i><span>1-888-576-9668</span></li>
            </ul>
            <div class="clear"></div>
        </div>
    </div>
    <!-- end aonline -->
    <div class="row-fluid row-gray-b96 row-brdrwhite">
        <div class="row-maxwidth-98pct">
            <div class="footer-nav-wrapper clearfix">
                <div class="footer-logo">
                    <div class="logo-pic">
                            <img src="https://www.advantech.com/css/css-img/advantech-logo-notagl.svg" alt="Advantech" border="0" />
                    </div>
                </div>
                <div class="footer-nav">
                    <ul class="clearfix">
                        <li><i class="fa fa-angle-right fa-lg" aria-hidden="true"></i> <a href="/about/missionandfocus">Company Information</a></li>
                        <li><i class="fa fa-angle-right fa-lg" aria-hidden="true"></i> <a href="/investor">Investor Relations</a></li>
                        <li><i class="fa fa-angle-right fa-lg" aria-hidden="true"></i> <a href="/contact">Contact Us</a></li>
                        <li><i class="fa fa-angle-right fa-lg" aria-hidden="true"></i> <a href="https://csr.advantech.com/en-us" target="_blank">Corporate Citizenship (CSR)</a></li>
                        <li><i class="fa fa-angle-right fa-lg" aria-hidden="true"></i> <a href="/eventnews/events/">Global Exhibitions</a></li>
                        <li><i class="fa fa-angle-right fa-lg" aria-hidden="true"></i> <a href="/careers">Careers</a></li>
                    </ul>
                </div>
            </div>
            <!-- end .footer-nav-wrapper -->
            <div class="footer-wrapper clearfix">
                    <div class="footer-language" id="footer-language"><i class="far fa-globe-americas" aria-label="Language"></i><a href="#" class="language-earth-svg">United States</a></div>
                    <div class="row-fluid row-brdrgray footer-panel-wrapper language-panel" id="language-panel">
                        <div class="row-maxwidth-100pct">
                            <div class="panel-control-down"><a href="#">Panel Button</a></div>
                            <div class="lang-desc">Visit the <a href="#">Advantech Global website</a>, or choose your country or region below.</div>
                            <div class="panel-block">
                                <h4>America Region</h4>
                                <ol class="lang-list clearfix">
                                    <li><a href="https://www.advantech.com">United States</a></li>
                                    <li><a href="https://www.advantech.com.br">Brasil</a></li>
                                    <li><a href="https://www.advantech.com.mx">México</a></li>
                                    <li><a href="https://www.advantech.com.ar">Argentina</a></li>
                                    <li><a href="https://www.advantech-cl.com">Chile</a></li>
                                    <li><a href="https://www.advantech.com.co">Colombia</a></li>
                                    <li><a href="https://www.advantech.com.pe">Perú</a></li>
                                </ol>
                                <div class="clear"></div>
                            </div>
                            <div class="panel-block">
                                <h4>Europe Region</h4>
                                <ol class="lang-list clearfix">
                                    <li><a href="https://www.advantech.eu">Europe</a></li>
                                    <li><a href="https://www.advantech.ru">Россия</a></li>
                                    <li><a href="https://www.advantech.es">España</a></li>
                                </ol>
                                <div class="clear"></div>
                            </div>
                            <div class="panel-block">
                                <h4>Asia Pacific</h4>
                                <ol class="lang-list clearfix">
                                    <li><a href="https://www.advantech.net.au">Australia</a></li>
                                    <li><a href="https://www.advantech.com.cn">中国</a></li>
                                    <li><a href="https://www.advantech.in">India</a></li>
                                    <li><a href="https://www.advantech.co.id">Indonesia</a></li>
                                    <li><a href="https://www.advantech.co.jp">日本</a></li>
                                    <li><a href="https://www.advantech.co.kr">대한민국</a></li>
                                    <li><a href="https://www.advantech.com.my">Malaysia</a></li>
                                    <li><a href="https://www.advantech.com.sg">Singapore</a></li>
                                    <li><a href="https://www.advantech.tw">台灣</a></li>
                                    <li><a href="https://www.advantech.co.th">ไทย</a></li>
                                    <li><a href="https://www.advantech.com.tr">Türkiye</a></li>
                                    <li><a href="https://www.advantech.com.vn">Việt nam</a></li>
                                </ol>
                                <div class="clear"></div>
                            </div>
                            <div class="panel-block">
                                <h4>Africa &amp; Middle East</h4>
                                <ol class="lang-list clearfix">
                                    
                                    <li><a href="https://www.advantech.ae">MENA</a></li>
                                </ol>
                                <div class="clear"></div>
                            </div>
                        </div>
                    </div>
                <!-- end .footer-panel-wrapper -->
                <ul class="footer-copyright clearfix">
                    <li class="copr-first">&#169; 1983-2021 Advantech Co., Ltd.</li>
                    <li id="footer-info-sitemap"><a href="/sitemap">Site Map</a></li>
                        <li id="footer-info-privacy"><a href="/legal/privacy">Privacy Policy</a></li>
                    <li><a href="/legal/privacy/ccpa-do-not-sell">Do Not Sell My Personal Information</a></li>
                </ul>
                <div class="clear"></div>
            </div>
            <!-- end .footer-wrapper -->
        </div>
    </div>
</div>



    </div>
    
    <div id="download-form" class="barcode-form" style="display: none;">
        <div class="formWrap">
            <h4>Driver for MIC-770V2</h4>
            <p>Please enter your barcode to get this file.</p>
            <span id="barcodeWrap" class="inputWrap fixed">
                <input id="barcode" type="text" placeholder="Barcode" v-model="barcode" :disabled="isBarcodeSended && isBarcodeValid">
                <span class="sucessful-icon"><i class="fas fa-check-circle"></i></span>
                <p v-show="isBarcodeSended && !isBarcodeValid" class="form-text">This barcode is invalid.</p>
            </span>
        </div>
        <div class="btn"><a id="submit" href="#">Submit</a></div>
        <div class="btn"><a id="download" :href="downloadURL" target="_blank" style="display: none;">Download</a></div>
        <button data-fancybox-close="" class="fancybox-close-small" title="Close"></button>
    </div>
    <div id="auth-form" class="barcode-form" style="display: none;">
        <div class="formWrap">
            <h4>Driver for MIC-770V2</h4>
            <p>Please enter your barcode to get this file.</p>
            <span id="barcodeWrap" class="inputWrap fixed">
                <input id="barcode" type="text" placeholder="Barcode" v-model="barcode" :disabled="isBarcodeSended && isBarcodeValid">
                <span class="sucessful-icon"><i class="fas fa-check-circle"></i></span>
                <p v-show="isBarcodeSended && !isBarcodeValid" class="form-text">This barcode is invalid.</p>
            </span>
        </div>
        <div class="btn"><a id="auth" href="#">Submit</a></div>
        <button data-fancybox-close="" class="fancybox-close-small" title="Close"></button>
    </div>


    <!-- All JavaScript ( Header, Footer, SlideTab, GA ) -->
        <script type="text/javascript" src="https://advcloudfiles.advantech.com/web/lib/jquery-ui/jquery-ui.min.js"></script>

    <!--[if lt IE 9]>
    <script src="https://advcloudfiles.advantech.com/web/lib/html5shiv/html5.js"></script>
    <script src="https://advcloudfiles.advantech.com/web/lib/css3-mediaqueries/css3-mediaqueries.js"></script>
    <![endif]-->
    <!-- Common -->
    <script type="text/javascript" src="https://advcloudfiles.advantech.com/web/lib/es5-shim/es5-shim.min.js"></script>
    <script type="text/javascript" src="https://advcloudfiles.advantech.com/web/lib/jquery-equalHeight/jquery.equalHeights.min.js"></script>
    <script type="text/javascript" src="https://advcloudfiles.advantech.com/web/lib/jquery-cookie/jquery.cookie.min.js"></script>
        <script type="text/javascript" src="https://advcloudfiles.advantech.com/support/live-chat/1.3.2/dist/main.min.js" defer async></script>

    <!-- Responsive Nav and Slding Panel -->
        <script type="text/javascript" src="/js/common.js"></script>

    
    <script type="text/javascript" src="https://advcloudfiles.advantech.com/web/lib/jquery-dotdotdot/jquery.dotdotdot.min.js"></script>
    <script src="https://advcloudfiles.advantech.com/web/lib/jquery-fancybox/3.1.28/jquery.fancybox.min.js" type="text/javascript"></script>
    <script src="/js/support/utility/detail-helper.js" type="text/javascript"></script>
    <script src="/js/support/main-site/detail.js?v=20210129" type="text/javascript"></script>



    <!-- Header -->
    <script type="text/javascript" src="/js/Products/Search.min.js?v=2020072915"></script>


    <!-- Start _TrackingCodeBody  -->
        <!-- Google Code for Corp Conversion Page -->
    <div style="position:absolute;top:-9999px;left:-9999px">
        <img height="1" width="1" style="border-style:none;" alt="" src="https://www.googleadservices.com/pagead/conversion/1002092822/?value=0&amp;label=YE7BCOqG2gIQlvLq3QM&amp;guid=ON&amp;script=0" />
        <img height="1" width="1" style="border-style:none;" alt="" src="//googleads.g.doubleclick.net/pagead/viewthroughconversion/1041592169/?value=0&amp;guid=ON&amp;script=0" />
    </div>
    <!--  GA Tracking Code by IP -->
    <div id="divGoogle" style="position:absolute;top:-9999px;left:-9999px"></div>
    <script>
        $.ajax({
            type: "POST",
            cache: false,
            url: '/handler/CheckIP.ashx',
            dataType: 'json',
            processData: true,
            success: function (data) {
                $("#divGoogle").html(data.ip);

                $('body').trigger('trackingCodeReady');
            },
            error: function (e) {
            }
        });
    </script>


    <!-- advWebTracking -->
    <!-- change [jquery.cookies.2.2.0.js] to [jquery.cookie.js] by Jayson 20150420 -->
    <script type="text/javascript" src="https://advwebtracking.advantech.com/Track/AdvTrack.js"></script>
    <script type="text/javascript">

    var _advWebTrackingPortal = "www.advantech.com",
        _advWebTrackingEngagementLevel = "",
        _advWebTrackingPageType = "",
        _advWebTrackingContentID = "",
        _advWebTrackingFocusAOnline = "",
        Message = $.cookie('Adv_Webtracking');

    var _Email = (Message != null) ? Message : "";

    var args = GetUrlParms(location.search.substring(1)),
        _UID = args.hasOwnProperty('uid') ? args['uid'] : "",
        _CampId = args.hasOwnProperty('campid') ? args['campid'] : "";
    // these variables are needed by AdvTrack.js
    // advTrack.js will run at window.onload

    if (window.location.hostname !== 'www.advantech.com.cn') {
        var resource = document.createElement('script');
        resource.async = "true";
        resource.src = "https://advwebtracking-cloud.advantech.com/GoogleAdwords/ad.js";
        var script = document.getElementsByTagName('script')[0];
        script.parentNode.insertBefore(resource, script);
    }
    </script>


    <script>
        $(function () {
            var $sidePanel = $('#advan-sidepanel');

            $sidePanel.find('.handle').on('click', function () {
                if (window.ga) {
                    ga('send', 'event', 'FixedRightTab', 'click', location.href);
                }
            });

            $sidePanel.find('li.callback a').on('click', function () {
                if (window.ga) {
                    ga('send', 'event', 'FixedRightTab_RequestCallBack', 'click', location.href);
                }
            });

            $sidePanel.find('li.livechat').on('click', function () {
                if (window.ga) {
                    ga('send', 'event', 'FixedRightTab_LiveChat', 'click', location.href);
                }
            });

            $sidePanel.find('li.emailus').on('click', function () {
                if (window.ga) {
                    ga('send', 'event', 'FixedRightTab_SalesQuotation', 'click', location.href);
                }
            });
        });
    </script>


    <script type="text/javascript">
        (function (d, s, i, r) {
            if (d.getElementById(i)) { return; }
            var n = d.createElement(s), e = d.getElementsByTagName(s)[0];
            n.id = i; n.src = '//js.hs-analytics.net/analytics/' + (Math.ceil(new Date() / r) * r) + '/398452.js';
            e.parentNode.insertBefore(n, e);
        })(document, "script", "hs-analytics", 300000);
    </script>


<!-- Facebook Pixel Code -->
<!-- End Facebook Pixel Code -->

    <!-- Start Advantech Web Tracking Plug-in -->
    <script>
    window.__AdvWebTracking_Site__ = 'Corp. Site - www.advantech.com';
    </script>
    <script src="https://advcloudfiles.advantech.com/components/plugins/adv-web-tracking/1.2.0/dist/adv-web-tracking-logs.min.js" defer async></script>
    <!-- End Advantech Web Tracking Plug-in -->

    <!-- End _TrackingCodeBody  -->
    <!-- Start siteinfo.BodyEnd  -->
    <!-- End siteinfo.BodyEnd  -->


    <script src="https://advcloudfiles.advantech.com/components/plugins/utm-track/1.1.0/utm-track.min.js" async defer></script>
</body>

</html>

'''

# %%
soup = BeautifulSoup(res, "html.parser")

# %%
for i in soup.select("#X_1_2"):
    if re.search("19A.*", i.get_text()) and re.search("Part Approve", i.parent.parent.select("#X_4_2")[0].get_text()):  
        print(i.get_text())
        sn = i.get_text()
# Out:
# 19A1080501-01 [01]

# %%
res='''<html><head>
   <title> 19A NPb PCB/ENTEK: 19A1058701-01 - PCB ASMB-587 A101-2 L:6 C:G 1.65MM FR4-TG150
   </title>
  
  
    <meta http-equiv="expires" content="Mon, 26 Jul 1997 05:00:00 GMT">
	<meta http-equiv="Cache-Control" content="no-cache">
    <meta http-equiv="Cache-Control" content="no-store">
    <meta http-equiv="Cache-Control" content="max-age=0">
    <meta http-equiv="Cache-Control" content="must-revalidate">
    <meta http-equiv="Cache-Control" content="post-check=0, pre-check=0">
    <meta http-equiv="pragma" content="no-cache">

   <script language="Javascript" src="/Agile/static/ee24214b1d88b2edbd1835935b9c3221en_US/default/includes/ScriptMessages.jsp"></script>
    









			<link href="/Agile/static/46b836388f591e23cf7560ef8507e93c/agile1002.css" rel="STYLESHEET" type="text/css">

    






<script language="JavaScript" type="text/javascript">
   var strAM = "AM";  // set JavaScript global vars for use in calendarControl
   var strPM = "PM";
</script>

    <script language="Javascript" src="/Agile/static/2e3aa9c44af32290498cb47cb0a9a09d/includes/FormsLib.js"></script>
    <script language="Javascript" src="/Agile/static/6fa072654177ab77f3d70dfdf630ea76/includes/PCFormsLib.js"></script>
    <script language="Javascript" src="/Agile/static/5328dd27a2930ce8d0d47bac9dcc75e7/includes/TableLib.js"></script>
    <script language="Javascript" src="/Agile/static/0971f0565f94f88627f63033b8726dd9/includes/dualSelectControl.js"></script>
    <script language="Javascript" src="/Agile/static/061eb1c321c064548aef8c122cb3c93a/includes/DataDialogLib.js"></script>
    <script language="Javascript" src="/Agile/static/9daf7f145e3311ce54284ef45a1eb48b/includes/browserSniffer.js"></script>
	<script language="Javascript" src="/Agile/static/9dfd213d20b15c43ab4141ee48403d55/includes/browserSniffer2.js"></script>
    <script language="Javascript" src="/Agile/static/c3f3f84ada72ac6a1597b799ce27c9a2/includes/rowHighlight.js"></script>
    <script language="JavaScript" src="/Agile/static/5724d8435a13a6aec5c8f28cafc1eac3/includes/PaginationLib.js"></script>
    <script language="Javascript" src="/Agile/static/a0545badad5a3a38baf2f2fa016bbf62/includes/menusCommon.js"></script>
    <script language="Javascript" src="/Agile/static/6dc33c01729884dfb5f87648b808605f/includes/setFocus.js"></script>
    <script language="JavaScript" src="/Agile/static/34b2ae1bec77c045acf603ef1608054b/includes/rightHeaderInclude.js"></script>
    <script language="Javascript" src="/Agile/static/fce49c43e2cf4e28a176fbb92fa228bc/includes/AttachmentLib.js"></script>
    <script language="Javascript" src="/Agile/static/61dcaaa0b36a44e269ca1540cb1ffe79/includes/freezePanes.js"></script>
    <script language="Javascript" src="/Agile/static/bd0cd2d1ad60533380ab95389aad2d5e/includes/iconOverlay.js"></script>
    <script language="Javascript" src="/Agile/static/b0fc7c5c76b597934afa81c63d8e980c/includes/ObjectsLib.js"></script>
     
    <script>
     
     if(is_ie){
       document.write('<script language="Javascript" src="/Agile/static/5978105420835c86b1371f73da1192e6/includes/scrollingTabs.js"><\/script>');
     }
     </script>
     
    <script language="JavaScript">
	  if(!opener) {
		top.frames.TopPane.clearMenus();
	  }

 			if (!is_mac) {
        this.window.name = "RightPane";
      }
      // Tabs Menu
      var arMenu1000 = new Array("","638","244","","","#FFFFFF","","","");
      var doOnloadActions;
      var doOnUnloadActions;
      var doOnKeyPress;
      var doTopPaneLoadActions;
      var wizardLoadLeftPane;
      var bShowRightClickMenu = true;
	  var hasRowErrors = false;
      var arTabText = new Array();
      var arTabAction = new Array();
                var ns_6 = (!document.layers) && (navigator.userAgent.indexOf('Netscape')!=-1)?true:false;
                var ie_5 = ((document.all)&&(navigator.appVersion.indexOf("MSIE 5.")!=-1)) ? true : false;
                if(ie_5) {
                    height = null;
                    width = null;
                }

      

	  function callRefreshRecentlyVisitIFrame()
	  {
		  if(top.frames.LeftPane.refreshRecentlyVisitIFrame)
		  {
			top.frames.LeftPane.refreshRecentlyVisitIFrame();
		  }
	  }

      function doRightPaneOnloadActions(){

			var isLeftPaneNavCalled = false;
			var refreshBookmarks = false;
            var refreshSearchFolders = false;

			

			
			 if (!isLeftPaneNavCalled) {
				isLeftPaneNavCalled = showLeftPaneContextualNavigation();
			 }

      
            if (document.MainForm.popup.value != "true")
               try{
                 if (parent.LeftPane.document.SearchFolderForm == null)         // detect if default left pane is already loaded
                   if ( wizardLoadLeftPane == null ) {                     // detect if in a wizard
                    
										 if (!isLeftPaneNavCalled) {
                     	parent.LeftPane.document.location = "PCMServlet?module=LeftPaneHandler&opcode=displayObject&drawer=search";
                     } // if
                   }
               } catch (err){
                  
               }
      
         
         initTableEvents();
         adjustPageTipWidths();
         
			 setTabLineWidthForSingleTableDisplay();
			 
       
       if(is_ie){
        adjustTabsWidth();//set the table width for the page tips to fit in the page
       }
         
         adjustSelectElementWidths();
         adjustDualSelectElementWidths();
         
      
        
      
        
      
        
    
         
            // -------------------------------------------------------------
            // if you don't want something to appear in popup, place it here
            // -------------------------------------------------------------
      // agile00127266
      if(!opener && top.frames.TopPane.isSearching)
        top.frames.TopPane.activateSimpleSearch();
         
         if (doOnloadActions != null){
	    //agile00200730
	    //To fix the javascrip error getting displayed because of refresh timing issue.
	     doOnloadActions();  // doOnloadActions() function may be placed on individual pages if page specific onload actions reqd.
         }
         if (wizardLoadLeftPane != null){
            wizardLoadLeftPane();  // wizardLoadLeftPane() function is inside WizardLayout. It loads the left pane wizard steps for some wizards.
         }
        // -------------------------------------------------------------
         //    Focus on first form field
         //agile00189231
        if (top.frames.RightPane && top.frames.RightPane.document.forms[0] && top.frames.RightPane.document.forms[0].displayMode)
	{
	   var displayMode = top.frames.RightPane.document.forms[0].displayMode.value;
	   if(displayMode != null &&  displayMode.length > 0 && displayMode != '0')
           {
        	 setFocusInFirstField(); // set the focus only for edit/create mode
           }
        }
        // -------------------------------------------------------------
         // Build the menu for right click on tabs scroll button
    arMenu1000.length = 9;
    for (var i = 0; i < arTabText.length; i++) {
       arMenu1000[arMenu1000.length] = arTabText[i];
       arMenu1000[arMenu1000.length] = arTabText[i];
       arMenu1000[arMenu1000.length] = arTabAction[i];
       arMenu1000[arMenu1000.length] = 0;
       arMenu1000[arMenu1000.length] = 0;
       arMenu1000[arMenu1000.length] = 0;
    }
     if (doTopPaneLoadActions != null){
		 if(top.frames.TopPane) {
			 doTopPaneLoadActions();
		 } else {
			 setTimeout("doTopPaneLoadActions()", 1250);
		 }
     }

     setPageViewContent();
	 setTableViewContent()
	 highlightFirstErrorRow();
	 resizeLastColumn();
	 

     
  } // fn();

	function showErrorWarningPopup() {
		openDialogWindowFrom2ndForm('MainForm',document.MainForm.module.value, 'showErrorAndWarningsInDelete', '_New', 410, 700, "true", "no");
	}

    function showPreAuditWarningPopup() {
        
            if (confirm("")) {
                submitForm('MainForm','ItemHandler','','RightPane', '');
            }
        
    }

    function highlightFirstErrorRow() {
	}

    function doResizeActions()

    {
      
        if(is_ie){
          adjustTabsWidth();
        }
      
	  resizeLastColumn();
      setPageViewContent();
      setTableViewContent()
    }
    window.onresize = doResizeActions;
    function doScrollingResizeActions()
    {
      
        if(is_ie){
          adjustTabsWidth();
        }
      
	  resizeLastColumn();
      setPageViewContent();
      doResize();
      setTableViewContent();
    }

    function showLeftPaneContextualNavigation() {
				var isLeftPaneRefreshCalled = false;
    		var isloadFromLeftPane = 'false';
        
           if (top.frames.LeftControllerPane) {
           	if (top.frames.LeftPane.ContextualNavigation != null &&
           		(top.frames.LeftPane.ContextualNavigation.classid.value != '18022' &&
           		top.frames.LeftPane.ContextualNavigation.classid.value != '18387')) {
            	top.frames.LeftControllerPane.removeDynamicTab();
            } // if
           } // if
        
            var previousMod = 'LeftPaneHandler';
            var currentMod = 'ItemHandler';
            if (previousMod == 'ActivityHandler' &&
                currentMod != 'ActivityHandler' &&
                wizardLoadLeftPane == null) {

              if (top.frames.LeftPane) {
              	//isLeftPaneRefreshCalled = true;
                //top.frames.LeftPane.refreshSearches();
              } // if

            } else if (previousMod == 'ActivityHandler' &&
                      currentMod == 'ActivityHandler') {

											if (top.frames.LeftPane && top.frames.LeftPane.openedDrawer && top.frames.LeftPane.openedDrawer != 'processFlow') {
												if (top.frames.LeftPane.loadContextNav && isloadFromLeftPane != 'false') {
													isLeftPaneRefreshCalled = true;
													top.frames.LeftPane.refreshProcessFlow();
												} // if
                      } else {
                      	if (document.MainForm.module.value == 'BOAttachmentWizardHandler') {
													if (top.frames.LeftPane) {
														isLeftPaneRefreshCalled = true;
														top.frames.LeftPane.refreshSearches();
													} // if
												} // if
                      } // else
            } else {
                if (previousMod != 'ActivityHandler' &&
                    currentMod == 'ActivityHandler' &&
                    wizardLoadLeftPane == null &&
                    (top.frames.LeftPane.openedDrawer != 'processFlow' ||
                    top.frames.LeftControllerPane.document.getElementById("processFlow").contextNavTitle == "Wizard")) {

										if (previousMod != 'LeftPaneHandler') {
											if (top.frames.LeftPane.loadContextNav && top.frames.LeftPane.document.ContextualNavigation) {
												if (top.frames.LeftPane.document.ContextualNavigation.classid.value != '18022') {
													if (!top.frames.LeftControllerPane.isDynamicTabEnabled()) {
														if (top.frames.LeftControllerPane.document.getElementById("processFlow").contextNavTitle != "Program") {
															//top.frames.LeftPane.refreshProcessFlow();
															isLeftPaneRefreshCalled = true;
															top.frames.LeftPane.showLeftNavTreePE('ActivityHandler', 'showLeftPaneNav', document.forms[0].classid.value, document.forms[0].objid.value, '', '');
														} // if
													} // if
												} else {
													//top.frames.LeftPane.refreshProcessFlow();
												} // else
											} else {
												
												parent.LeftPane.document.location = "PCMServlet?module=ActivityHandler&opcode=showLeftPaneNav&drawer=processFlow" + '&' + 'objid=' + document.forms[0].objid.value + '&classid=' + document.forms[0].classid.value;
												isLeftPaneRefreshCalled = true;
											} // else
										} else {
											if (!top.frames.LeftPane.loadContextNav) {
												top.frames.LeftPane.showLeftNavTreePE('ActivityHandler', 'showLeftPaneNav', document.forms[0].classid.value, document.forms[0].objid.value, '', '');
											} // if

										} // else

                } // if
            } // else
        

        
        return isLeftPaneRefreshCalled;
    }
    function showTreeViewInLeftPane(module,opcode)
    {

        var revChgId = '';
        var revChangeClsId = '';
        var siteId ='';

            if (document.MainForm.revchangeid)                          //added by phaneendhar
                revChgId = document.MainForm.revchangeid.value;

            if (document.MainForm.revchangeclass)                       //added by phaneendhar
                revChangeClsId = document.MainForm.revchangeclass.value;

            if (document.MainForm.siteId)                       //added by phaneendhar
                siteId = document.MainForm.siteId.value;

        

    top.frames.LeftControllerPane.openLeftPane()
        top.frames.LeftPane.refreshLeftPaneBOMView(module,opcode,'10000','433672420',revChgId,revChangeClsId,siteId);

    }

  function copyToClipBoard()
  {

    var module = '';
    var opcode = '';
    var classId ='';
    var objid ='';
    var tabid ='';

  if (document.MainForm.module)
      module = document.MainForm.module.value;

  if (document.MainForm.opcode)
      opcode = document.MainForm.opcode.value;

  if (document.MainForm.classid)
      classId = document.MainForm.classid.value;

  if (document.MainForm.objid)
      objid = document.MainForm.objid.value;

  if (document.MainForm.tabid)
      tabid = document.MainForm.tabid.value;

 var queryString = 'module='+module+'&opcode='+opcode+
        '&classid='+classId+'&objid='+
         objid+'&tabid='+
   tabid+'&';



  

  var url = 'http://plmprodap.advantech.corp/Agile/PCMServlet';
  queryString = '?fromPCClient=true&module='+module+'&requestUrl='+ escape(queryString);
  if(navigator.appName != 'Netscape'){
    var copyMessage ="The following URL has been copied to the clipboard.Use CTRL-V to paste.";
    copyToClipboard(url+queryString);
    alert(copyMessage+'\n\n'+url+queryString);
  }else{
        var formName = eval('document.MainForm');
        addlParam =  url+queryString;
        openDialogWindow('MainForm', 'CMBaseHandler', "copyToClipBoard", "popUpWindow", "200", "400", 'true', 'false', addlParam);
  }


  }
 </script>

<!-- Back Forward Navigation Scripts -->




<script>

function doTopPaneLoadActions()
{
	if(top.frames.TopPane)
	{
		
			top.frames.TopPane.toggleBackNavigation(true);
		

		
			top.frames.TopPane.toggleForwardNavigation(false);
		

		
			top.frames.TopPane.toggleRefreshAll(false);
		
	}
}

</script>
</head>

            <body onload="doRightPaneOnloadActions()" onunload="doRightPaneOnUnloadActions()" onkeypress="doRightPaneOnKeyPress(event)" marginwidth="0" marginheight="0">
        


<a name="toppage"></a>


<div id="rightScroll" style="width:14; height:18; position:absolute; visibility:hidden;">
<table cellpadding="0" cellspacing="0" border="0"><tbody><tr><td class="tabSelected">
<img src="/Agile/static/a91f00ca03609d7df62333d2fdd4821c/images/tabScrollButton_right.gif" alt="Scroll tabs" width="14" height="18" onmousedown="scrollButtonPressed('right')" onmouseup="hideShowScrollButtons()" onmouseout="hideTabsMenu()" oncontextmenu="return false">
</td></tr></tbody></table></div>
<div id="leftScroll" style="width:14; height:18; position:absolute; visibility:hidden;">
<table cellpadding="0" cellspacing="0" border="0"><tbody><tr><td class="tabSelected">
<img src="/Agile/static/436b8f506adeb58c22e4e1700422556a/images/tabScrollButton_left.gif" alt="Scroll tabs" width="14" height="18" onmousedown="scrollButtonPressed('left')" onmouseup="hideShowScrollButtons()" onmouseout="hideTabsMenu()" oncontextmenu="return false">
  </td></tr></tbody></table></div>
<script>isPageLoading=true;</script>
<form name="MainForm" method="POST" action="PCMServlet" enctype="application/x-www-form-urlencoded" onsubmit="return false;" target="RightPane">
<!-- Begin Form Standard Attributes -->
<input name="module" value="ItemHandler" type="HIDDEN" class="formElm" size="8" id="module">
<input name="opcode" value="displayObject" type="HIDDEN" class="formElm" size="8" id="opcode">
<input name="defaultAction" value="" type="HIDDEN" class="formElm" size="8" id="defaultAction">
<input name="addlParam" value="&amp;START&amp;tableDivHeight=414&amp;tableDivWidth=997&amp;END&amp;" type="HIDDEN" class="formElm" size="8" id="addlParam">
<input name="popup" value="" type="HIDDEN" class="formElm" size="8" id="popup">
<input name="objver" value="159" type="HIDDEN" class="formElm" size="8" id="objver">
<input name="objid" value="433672420" type="HIDDEN" class="formElm" size="8" id="objid">
<input name="classid" value="10000" type="HIDDEN" class="formElm" size="8" id="classid">
<input name="subclsid" value="27826" type="HIDDEN" class="formElm" size="8" id="subclsid">
<input name="tabid" value="11" type="HIDDEN" class="formElm" size="8" id="tabid">
<input name="viewid" value="0" type="HIDDEN" class="formElm" size="8" id="viewid">
<input name="displayMode" value="0" type="HIDDEN" class="formElm" size="8" id="displayMode">
<input name="refresh" value="false" type="HIDDEN" class="formElm" size="8" id="refresh">
<input name="pgWarnID" value="" type="HIDDEN" class="formElm" size="8" id="pgWarnID">
<input name="pgWarnCode" value="" type="HIDDEN" class="formElm" size="8" id="pgWarnCode">
<input name="warningString" value="" type="HIDDEN" class="formElm" size="8" id="warningString">
<input name="fullrev" value="" type="HIDDEN" class="formElm" size="8" id="fullrev">
<input name="process_actionId" value="" type="HIDDEN" class="formElm" size="8" id="process_actionId">
<input name="pageName" value="" type="HIDDEN" class="formElm" size="8" id="pageName">
<input name="formChanged" value="0" type="HIDDEN" class="formElm" size="8" id="formChanged">
<input name="currentToken" value="" type="HIDDEN" class="formElm" size="8" id="currentToken">
<input name="isTokenRequired" value="false" type="HIDDEN" class="formElm" size="8" id="isTokenRequired">
<input name="ContextName" value="19A1058701-01" type="HIDDEN" class="formElm" size="8" id="ContextName">
<input name="ContextType" value="19A NPb PCB/ENTEK" type="HIDDEN" class="formElm" size="8" id="ContextType">
<input name="helpID" value="1100" type="HIDDEN" class="formElm" size="8" id="helpID">
<input name="tableIds" value="5" type="HIDDEN" class="formElm" size="8" id="tableIds">
<input name="showTips" value="" type="HIDDEN" class="formElm" size="8" id="showTips">
<input name="refreshFromDB" value="" type="HIDDEN" class="formElm" size="8" id="refreshFromDB">
<input name="isPageDirty" value="" type="HIDDEN" class="formElm" size="8" id="isPageDirty">
<input name="iv" value="" type="HIDDEN" class="formElm" size="8" id="iv">
<!-- End Form Standard Attributes -->
<!-- Begin ModuleSpecific Form Attributes -->
<input name="cgToItemRevObjId" value="" type="HIDDEN" class="formElm" size="8" id="cgToItemRevObjId">
<input name="cgToItemRevClassId" value="" type="HIDDEN" class="formElm" size="8" id="cgToItemRevClassId">
<input name="cgToItemRevSiteId" value="" type="HIDDEN" class="formElm" size="8" id="cgToItemRevSiteId">
<input name="revchangeclass" value="6000" type="HIDDEN" class="formElm" size="8" id="revchangeclass">
<input name="revchangeid" value="447996547" type="HIDDEN" class="formElm" size="8" id="revchangeid">
<input name="siteId" value="-8" type="HIDDEN" class="formElm" size="8" id="siteId">
<input name="oldSiteId" value="-8" type="HIDDEN" class="formElm" size="8" id="oldSiteId">
<input name="siteOrRevChanged" value="" type="HIDDEN" class="formElm" size="8" id="siteOrRevChanged">
<input name="objectname" value="19A1058701-01" type="HIDDEN" class="formElm" size="8" id="objectname">
<input name="loadingMode" value="" type="HIDDEN" class="formElm" size="8" id="loadingMode">
<input name="expandLevel" value="" type="HIDDEN" class="formElm" size="8" id="expandLevel">
<input name="expandReferenceLevel" value="" type="HIDDEN" class="formElm" size="8" id="expandReferenceLevel">
<input name="rLeftPane" value="false" type="HIDDEN" class="formElm" size="8" id="rLeftPane">
<input name="objectname" value="19A1058701-01" type="HIDDEN" class="formElm" size="8" id="objectname">
<input name="sQueryId" value="false" type="HIDDEN" class="formElm" size="8" id="sQueryId">
<!-- End ModuleSpecific Form Attributes -->

<input type="hidden" name="skipKey" value="">
<input type="hidden" name="bookmarks_Refresh" value="false">

      



<table width="100%" cellpadding="0" cellspacing="0" border="0"><tbody><tr><td><span title="Search Results"><a href="javascript:submitURL('PCMServlet?module=SavedSearchExecutionHandler&amp;opcode=displayLastSearchResults')" class="breadCrumbLink">Search Results</a></span>&nbsp;<span class="funcLinks"><img src="/Agile/static/9c748be0d9fb9ae43c73376e9da6a95d/images/Arrow_breadcrumb2.gif" width="9" height="9" border="0"></span>&nbsp;<span class="objStyle" style="width:150px;overflow:hidden;text-overflow:ellipsis;" title="19A NPb PCB/ENTEK: 19A1058701-01"><nobr>19A NPb PCB/ENTEK: 19A1058701-01</nobr></span></td></tr></tbody></table>
<input name="trailPath" value="Search Results;10000:433672420" type="HIDDEN" class="formElm" size="8" id="trailPath">

    
      <table width="100%" cellspacing="0" cellpadding="0" border="0">
        
        <tbody><tr width="100%" row="1">
            <td nowrap="nowrap" valign="middle">
            






<script language="Javascript" src="/Agile/static/6fa072654177ab77f3d70dfdf630ea76/includes/PCFormsLib.js"></script>


<table border="0" cellspacing="0" cellpadding="0" width="100%">
<tbody><tr>

	<td width="25" valign="top" align="center">
		<table border="0" cellspacing="0" cellpadding="0">
		<tbody><tr><td>
		
			<img src="/Agile/static/3a1a68115a1583631d8dffe75d553539/images/PartGeneric.gif" border="0">
		
	</td></tr></tbody></table>
	</td>

<td valign="top">
	<table border="0" cellspacing="0" cellpadding="0" width="100%">
	<tbody><tr>
		
		<td nowrap="" class="titleObjectText">
			<div style="width:500px;overflow:hidden;text-overflow:ellipsis;" title="19A NPb PCB/ENTEK: 19A1058701-01">
			19A NPb PCB/ENTEK: 19A1058701-01</div>
		</td>
	</tr>

	<tr>
		<td class="titleObjectSmallText">
			<div style="width:500px;overflow:hidden;text-overflow:ellipsis;" title="PCB ASMB-587 A101-2 L:6 C:G 1.65MM FR4-TG150">
			PCB ASMB-587 A101-2 L:6 C:G 1.65MM FR4-TG150</div>
		</td>

	</tr>
	</tbody></table>

</td>
</tr>
</tbody></table>

<input name="helpId" value="https://supportstaging.agilesoft.com/help/en_us/top_help.htm" type="HIDDEN" class="formElm" size="8" id="helpId">
<input name="helpIndex" value="https://supportstaging.agilesoft.com/help/en_us/wcm/wwhelp.htm" type="HIDDEN" class="formElm" size="8" id="helpIndex">
<input name="helpOverview" value="https://supportstaging.agilesoft.com/help/en_us/top_help.htm" type="HIDDEN" class="formElm" size="8" id="helpOverview">




            </td>
            <td nowrap="nowrap" align="right">
            
            </td>
            <td nowrap="nowrap" align="right">
            




 



<!-- display indicator icons -->

    <script language="JavaScript">
        function showTab(str)
        {
            

            displayObject('','','',str)
        }
         function refreshPane()
         {
            refreshRightPane();
         }
    </script>
    
<!-- end display indicator icons -->
            
                




 






<div id="objStamp" style="top: 5px; left: 703px;">
<table border="0" cellpadding="0" cellspacing="0" align="right">
<tbody><tr>
	<td nowrap="nowrap">
	
	&nbsp;&nbsp;&nbsp;Unincorporated
	

	

	
	<img src="/Agile/static/95a4e53832525f0546d5d9a45d1f616a/images/BigStamp.gif" width="25" height="25" border="0" alt="Part Approve" align="bottom">
	&nbsp;<span class="stampText"><font color="Blue">Part Approve</font></span>
	
	</td>
</tr>
</tbody></table>
</div>

<script>
document.getElementById("objStamp").style.top = "5px";
</script>

            
            </td>
        </tr>
        </tbody></table>
    

    <table width="100%" cellspacing="0" cellpadding="0" border="0">
        
    <tbody><tr width="100%" row="3">
        <td colspan="2">
        
        
        </td>
        </tr>
      
      

    
    
       <tr width="100%" row="4">
            <td colspan="2">
            
            </td>
        </tr>
        <tr width="100%" height="25" valign="middle" row="5">
            <td nowrap="nowrap">
                <table border="0" cellpadding="0" cellspacing="0">
                <tbody><tr>
            
                <td nowrap="nowrap">
                












<script language="Javascript">
var revObjects = new Array ();
var index=0;

function RevObject (id, classId) {	
	this.id = id;
	this.classId = classId;
}

function SetRevObject (id, classId) {
	revObjects[index++] = new RevObject (id, classId);
}

var afterChangeSite = false ;

function changeRevs() 
{
	

	var mainfrm = getForm('MainForm');
	var revSelect = mainfrm.revSelectName;
	
	var siteSelect = mainfrm.siteSelectName;
	
	var selectRevId;
	var selectRevClassId;
	if (revSelect.length == 0) {
		selectRevId = 0;
		selectRevClassId = 931;

	} else {
		selectRevId = revSelect.options[revSelect.selectedIndex].value;
		for (j=0; j < revObjects.length; j++)
		{		
			if (revObjects[j].id == selectRevId)
				selectRevClassId = revObjects[j].classId;
		}
	}
	mainfrm.revchangeid.value = selectRevId;
	mainfrm.siteOrRevChanged.value = "true";
	mainfrm.revchangeclass.value = selectRevClassId;
	
	mainfrm.siteId.value = siteSelect.options[siteSelect.selectedIndex].value;	
	

	submitForm('',"ItemHandler","displayObject","RightPane");
}

function changeSite() 
{
	
	
	afterChangeSite = true ;
	
	var mainfrm = getForm('MainForm');
	var revSelect = mainfrm.revSelectName;
	var siteSelect = mainfrm.siteSelectName;	
	//var selectSiteId = siteSelect.options[siteSelect.selectedIndex].value;
	//if (selectSiteId == -8) {
	//	mainfrm.revchangeid.value = -2;
	//	mainfrm.revchangeclass.value = 931;
	//	mainfrm.siteId.value = -8;
	//	mainfrm.siteOrRevChanged.value = "true";
	//	submitForm(this,"ItemHandler","displayObject","RightPane");
	//} else {
		changeRevs();
	//}
}

function preDisplayObject(frm, module, classid, objid, tabid, target, viewid, xtraArgs) {
	var currentObjId = frm.objid.value;
	var currentClassId = frm.classid.value;
	var expandAll = frm.expandLevel;

	var revClassID = frm.revchangeclass;
	var revObjectID = frm.revchangeid;
	
		var siteID = frm.siteId;
		var oldSiteID = frm.oldSiteId;
	

	if (currentClassId != classid || currentObjId != objid ) {
		revClassID.value = "";
		revObjectID.value = "";
		if(expandAll)
			expandAll.value = "";
		
			siteID.value = "";
			oldSiteID.value = "";
		
	}
}


				SetRevObject( 447996547,6000 );
		
				SetRevObject( 443749976,6000 );
		
				SetRevObject( 443702683,6000 );
		
				SetRevObject( 433671091,6000 );
		
				SetRevObject( 0,931 );
		

function addPriceToChange() {
	openDialogWindow('MainForm','AddPriceToChangeWizardHandler', 'goToStep', '_New', 600, 900, 'true', 'yes'); 
}
function setFocusInFirstField(){ 
	//do nothing.Vara : Bug Fix: agile00118485
}






</script>


Site:

<select name="siteSelectName" disabled="" class="formElm" onchange="changeSite()" size="1" id="siteSelectName"><option value="-8" selected="" style="background-color:">ALL</option></select>


Rev:

<select name="revSelectName" class="formElm" onchange="changeRevs()" size="1" id="revSelectName"><option value="447996547" selected="">03        EE-214788</option><option value="443749976">02        EE-213221</option><option value="443702683">01        EE-213202</option><option value="433671091">00        PNR-405823</option><option value="0">Introductory</option></select>

&nbsp;
                </td>
            
            <td nowrap="nowrap">
            
            





<script>
function showPopupMenuInFrame(menuNum, evnt, x, y) {
	if ( top.frames.RightPane.document.getElementById("elMenu" + menuNum) )
		isNew = false ;
	else
		isNew = true ;

	top.frames.TopPane.popUpXFrame (menuNum, evnt, x, y+20, isNew, "top.frames.RightPane", "top.frames.RightPane");
}

</script>



<div id="gActions">

	<table cellpadding="0" cellspacing="0" border="0">
		<tbody><tr valign="bottom" nowrap="" align="left" class="dataDisplayEdit">
			
			<td align="left" valign="bottom">
				<script>

</script>
<table border="0" cellspacing="1" cellpadding="0"><tbody><tr><td nowrap="nowrap" class="iconButtonDisabledWithBorder">&nbsp;&nbsp;<img width="16" height="16" title="Show BOM Tree in Navigation Pane" border="0" src="/Agile/static/55530b5320888b21f161bd809bc999cb/images/showNavTree.gif" alt="Show BOM Tree in Navigation Pane">&nbsp;Show BOM Tree&nbsp;</td><td>&nbsp;&nbsp;</td></tr></tbody></table>

			</td>
 			<td align="left" valign="bottom">
				<script>

var arMenu2000
=new Array("", "", "", "", "", "#FFFFFF", "", "", "",
"Bookmark", "", "javascript:addBookMarks()", 0, 0, 0,
"Subscribe...", "", "javascript:submitForm('','ItemHandler','showSubscription','', '');", 0, 0, 1,
"Save As...", "", "javascript:submitForm('','SaveAsHandler','saveAs','RightPane', '');", 0, 0, 0,
"Delete", "", "javascript:submitForm('','ItemHandler','deleteObject','RightPane', '');", 0, 1, 1,
"Copy URL to Clipboard", "", "javascript:copyToClipBoard()", 0, 0, 0,
"Export...", "", "javascript:submitForm('','ItemHandler','export','RightPane', '');", 0, 0, 0,
"Print...", "", "javascript:submitForm('','ItemHandler','showPrintOptions','RightPane', '');", 0, 0, 0,
"Send...", "", "javascript:submitForm('','ItemHandler','showSendObjectPage','RightPane', '');", 0, 0, 0,
"Sharing...", "", "javascript:submitForm('','ItemHandler','share','RightPane', '');", 0, 1, 1,
"Incorporate", "", "javascript:submitForm('','ItemHandler','incorporateObject','RightPane', '');", 0, 1, 0,
"Unincorporate", "", "javascript:submitForm('','ItemHandler','unincorporateObject','RightPane', '');", 0, 1, 1,
"Create Change...", "", "javascript:displayCreateNewObjectPopupFromObject('CreateChangeWizardHandler', 'ItemHandler', 'createChange', '6')", 0, 0, 0,
"Create Product Service Request...", "", "javascript:displayCreateNewObjectPopupFromObject('CreatePSRWizardHandler', 'ItemHandler', 'createPSR', '27')", 0, 0, 0,
"Create Quality Change Requests", "", "javascript:displayCreateNewObjectPopupFromObject('CreateQCRWizardHandler', 'ItemHandler', 'createQCR', '28')", 0, 1, 0,
"Create Declaration...", "", "javascript:displayCreateNewObjectPopupFromObject('CreateMaterialDeclarationWizardHandler', 'ItemHandler', 'createMDO', '41')", 0, 1, 1,
"Insert Part Number & EOL", "", "javascript:invokeProcessAction('188803')", 0, 0, 0,
"MTBF Report", "", "javascript:invokeProcessAction('123384')", 0, 0, 0);
</script>
<table border="0" cellspacing="1" cellpadding="0">
<tbody><tr>
<td nowrap="nowrap" class="iconButtonOffWithBorder" onmousedown="this.className='iconButtonOver'" onmouseup="this.className='iconButtonOver'" onmouseover="showPopupMenuInFrame('2000',event,getPos(this).x,getPos(this).y);this.className='iconButtonOver'" onmouseout="opener ? opener.top.frames.TopPane.popDown('2000') : top.frames.TopPane.popDown('2000');this.className='iconButtonOffWithBorder';" valign="top">&nbsp;<img src="/Agile/static/a7b0b983243512d0201c46ff50f651c9/images/dot.gif" height="16" width="1" border="0" alt="">&nbsp;Actions&nbsp;<img src="/Agile/static/187cbc6abc4e4dd88f27e6b49eb730ee/images/arrow_menuDown.gif" width="11" height="11" border="0" alt=""></td>
</tr>
</tbody></table>

			</td>
		</tr>
	</tbody></table>
	

</div>

            
            </td>
            </tr>
            </tbody></table>
        </td>
        </tr>
        
        <tr height="5">
            <td></td>
        </tr>
         
	
		</tbody></table>
		






	<script>
		var filterTopAlign = 0;
		var filterLeftAlign = 0;
	</script>
		
	


<script>
function showPopupMenuInFrame(menuNum, evnt, x, y) {
	if ( top.frames.RightPane.document.getElementById("elMenu" + menuNum) )
		isNew = false ;
	else
		isNew = true ;

	if (DOM)
		top.frames.TopPane.popUpXFrame (menuNum, evnt, x, y+20, isNew, "top.frames.RightPane", "top.frames.RightPane");
}

</script>




 




	

	<table width="100%" cellpadding="0" cellspacing="0">
	<tbody><tr>
		<!-- tabs -->
		<td valign="bottom">
			<table border="0" cellspacing="0" cellpadding="0" width="100%"><tbody><tr><td width="800">
<script> if(is_ie){ 
document.write('<div id="tabsDiv" style="border:0; overflow-x : hidden; width:800">'); 
 } </script>
<table id="tabsTable" border="0" cellpadding="0" cellspacing="0">
<tbody><tr>

<td nowrap="true" valign="middle" width="8" align="right" class="tabUnselected"><img width="8" height="17" border="0" src="/Agile/static/2d97c1a117d810f61908711a820988c8/images/transtableft.gif"></td>
<td nowrap="true" valign="middle" align="center" class="tabUnselected">
<a href="javascript:displayObject('ItemHandler', '10000', '433672420', '0','', '0');" class="tabUnselectedText">Title Block</a>
<script>arTabText[arTabText.length] = "Title Block";
arTabAction[arTabAction.length] = "javascript:top.frames.RightPane.displayObject('ItemHandler', '10000', '433672420', '0','', '0');";</script>

</td>


<td nowrap="true" valign="middle" width="11" class="tabUnselected"><img width="11" height="17" border="0" src="/Agile/static/f59af2b18f57d698549bfc03a160b76f/images/transtabright.gif"></td>


<td nowrap="true" valign="middle" width="8" align="right" class="tabUnselected"><img width="8" height="17" border="0" src="/Agile/static/2d97c1a117d810f61908711a820988c8/images/transtableft.gif"></td>
<td nowrap="true" valign="middle" align="center" class="tabUnselected">
<a href="javascript:displayObject('ItemHandler', '10000', '433672420', '2','', '0');" class="tabUnselectedText">Changes</a>
<script>arTabText[arTabText.length] = "Changes";
arTabAction[arTabAction.length] = "javascript:top.frames.RightPane.displayObject('ItemHandler', '10000', '433672420', '2','', '0');";</script>

</td>


<td nowrap="true" valign="middle" width="11" class="tabUnselected"><img width="11" height="17" border="0" src="/Agile/static/f59af2b18f57d698549bfc03a160b76f/images/transtabright.gif"></td>


<td nowrap="true" valign="middle" width="8" align="right" class="tabUnselected"><img width="8" height="17" border="0" src="/Agile/static/2d97c1a117d810f61908711a820988c8/images/transtableft.gif"></td>
<td nowrap="true" valign="middle" align="center" class="tabUnselected">
<a href="javascript:displayObject('ItemHandler', '10000', '433672420', '3','', '0');" class="tabUnselectedText">BOM</a>
<script>arTabText[arTabText.length] = "BOM";
arTabAction[arTabAction.length] = "javascript:top.frames.RightPane.displayObject('ItemHandler', '10000', '433672420', '3','', '0');";</script>

</td>


<td nowrap="true" valign="middle" width="11" class="tabUnselected"><img width="11" height="17" border="0" src="/Agile/static/f59af2b18f57d698549bfc03a160b76f/images/transtabright.gif"></td>


<td nowrap="true" valign="middle" width="8" align="right" class="tabUnselected"><img width="8" height="17" border="0" src="/Agile/static/2d97c1a117d810f61908711a820988c8/images/transtableft.gif"></td>
<td nowrap="true" valign="middle" align="center" class="tabUnselected">
<img align="absmiddle" class="tabImage" border="0" src="/Agile/static/447cf7c9abf08d2e09994d138ad4a345/images/Manufacturer.gif"><a href="javascript:displayObject('ItemHandler', '10000', '433672420', '4','', '0');" class="tabUnselectedText">Manufacturer</a>
<script>arTabText[arTabText.length] = "Manufacturer";
arTabAction[arTabAction.length] = "javascript:top.frames.RightPane.displayObject('ItemHandler', '10000', '433672420', '4','', '0');";</script>

</td>


<td nowrap="true" valign="middle" width="11" class="tabUnselected"><img width="11" height="17" border="0" src="/Agile/static/f59af2b18f57d698549bfc03a160b76f/images/transtabright.gif"></td>


<td nowrap="true" valign="middle" width="8" align="right" class="tabUnselected"><img width="8" height="17" border="0" src="/Agile/static/2d97c1a117d810f61908711a820988c8/images/transtableft.gif"></td>
<td nowrap="true" valign="middle" align="center" class="tabUnselected">
<a href="javascript:displayObject('ItemHandler', '10000', '433672420', '7','', '0');" class="tabUnselectedText">Quality</a>
<script>arTabText[arTabText.length] = "Quality";
arTabAction[arTabAction.length] = "javascript:top.frames.RightPane.displayObject('ItemHandler', '10000', '433672420', '7','', '0');";</script>

</td>


<td nowrap="true" valign="middle" width="11" class="tabUnselected"><img width="11" height="17" border="0" src="/Agile/static/f59af2b18f57d698549bfc03a160b76f/images/transtabright.gif"></td>


<td nowrap="true" valign="middle" width="8" align="right" class="tabUnselected"><img width="8" height="17" border="0" src="/Agile/static/2d97c1a117d810f61908711a820988c8/images/transtableft.gif"></td>
<td nowrap="true" valign="middle" align="center" class="tabUnselected">
<a href="javascript:displayObject('ItemHandler', '10000', '433672420', '10','', '0');" class="tabUnselectedText">Where Used</a>
<script>arTabText[arTabText.length] = "Where Used";
arTabAction[arTabAction.length] = "javascript:top.frames.RightPane.displayObject('ItemHandler', '10000', '433672420', '10','', '0');";</script>

</td>


<td nowrap="true" valign="middle" width="11" class="tabUnselected"><img width="11" height="17" border="0" src="/Agile/static/f59af2b18f57d698549bfc03a160b76f/images/transtabright.gif"></td>


<td nowrap="true" valign="middle" width="8" align="right" class="tabSelected"><img width="8" height="17" border="0" src="/Agile/static/2d97c1a117d810f61908711a820988c8/images/transtableft.gif"></td>
<td nowrap="true" valign="middle" align="center" class="tabSelected">
<img align="absmiddle" class="tabImage" border="0" src="/Agile/static/ce0b9660b769b9408ec1eedc2770a311/images/AttachmentTabIcon.gif"><a href="javascript:displayObject('ItemHandler', '10000', '433672420', '11','', '0');" class="tabText">Attachments</a>
<script>arTabText[arTabText.length] = "Attachments";
arTabAction[arTabAction.length] = "javascript:top.frames.RightPane.displayObject('ItemHandler', '10000', '433672420', '11','', '0');";</script>

</td>


<td nowrap="true" valign="middle" width="11" class="tabSelected"><img width="11" height="17" border="0" src="/Agile/static/f59af2b18f57d698549bfc03a160b76f/images/transtabright.gif"></td>


<td nowrap="true" valign="middle" width="8" align="right" class="tabUnselected"><img width="8" height="17" border="0" src="/Agile/static/2d97c1a117d810f61908711a820988c8/images/transtableft.gif"></td>
<td nowrap="true" valign="middle" align="center" class="tabUnselected">
<a href="javascript:displayObject('ItemHandler', '10000', '433672420', '12','', '0');" class="tabUnselectedText">History</a>
<script>arTabText[arTabText.length] = "History";
arTabAction[arTabAction.length] = "javascript:top.frames.RightPane.displayObject('ItemHandler', '10000', '433672420', '12','', '0');";</script>

</td>


<td nowrap="true" valign="middle" width="11" class="tabUnselected"><img width="11" height="17" border="0" src="/Agile/static/f59af2b18f57d698549bfc03a160b76f/images/transtabright.gif"></td>

</tr>
</tbody></table>
<script> if(is_ie){ 
document.write('</div>'); 
 } </script> 
</td>
</tr></tbody></table>

		</td>
		<!-- end tabs -->

		<td width="90%">&nbsp;</td>


	</tr>
	</tbody></table>

	<table cellspacing="0" cellpadding="0" border="0" width="100%" id="tabLine" style="width: 2309px;">
	<tbody><tr>
		<td class="tabLine"><img src="/Agile/static/a7b0b983243512d0201c46ff50f651c9/images/dot.gif" width="100%" height="5" border="0" alt=""></td>
	</tr>
	</tbody></table>

	
	<div id="divContents" class="divContents" style="width: 2309px;">
	
            	<!--region:render section="tabTips" /-->
				<!-- This div is used in Attachments.inc to set the error message on the parent, DONOT remove this DIV-->
				<div id="errorDiv" style="display:none" width="100%">
				</div>
				










					<table cellpadding="4" cellspacing="0" border="0" width="100%" id="contentIndentTable">
					<tbody><tr>
						<td nowrap="nowrap">
      					
      					











						
      					
						
						</td>
					</tr>

					<tr>
						<td nowrap="nowrap">
				  			 <table border="0" cellpadding="0" cellspacing="0"><tbody><tr>            
								<td nowrap="nowrap">
									







	<table cellpadding="0" cellspacing="0" border="0" width="100%">
		<tbody><tr>
			<td nowrap="">
				
			</td>

			
		</tr>
	</tbody></table>


								</td></tr></tbody></table>
				  			
					  		<table cellpadding="0" cellspacing="0" border="0" width="100%">
							<tbody><tr><td>
								<div id="pageViewContent" name="pageViewContent" style="position: relative; width: 1039px;">
								<table cellpadding="0" cellspacing="0" border="0" width="100%">
								<tbody><tr>
								<td nowrap="nowrap" width="100%">
								
								</td>
								<td align="right" width="100%">&nbsp;
								
								
								







						
		
			
		
		
		
		




								
								
								</td>
								</tr>
								<tr>
								<td nowrap="nowrap" valign="bottom" align="right">
									
								</td>
								</tr></tbody></table></div>
							</td></tr>
							</tbody></table>
							
						</td>
					</tr>
					</tbody></table>
	
	









<!-- BEGIN ITEM ATTACHMENTS CONTENT -->
<script language="Javascript" src="/Agile/static/fce49c43e2cf4e28a176fbb92fa228bc/includes/AttachmentLib.js"></script>

<script language="Javascript">

function importFiles(handlerName) {
    var msg;
    var tableId = document.MainForm.registeredTables.value;
    var nSelected = parseInt( eval("document.forms[0].selectedItems_" + tableId + ".value") ) ;

    if ( nSelected == 0 ) {
        alert("An attachment must be selected before this operation can be performed. Please check the box next to the file you would like to import.")
        return ;
    }

    if ( nSelected > 1 ) {
        alert("You can import only one file at a time. Please select only one attachment below.")
        return ;
    }

    msg = "You are about to import the selected file. Click OK to import.";
    if(confirm(msg)) {
        setCursorToHourglass = false;
        submitForm('MainForm', handlerName, 'importAttachments', '_self', '');
        setCursorToHourglass = true;
    }
}


function showAttachmentVersions(classId, objId, rowId, version) {
   var addlParam = "versionControlItemClassId=" + classId
                   + "&versionControlItemObjId=" + objId
                   + "&versionControlItemRowId=" + rowId
                   + "&version=" + version;
   openDialogWindow('MainForm', '', 'showAttachmentVersions', '_New', '450', '700', 'true', 'no', addlParam);
}


function showFileOpModesDialog(requestFrom, addlParam, fName) {
   addlParam = addlParam + "&REQUEST_FROM=" + requestFrom;
   addlParam = addlParam.replace('/=\\/g', '=');
   addlParam = addlParam.replace('/[\\$|\\&]/g', '');
   if(fName != null)
	addlParam = addlParam + "&fileName=" + encodeToHex(fName);
   openDialogWindow('MainForm', '', 'showFileOpModesDialog', 'FileOpMode', '450', '700', 'true', 'no', addlParam);
}


function viewAction(action) {
   var checkCount = findCheckCount();
   var isViewAction = false;

   if (action.substr(0, 7) == 'advance') {
      if (checkCount < 1) {
         alert("Please select at least one item for this operation.");
         return;
      }
   }
   else if (action == "batchPrint") {
      if (checkCount < 1) {
         alert("Please select at least one item for this operation.");
         return;
      }
   }
   else if (action == "viewMultipleFiles") {
      isViewAction = true;
      if (checkCount < 1) {
         alert("Please select at least one item for this operation.");
         return;
      }
   }
   else if (action == "compareFiles") {
      if (checkCount < 1) {
         alert("Please select at least one item for this operation.");
         return;
      }
   }
   else if (action == "overlayFiles") {
      if (checkCount < 1) {
         alert("Please select at least one item for this operation.");
         return;
      }
   }
   else if (action == "crossProbeFiles") {
      if (checkCount < 1) {
         alert("Please select at least one item for this operation.");
         return;
      }
   }
   else if (action == "mockupFiles") {
      if (checkCount < 1) {
         alert("Please select at least one item for this operation.");
         return;
      }
   }
   // agile00188727 fix - resetting the flag to false so that refresh can happen only for view action
   if(isViewAction) {
      //document.forms[0].viewerUnloaded.value=true;
   }

   document.forms[0].tableId.value = document.forms[0].registeredTables.value;
   document.forms[0].jvueAction.value = action;
   document.forms[0].fromPCViewer.value = false;
   openDialogWindow('MainForm', '', 'jvueAttachment', 'viewerlauncher', 600, 700, 'true')
}


function addFilePopUp(id, parentid)
{
   handleCookie(id, parentid);
   openDialogWindow('MainForm', '', 'addFileAttachments', 'popupWindow', 450, 700, 'true', 'no', 'QUICKADD=true');
}


function addURLPopUp(id, parentid)
{
   handleCookie(id, parentid);
   openDialogWindow('MainForm', '', 'addURLAttachments', 'popupWindow', 450, 700, 'true', 'no', 'QUICKADD=true');
}

function confirmBeforeRemove(module, opcode, target, tableId) {
	if(confirm(localMsg.remove_attachments)) {
		submitForm('', module, opcode, target);
	}
}



function addAttachmentPopUp()
{
   openDialogWindow('MainForm', 'AddAttachmentWizardHandler', 'goToStep', 'agileviewer', 600, 900, 'true');
}

function encodeToHex(str) {
   var encodedStr = "";
   for (var i=0; i < str.length; i++) {
       if (str.charAt(i) == '&') {
           encodedStr += "\\x26";
       }
       else if (str.charAt(i) == '=') {
           encodedStr += "\\x3D";
       }
       else {
           encodedStr += str.charAt(i);
       }
   }

   return encodedStr;
}


function openAttachments(formName, rowId, version, tableId, userSelectedMode) {
    var frm = getForm(formName);
    var addlParams = "currentrowid=" + rowId
                   + "&version=" + version
                   + "&tableId=" + tableId
                   + "&USER_SELECTED_FILEOPMODE="+ userSelectedMode;
    openDialogWindow('MainForm', frm.module.value, 'openAttachments', 'viewerlauncher', 100, 400, 'true', 'no', addlParams);
}


function getBOAttachment(formName, rowId, version, fileId, fileSize, fileName, attachmentId, attachmentNum, userSelectedMode) {
    var frm = getForm(formName);
    
    if (fileId==0) {
        frm.version.value = version;
        frm.versionControlItemRowId.value = rowId;
        frm.versionControlItemClassId.value = 6159;
        frm.versionControlItemObjId.value = attachmentId;
        frm.attachmentNumber.value = attachmentNum;
        frm.checkincheckoutoperate.value="out";
        addlParams = "USER_SELECTED_FILEOPMODE="+ userSelectedMode
                   + "&REQUEST_FROM=FROM_GETBOFILES";
        saveForm(frm);
        refreshTables(true);
        openDialogWindow('MainForm', 'BOAttachmentWizardHandler', 'goToStep', '_New', 500, 800, 'true', 'no', addlParams);
        resetForm(frm);
    } else {
        frm.versionControlItemRowId.value = rowId;
        frm.versionControlItemClassId.value = 6159;
        frm.versionControlItemObjId.value = attachmentId;
        frm.attachmentNumber.value = attachmentNum;
        addlParams = "rowId=" + rowId + "&versionId=" + version + "&fileId=" + fileId
                   + "&fileSize=" + fileSize + "&fileName=" + encodeToHex(fileName)
                   + "&attachmentId=" + attachmentId
                   + "&USER_SELECTED_FILEOPMODE=" + userSelectedMode
                   + "&REQUEST_FROM=FROM_GETBOFILES";
        saveForm(frm);
        submitForm('MainForm', frm.module.value, 'showGetBOAttachmentPopup', 'AttachmentFrame', addlParams);
        resetForm(frm);
    }
}


function checkoutAttachment(formName, attachmentClsId, attachmentId, rowId, attachmentNum, version, fileId, fileSize, fileName, userSelectedMode) {
    var frm = getForm(formName);
    if (userSelectedMode == 1) {
        var needGetFile = 'true';
        frm.needGetFile.value = needGetFile;
        frm.checkoutFolderVersion.value = version;
        frm.checkoutFolderFileID.value = fileId;
        frm.checkoutFolderFileSize.value = fileSize;
        frm.checkoutFolderfileName.value = fileName;
        frm.checkincheckoutoperate.value = 'out';
        doVersionControl(formName, 'out', attachmentId, attachmentClsId, rowId, attachmentNum);
    } else {
        if (fileId==0) {
            frm.versionControlItemClassId.value = attachmentClsId;
            frm.versionControlItemObjId.value = attachmentId;
            frm.versionControlItemRowId.value = rowId;
            frm.attachmentNumber.value = attachmentNum;
            frm.checkincheckoutoperate.value="out";
            addlParams = "USER_SELECTED_FILEOPMODE=" + userSelectedMode
                       + "&REQUEST_FROM=FROM_CHECKOUT_BO";
            openDialogWindow('MainForm', 'BOAttachmentWizardHandler', 'goToStep', '_New', 500, 800, 'true', 'no', addlParams);
        } else {
            addlParams = "rowId=" + rowId + "&versionId=" + version + "&fileId=" + fileId
                       + "&fileSize=" + fileSize + "&fileName=" + encodeToHex(fileName)
                       + "&attachmentId=" + attachmentId
                       + "&USER_SELECTED_FILEOPMODE=" + userSelectedMode
                       + "&REQUEST_FROM=FROM_CHECKOUT_BO";
            submitForm('MainForm', frm.module.value, 'showGetBOAttachmentPopup', 'AttachmentFrame', addlParams);
        }
    }
}


function checkinAttachment(formName, attachmentClsId, attachmentId, rowId, attachmentNum, version, tableId, fileId, fileName, asLatest, asAllFiles, requestFrom, userSelectedMode) {
    var frm = getForm(formName);
    if (userSelectedMode == 1) {
        if (requestFrom == 'FROM_CHECKIN_BO') {
            frm.checkinFolderVersion.value = version;
            frm.checkinFolderTableID.value = tableId;
            frm.checkincheckoutoperate.value = 'in';
            doVersionControl(formName, 'in', attachmentId, attachmentClsId, rowId, attachmentNum);
        } else {
            openDialogWindow('', 'AttachmentHandler', 'replaceFileAttachment', '_New', 250, 420, 'true','false','replaceRowId='+rowId + '&tableID='+tableId + '&checkoutFolderFileID='+fileId + '&fromAllFile='+asAllFiles +'&fileName='+encodeToHex(fileName));
        }
    } else {
        frm.versionControlItemClassId.value = attachmentClsId;
        frm.versionControlItemObjId.value = attachmentId;
        frm.versionControlItemRowId.value = rowId;
        frm.tableId.value = tableId;
        addlParams = "fileId=" + fileId + "&asLatest=" + asLatest + "&asAllFiles=" + asAllFiles
                   + "&USER_SELECTED_FILEOPMODE=" + userSelectedMode
                   + "&REQUEST_FROM=FROM_CHECKIN_BO";
        submitForm('MainForm', frm.module.value, 'showAdvancedCheckIn', 'AttachmentFrame', addlParams);
    }
}


function cancleCheckoutAttachment(formName, objId, classId, rowId, attachmentNum) {
    var msg = "Are you sure you want to cancel the checkout?";
    if (confirm(msg)) {
        doVersionControl(formName, 'cancelOut', objId, classId, rowId, attachmentNum)
    }
}


ATT_FILEFILENAME_ID = "1046";
ATTACHMENT_ALL_FILES_ID = "0";
ATTACHMENT_ALL_FILES_LABEL = "[All Files]";
ATTACHMENT_LATEST_VSN_ID = '9999';
ATT_FILEVERSION_ID = '3622';
TABLE_ROW_INFO_ID = '1234567';

function writeTableInfo(formName, opcode)
{
   enableSelBox();
   var frm = getForm(formName);
   if(frm.registeredTables != null )
   {
      var registeredTables = frm.registeredTables.value;
      if(registeredTables != null && registeredTables.length > 0)
      {
         var tableIds = registeredTables.split(",");
         var i = 0;
         for(i=0; i<tableIds.length; i++)
         {
            if(shouldPersistSelections(formName, tableIds[i]))
            {
               autoSelectSingleRow(formName, tableIds[i], opcode);
               setTableInfo(formName, tableIds[i]);
            } // if
         } // for
      } // if
   } // if
} // fn
function enableSelBox()
{
   var selList = document.MainForm.elements;
   for(var i=0;i<selList.length;i++)
   {
      var selBox = selList[i];
      var selname = selBox.name;
      var ind_1 = selname.indexOf('_');
      var ind_2 = selname.lastIndexOf('_');
      var attid = selname.substring(ind_1+1, ind_2);
      if(attid=='1046')
      {
         selBox.disabled = false;
      }
   }
}

</script>



<iframe src="dummy.html" name="AttachmentFrame" id="AttachmentFrame" width="20" height="0" frameborder="false"></iframe>

<table width="100%" cellpadding="0" cellspacing="0" border="0">
<tbody><tr>
    <td>
        <input name="Selections_5" value="" type="HIDDEN" class="formElm" size="8" id="Selections_5"><input name="multipleSelect_5" value="true" type="HIDDEN" class="formElm" size="8" id="multipleSelect_5"><input name="isSelectable_5" value="true" type="HIDDEN" class="formElm" size="8" id="isSelectable_5"><input name="TableDirtyRows_5" value="" type="HIDDEN" class="formElm" size="8" id="TableDirtyRows_5"><input name="TableRowMap_5" value="" type="HIDDEN" class="formElm" size="8" id="TableRowMap_5"><input name="TableTreeRows_5" value="" type="HIDDEN" class="formElm" size="8" id="TableTreeRows_5"><input name="ExpandedRow_5" value="-1" type="HIDDEN" class="formElm" size="8" id="ExpandedRow_5"><input name="persistSelections_5" value="true" type="HIDDEN" class="formElm" size="8" id="persistSelections_5"><input name="sortCriteria_5" value="" type="HIDDEN" class="formElm" size="8" id="sortCriteria_5"><input name="displayModeForTable_5" value="0" type="HIDDEN" class="formElm" size="8" id="displayModeForTable_5"><input name="TableRowWarnings_5" value="" type="HIDDEN" class="formElm" size="8" id="TableRowWarnings_5"><!-- BEGIN PAGINATION  --><input name="rowsPerPage_5" value="" type="HIDDEN" class="formElm" size="8" id="rowsPerPage_5"><input name="currentPage_5" value="1" type="HIDDEN" class="formElm" size="8" id="currentPage_5"><input name="totalItems_5" value="11" type="HIDDEN" class="formElm" size="8" id="totalItems_5"><input name="lastPageNumber_5" value="1" type="HIDDEN" class="formElm" size="8" id="lastPageNumber_5"><input name="itemsOnPage_5" value="11" type="HIDDEN" class="formElm" size="8" id="itemsOnPage_5"><input name="itemsPerPage_5" value="250" type="HIDDEN" class="formElm" size="8" id="itemsPerPage_5"><input name="selectedItems_5" value="0" type="HIDDEN" class="formElm" size="8" id="selectedItems_5"><input name="globalValue_5" value="false" type="HIDDEN" class="formElm" size="8" id="globalValue_5"><input name="globalSelectChanged_5" value="false" type="HIDDEN" class="formElm" size="8" id="globalSelectChanged_5">












<script language="JavaScript" src="/Agile/static/f95fdd7c2a966750c44ccd47484d0c89/includes/jsMessages.js"></script>

<div id="pageViewContent" name="pageViewContent" style="position: relative; width: 1039px;">
<table class="pagination" border="0" height="15" cellpadding="0" cellspacing="0" width="100%">
<tbody><tr valign="middle" height="20">
   
    

	<td valign="middle" align="left" width="75%" nowrap="nowrap" class="pagination">
		<table cellpadding="0" cellspacing="0" border="0">
		<tbody><tr>
			<td>

					<script>



var arMenu1004
=new Array("", "", "", "", "", "#FFFFFF", "", "", "",
"<checkImg N><ImgSrc /Agile/static/1477b14caba6254640e8c475d7041867/images/addfile.gif>Files...", "", "javascript:addFilePopUp(20092, 20057);swapParentAction('sTD_1004','sIMG_1004','javascript:addFilePopUp(20092, 20057)','/Agile/static/1477b14caba6254640e8c475d7041867/images/addfile.gif');", 0, 0, 0,
"<checkImg N><ImgSrc /Agile/static/b16d6675af2cbeabd203d7cfca40a2f5/images/addurl.gif>URLs...", "", "javascript:addURLPopUp(20093, 20057);swapParentAction('sTD_1004','sIMG_1004','javascript:addURLPopUp(20093, 20057)','/Agile/static/b16d6675af2cbeabd203d7cfca40a2f5/images/addurl.gif');", 0, 1, 0,
"<checkImg N><ImgSrc /Agile/static/0e09de4c8d1e254454cb4a6c75d71b9d/images/addbysearch.gif>By Search...", "", "javascript:addAttachmentObjects(20094, 20057);swapParentAction('sTD_1004','sIMG_1004','javascript:addAttachmentObjects(20094, 20057)','/Agile/static/0e09de4c8d1e254454cb4a6c75d71b9d/images/addbysearch.gif');", 0, 0, 0)


var arMenu1005
=new Array("", "", "", "", "", "#FFFFFF", "", "", "",
"<checkImg N><ImgSrc /Agile/images/View.gif>View...", "", "javascript:viewAction('viewMultipleFiles');", 0, 0, 0,
"<checkImg N><ImgSrc /Agile/static/84ee9e10de3ef93caf2ec9fad438908c/images/ViewCrossProbe.gif>Cross Probe...", "", "javascript:viewAction('crossProbeFiles');", 0, 0, 0,
"<checkImg N><ImgSrc /Agile/static/136d68f6af759f52b17d64a1a746b866/images/ViewCompare.gif>Compare...", "", "javascript:viewAction('compareFiles');", 0, 0, 0,
"<checkImg N><ImgSrc /Agile/static/a4e6b7979977825a47562a45004a20a4/images/ViewOverlay.gif>Overlay...", "", "javascript:viewAction('overlayFiles');", 0, 0, 0,
"<checkImg N><ImgSrc /Agile/static/a8fb00a5eab802401d5bad4022edfd9b/images/ViewMockup.gif>Digital Mockup...", "", "javascript:viewAction('mockupFiles');", 0, 0, 0,
"<checkImg N><ImgSrc /Agile/static/436753842006638da95aa15d113b5e31/images/ViewBySearch.gif>By Search...", "", "javascript:return;", 1, 0, 0)

var arMenu1005_6
=new Array("<checkImg N><ImgSrc /Agile/static/84ee9e10de3ef93caf2ec9fad438908c/images/ViewCrossProbe.gif>Cross Probe...", "", "javascript:viewAction('advanceCrossProbeFiles');", 0, 0, 0,
"<checkImg N><ImgSrc /Agile/static/136d68f6af759f52b17d64a1a746b866/images/ViewCompare.gif>Compare...", "", "javascript:viewAction('advanceCompareFiles');", 0, 0, 0,
"<checkImg N><ImgSrc /Agile/static/a4e6b7979977825a47562a45004a20a4/images/ViewOverlay.gif>Overlay...", "", "javascript:viewAction('advanceOverlayFiles');", 0, 0, 0,
"<checkImg N><ImgSrc /Agile/static/a8fb00a5eab802401d5bad4022edfd9b/images/ViewMockup.gif>Digital Mockup...", "", "javascript:viewAction('advanceMockupFiles');", 0, 0, 0)

</script>
<table border="0" cellspacing="1" cellpadding="0"><tbody><tr>
<td nowrap="true"><table cellspacing="1" cellpadding="0"><tbody><tr><td id="Edit" nowrap="nowrap" class="iconButtonOff" onmousedown="this.className='menuBarDown'" onmouseup="this.className='iconButtonOver'" onmouseover="this.className='iconButtonOver'" onmouseout="this.className='iconButtonOff';" onclick="this.className='iconButtonDisabled';this.disabled=true;this.onmouseup='';this.onmouseover='';this.onmouseout='';submitForm('MainForm','ItemHandler','displayEditObject','RightPane', '');" valign="top">&nbsp;<img width="16" height="16" title="Edit" border="0" src="/Agile/static/82b254ef76b02929228803594e92256b/images/Edit.gif" alt="Edit" id="sIMG_1002">&nbsp;Edit&nbsp;</td></tr></tbody></table>

</td>

<td nowrap="true"><table cellspacing="1" cellpadding="0"><tbody><tr><td id="Remove" nowrap="nowrap" class="iconButtonDisabled">&nbsp;<img src="/Agile/static/a7b0b983243512d0201c46ff50f651c9/images/dot.gif" height="16" width="1" border="0" alt="">&nbsp;<img width="16" height="16" title="Remove" border="0" src="/Agile/static/674d5eb96884fa5009db9dcb1e30c11b/images/delete.gif" alt="Remove" id="sIMG_1003">&nbsp;Remove&nbsp;</td></tr></tbody></table>

</td>

<td nowrap="true"><table cellspacing="0" cellpadding="0"><tbody><tr><td nowrap="nowrap" class="iconButtonDisabled">&nbsp;<img src="/Agile/static/a7b0b983243512d0201c46ff50f651c9/images/dot.gif" height="16" width="1" border="0" alt="">&nbsp;<img width="16" height="16" title="Add" border="0" src="/Agile/static/1477b14caba6254640e8c475d7041867/images/addfile.gif" alt="Add">&nbsp;Add<img src="/Agile/static/187cbc6abc4e4dd88f27e6b49eb730ee/images/arrow_menuDown.gif" width="11" height="11" border="0" alt=""></td></tr></tbody></table>

</td>

<td nowrap="true"><table cellspacing="0" cellpadding="0"><tbody><tr><td nowrap="nowrap" class="iconButtonOff" onmousedown="this.className='menuBarDown'" onmouseup="this.className='iconButtonOver'" onmouseover="doWhenMouse('divider_1005', true);this.className='iconButtonOver'" onmouseout="doWhenMouse('divider_1005', false);this.className='iconButtonOff';"><table id="combo_1005" cellspacing="0" cellpadding="0"><tbody><tr><td id="sTD_1005" nowrap="nowrap" onclick="javascript:viewAction('viewMultipleFiles');" valign="top">&nbsp;<img name="ViewAttachment" width="16" height="16" title="View" border="0" src="/Agile/images/View.gif" alt="View" id="sIMG_1005">&nbsp;View&nbsp;</td><td nowrap="nowrap">&nbsp;<span id="divider_1005" style="width:1px;height:16px;background-color:black;display:none;"></span>&nbsp;</td><td width="5" nowrap="nowrap" onmouseout="top.frames.TopPane.popDown('1005');this.className='iconButtonOff';" onmouseover="showPopupMenuInFrame('1005',event,getPos(document.getElementById('combo_1005')).x,getPos(document.getElementById('combo_1005')).y);"><img src="/Agile/static/187cbc6abc4e4dd88f27e6b49eb730ee/images/arrow_menuDown.gif" width="11" height="11" border="0" alt=""></td></tr></tbody></table>
</td></tr></tbody></table>

</td>
</tr></tbody></table>
  


			</td>

			<td align="left" width="25%" valign="top">&nbsp;
			<span id="minimizedFilter">&nbsp;</span></td>

		</tr>
		</tbody></table>
	</td>

    
    <td valign="middle" align="right" class="pagination">
      <table width="30%" border="0">
      <tbody><tr>
		
		<td valign="middle" class="pagination" align="right" nowrap="nowrap">&nbsp;&nbsp;&nbsp;
			
		

		  Selected: <b><span id="selectedItems_begin_5">0</span></b>
		  of

		

	  <b><span id="totalItems_begin_5">11</span></b>&nbsp;
	   </td>

		<td class="pagination">&nbsp;&nbsp;</td>
		
         <td valign="middle" class="pagination" nowrap="">
         
               <img src="/Agile/static/d671e92c8ec22f475895c663a1a4264e/images/PaginStartInactive.gif" width="10" height="10" alt="Go to first page" border="0" align="absmiddle">
               <img src="/Agile/static/c64c2da800a5e27c4402e43f8a6fff3c/images/PaginLeftInactive.gif" width="10" height="10" alt="Go to previous page" border="0" align="absmiddle">
         
         </td>
         <td valign="middle" class="pagination" nowrap="">
            Page:
         </td>
         <td valign="middle" class="pagination">
            
               <select class="pagination" disabled="true" onchange="javascript:null;" size="1" name="userPageSelection" align="absmiddle">
            
            
                  <option value="1" selected="true">1</option>
            
            </select>
         </td>
         <td valign="middle" class="pagination" nowrap="">
            of  1
         </td>
         <td valign="middle" class="pagination" nowrap="">
            
            <img src="/Agile/static/41ce26a9ff232409c256ef76ca161d73/images/PaginRightInactive.gif" width="10" height="10" alt="Go to next page" border="0" align="absmiddle">
            <img src="/Agile/static/61250787f3b923dcc79e943b6de27f9e/images/PaginEndInactive.gif" width="10" height="10" alt="Go to last page" border="0" align="absmiddle">
            
         </td>
        <td valign="middle" width="55" class="pagination" align="right" nowrap="nowrap">&nbsp;&nbsp;&nbsp;
         </td>
      </tr>
      </tbody></table>
   </td>
   

</tr>
</tbody></table>
</div><!-- END PAGINATION --><table id="header_5" name="header_5" cellspacing="0" cellpadding="0"><tbody><tr valign="top"><th class="tHd" width="10" onmouseover="javascript:this.style.cursor='hand';" onmouseout="javascript:this.style.cursor='default';" onclick="selectCheckBox(MainForm.pageSelect_5);selectGlobal('MainForm','5', MainForm.pageSelect_5.checked);toggleHighlightAll(5, MainForm.pageSelect_5);"><div id="gsCol" style="width:10">
<span style="display:none">
<input name="pageSelect_5" value="true" type="CHECKBOX" class="" size="8" id="pageSelect_5">
</span>&nbsp;
</div></th>
	<th width="20" class="tHd">
<div id="XH_0_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">
<img name="R9_-6_5" title="Has Been Checked Out " class="tL" border="0" src="images/CheckedOut.gif" alt="Has Been Checked Out " id="R9_-6_5"></div></th>
	<th width="20" class="tHd">
<div id="XH_1_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">
<img name="GetAttachment" title="Get" border="0" src="images/Get.gif" alt="Get" id="GetAttachment"></div></th>
	<th width="20" class="tHd">
<div id="XH_2_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">
<img name="CheckOut" title="CheckOut" border="0" src="images/CheckOut.gif" alt="CheckOut" id="CheckOut"></div></th>
	<th width="20" class="tHd">
<div id="XH_3_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">
<img name="CancelCheckOut" title="Cancel CheckOut" border="0" src="images/CancelCheckOut.gif" alt="Cancel CheckOut" id="CancelCheckOut"></div></th>
	<th width="20" class="tHd">
<div id="XH_4_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">
<img name="Print" title="Print" border="0" src="images/print.gif" alt="Print" id="Print"></div></th>
	<th width="20" class="tHd">
<div id="XH_5_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">
<img name="Redline" title="Has Been Redlined" border="0" src="images/redlined.gif" alt="Has Been Redlined" id="Redline"></div></th>
	<th width="20" class="tHd">
<div id="XH_6_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">
<img name="ShowVersion" title="Show Versions" border="0" src="images/versions.gif" alt="Show Versions" id="ShowVersion"></div></th>
	<th width="20" class="tHd">
<div id="XH_7_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">
<img name="Checksum Failed" title="Has checksum error" border="0" src="images/Error.gif" alt="Has checksum error" id="Checksum Failed"></div></th>
	<th width="188" onclick="javascript:sortTableBy('5','1045','1')" class="tHRSort" onmousemove="javascript:setFinalPosition(event);event.cancelBubble = true;" onmouseup="resizeColumn();event.cancelBubble = true;" title="File Description  ">
<div id="XH_8_5" style="width:188;overflow:hidden;text-overflow:ellipsis;">
File Description</div></th>
<th class="tHSd" width="0" onmousedown="javascript:setInitialPosition(event, 'RE_XH_8_5','ATTACHMENTS_FILELIST','1045');event.cancelBubble = true;" onmousemove="javascript:setFinalPosition(event);event.cancelBubble = true;" onmouseup="resizeColumn();event.cancelBubble = true;">&nbsp;</th>
	<th width="748" onclick="javascript:sortTableBy('5','1046','1')" class="tHRSort" onmousemove="javascript:setFinalPosition(event);event.cancelBubble = true;" onmouseup="resizeColumn();event.cancelBubble = true;" title="Filename  ">
<div id="XH_9_5" style="width:748;overflow:hidden;text-overflow:ellipsis;">
Filename</div></th>
<th class="tHSd" width="0" onmousedown="javascript:setInitialPosition(event, 'RE_XH_9_5','ATTACHMENTS_FILELIST','1046');event.cancelBubble = true;" onmousemove="javascript:setFinalPosition(event);event.cancelBubble = true;" onmouseup="resizeColumn();event.cancelBubble = true;">&nbsp;</th>
	<th width="100" onclick="javascript:sortTableBy('5','4681','1')" class="tHRSort" onmousemove="javascript:setFinalPosition(event);event.cancelBubble = true;" onmouseup="resizeColumn();event.cancelBubble = true;" title="Attachment Type  ">
<div id="XH_10_5" style="width:100;overflow:hidden;text-overflow:ellipsis;">
Attachment Type</div></th>
<th class="tHSd" width="0" onmousedown="javascript:setInitialPosition(event, 'RE_XH_10_5','ATTACHMENTS_FILELIST','4681');event.cancelBubble = true;" onmousemove="javascript:setFinalPosition(event);event.cancelBubble = true;" onmouseup="resizeColumn();event.cancelBubble = true;">&nbsp;</th>
	<th width="75" onclick="javascript:sortTableBy('5','3623','1')" class="tHRSort" onmousemove="javascript:setFinalPosition(event);event.cancelBubble = true;" onmouseup="resizeColumn();event.cancelBubble = true;" title="File Size  ">
<div id="XH_11_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">
File Size</div></th>
<th class="tHSd" width="0" onmousedown="javascript:setInitialPosition(event, 'RE_XH_11_5','ATTACHMENTS_FILELIST','3623');event.cancelBubble = true;" onmousemove="javascript:setFinalPosition(event);event.cancelBubble = true;" onmouseup="resizeColumn();event.cancelBubble = true;">&nbsp;</th>
	<th width="100" onclick="javascript:sortTableBy('5','3624','1')" class="tHRSort" onmousemove="javascript:setFinalPosition(event);event.cancelBubble = true;" onmouseup="resizeColumn();event.cancelBubble = true;" title="File Type  ">
<div id="XH_12_5" style="width:100;overflow:hidden;text-overflow:ellipsis;">
File Type</div></th>
<th class="tHSd" width="0" onmousedown="javascript:setInitialPosition(event, 'RE_XH_12_5','ATTACHMENTS_FILELIST','3624');event.cancelBubble = true;" onmousemove="javascript:setFinalPosition(event);event.cancelBubble = true;" onmouseup="resizeColumn();event.cancelBubble = true;">&nbsp;</th>
	<th width="75" onclick="javascript:sortTableBy('5','3622','1')" class="tHRSort" onmousemove="javascript:setFinalPosition(event);event.cancelBubble = true;" onmouseup="resizeColumn();event.cancelBubble = true;" title="Folder Version  ">
<div id="XH_13_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">
Folder Version</div></th>
<th class="tHSd" width="0" onmousedown="javascript:setInitialPosition(event, 'RE_XH_13_5','ATTACHMENTS_FILELIST','3622');event.cancelBubble = true;" onmousemove="javascript:setFinalPosition(event);event.cancelBubble = true;" onmouseup="resizeColumn();event.cancelBubble = true;">&nbsp;</th>
	<th width="100" onclick="javascript:sortTableBy('5','6038','1')" class="tHRSort" onmousemove="javascript:setFinalPosition(event);event.cancelBubble = true;" onmouseup="resizeColumn();event.cancelBubble = true;" title="Folder Number  ">
<div id="XH_14_5" style="width:100;overflow:hidden;text-overflow:ellipsis;">
Folder Number</div></th>
<th class="tHSd" width="0" onmousedown="javascript:setInitialPosition(event, 'RE_XH_14_5','ATTACHMENTS_FILELIST','6038');event.cancelBubble = true;" onmousemove="javascript:setFinalPosition(event);event.cancelBubble = true;" onmouseup="resizeColumn();event.cancelBubble = true;">&nbsp;</th>
	<th width="100" onclick="javascript:sortTableBy('5','6039','1')" class="tHRSort" onmousemove="javascript:setFinalPosition(event);event.cancelBubble = true;" onmouseup="resizeColumn();event.cancelBubble = true;" title="Folder Description  ">
<div id="XH_15_5" style="width:100;overflow:hidden;text-overflow:ellipsis;">
Folder Description</div></th>
<th class="tHSd" width="0" onmousedown="javascript:setInitialPosition(event, 'RE_XH_15_5','ATTACHMENTS_FILELIST','6039');event.cancelBubble = true;" onmousemove="javascript:setFinalPosition(event);event.cancelBubble = true;" onmouseup="resizeColumn();event.cancelBubble = true;">&nbsp;</th>
	<th width="75" onclick="javascript:sortTableBy('5','1142','1')" class="tHRSort" onmousemove="javascript:setFinalPosition(event);event.cancelBubble = true;" onmouseup="resizeColumn();event.cancelBubble = true;" title="Checkout User  ">
<div id="XH_16_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">
Checkout User</div></th>
<th class="tHSd" width="0" onmousedown="javascript:setInitialPosition(event, 'RE_XH_16_5','ATTACHMENTS_FILELIST','1142');event.cancelBubble = true;" onmousemove="javascript:setFinalPosition(event);event.cancelBubble = true;" onmouseup="resizeColumn();event.cancelBubble = true;">&nbsp;</th>
	<th width="75" onclick="javascript:sortTableBy('5','1143','2')" class="tHRSort" onmousemove="javascript:setFinalPosition(event);event.cancelBubble = true;" onmouseup="resizeColumn();event.cancelBubble = true;" title="Checkout Date  ">
<div id="XH_17_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">
Checkout Date</div></th>
<th class="tHSd" width="0" onmousedown="javascript:setInitialPosition(event, 'RE_XH_17_5','ATTACHMENTS_FILELIST','1143');event.cancelBubble = true;" onmousemove="javascript:setFinalPosition(event);event.cancelBubble = true;" onmouseup="resizeColumn();event.cancelBubble = true;">&nbsp;</th>
	<th width="75" onclick="javascript:sortTableBy('5','3621','2')" class="tHRSort" onmousemove="javascript:setFinalPosition(event);event.cancelBubble = true;" onmouseup="resizeColumn();event.cancelBubble = true;" title="Modified Date  ">
<div id="XH_18_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">
Modified Date</div></th>
<th class="tHSd" width="0" onmousedown="javascript:setInitialPosition(event, 'RE_XH_18_5','ATTACHMENTS_FILELIST','3621');event.cancelBubble = true;" onmousemove="javascript:setFinalPosition(event);event.cancelBubble = true;" onmouseup="resizeColumn();event.cancelBubble = true;">&nbsp;</th>
	<th width="75" onclick="javascript:sortTableBy('5','3645','2')" class="tHRSort" onmousemove="javascript:setFinalPosition(event);event.cancelBubble = true;" onmouseup="resizeColumn();event.cancelBubble = true;" title="Last View Date  ">
<div id="XH_19_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">
Last View Date</div></th>
<th class="tHSd" width="0" onmousedown="javascript:setInitialPosition(event, 'RE_XH_19_5','ATTACHMENTS_FILELIST','3645');event.cancelBubble = true;" onmousemove="javascript:setFinalPosition(event);event.cancelBubble = true;" onmouseup="resizeColumn();event.cancelBubble = true;">&nbsp;</th>
	<th width="100" onclick="javascript:sortTableBy('5','1144','1')" class="tHRSort" onmousemove="javascript:setFinalPosition(event);event.cancelBubble = true;" onmouseup="resizeColumn();event.cancelBubble = true;" title="Checkout Location  ">
<div id="XH_20_5" style="width:100;overflow:hidden;text-overflow:ellipsis;">
Checkout Location</div></th>
<th class="tHSd" width="0" onmousedown="javascript:setInitialPosition(event, 'RE_XH_20_5','ATTACHMENTS_FILELIST','1144');event.cancelBubble = true;" onmousemove="javascript:setFinalPosition(event);event.cancelBubble = true;" onmouseup="resizeColumn();event.cancelBubble = true;">&nbsp;</th>
<th class="tHd" width="30" onmousemove="javascript:setFinalPosition(event);event.cancelBubble = true;" onmouseup="resizeColumn();event.cancelBubble = true;"><div id="dColHdr_5" name="dColHdr_5" style="width:30;overflow:hidden;text-overflow:ellipsis;">&nbsp; </div></th></tr></tbody></table><input name="noOfHeaderRows_5" value="1" type="HIDDEN" class="formElm" size="8" id="noOfHeaderRows_5"><input name="R1_1234567_5" value="fileId=443702433&amp;directEditable=false" type="HIDDEN" class="formElm" size="8" id="R1_1234567_5"><table id="rT_5_0" name="rT_5_0" cellspacing="0" cellpadding="3" title="FOLDER0002729804" onclick="doOnClick(event, 5)" onmousedown="doMouseDown(event, 5);" onmouseup="doMouseUp(event, 5);"><tbody><tr valign="top" class="tRL"><th class="tHd" width="10" align="center" onmouseover="javascript:this.style.cursor='hand';" onmouseout="javascript:this.style.cursor='default';" id="tdId#R1_5"><div id="sCol" name="sCol" style="width:10;height:100%" onmouseover="javascript:this.style.cursor='hand';this.style.cursor='pointer';" onmouseout="javascript:this.style.cursor='default';">
<span style="display:none">
<input name="R1_5" value="true" type="CHECKBOX" class="" size="8" id="R1_5">
</span>&nbsp;
</div></th>
<td width="20"><div id="X_0_5" name="X_0_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="20"><div id="X_1_5" name="X_1_5" style="width:20;overflow:hidden;text-overflow:ellipsis;"><a name="R1_-5_5" href="javascript:getBOAttachment('MainForm', 447996550, 1, '443702433', '70584640', '19A1058701-01-2581-ASS.cvg', 443705168, 'FOLDER0002729804', 1);" class="tL" id="R1_-5_5"><img name="GetAttachment" title="Get" border="0" src="images/Get.gif" alt="Get" id="GetAttachment"></a></div></td><td width="20"><div id="X_2_5" name="X_2_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="20"><div id="X_3_5" name="X_3_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="20"><div id="X_4_5" name="X_4_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="20"><div id="X_5_5" name="X_5_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="20"><div id="X_6_5" name="X_6_5" style="width:20;overflow:hidden;text-overflow:ellipsis;"><a name="R1_-7_5" href="javascript:showAttachmentVersions('10000', '433672420', '447996550', '1');" class="tL" id="R1_-7_5"><img name="ShowVersion" title="Show Versions" border="0" src="images/versions.gif" alt="Show Versions" id="ShowVersion"></a></div></td><td width="20"><div id="X_7_5" name="X_7_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="188"><div id="X_8_5" name="X_8_5" style="width:188;overflow:hidden;text-overflow:ellipsis;">ASS</div></td><td width="0"></td><td width="748"><div id="X_9_5" name="X_9_5" style="width:748;overflow:hidden;text-overflow:ellipsis;"><a name="R1_1046_5" class="tL" id="R1_1046_5"><img name="Document" title="Document" border="0" src="images/DocumentGeneric.gif" alt="Document" id="Document"></a><a href="javascript:openAttachments('MainForm', 447996550, 1, 5, 1);">19A1058701-01-2581-ASS.cvg</a></div></td><td width="0"></td><td width="100"><div id="X_10_5" name="X_10_5" style="width:100;overflow:hidden;text-overflow:ellipsis;">File</div></td><td width="0"></td><td width="75"><div id="X_11_5" name="X_11_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">70,584,640</div></td><td width="0"></td><td width="100"><div id="X_12_5" name="X_12_5" style="width:100;overflow:hidden;text-overflow:ellipsis;">cvg</div></td><td width="0"></td><td width="75"><div id="X_13_5" name="X_13_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">1</div></td><td width="0"></td><td width="100"><div id="X_14_5" name="X_14_5" style="width:100;overflow:hidden;text-overflow:ellipsis;">FOLDER0002729804</div></td><td width="0"></td><td width="100"><div id="X_15_5" name="X_15_5" style="width:100;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="0"></td><td width="75"><div id="X_16_5" name="X_16_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="0"></td><td width="75"><div id="X_17_5" name="X_17_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="0"></td><td width="75"><div id="X_18_5" name="X_18_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">11/05/2020 11:13:32 AM CST</div></td><td width="0"></td><td width="75"><div id="X_19_5" name="X_19_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">11/05/2020 11:13:32 AM CST</div></td><td width="0"></td><td width="100"><div id="X_20_5" name="X_20_5" style="width:100;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="0"></td><td width="30"><div id="dColRow_5" name="dColRow_5" style="width:20">&nbsp;</div></td>
</tr>
<script>addRow('5', 'R1', '', "6159_443705168_447996550", '1', false,false,false,true,true);</script></tbody></table><input name="R2_1234567_5" value="fileId=443702540&amp;directEditable=false" type="HIDDEN" class="formElm" size="8" id="R2_1234567_5"><table id="rT_5_1" name="rT_5_1" cellspacing="0" cellpadding="3" title="FOLDER0002729805" onclick="doOnClick(event, 5)" onmousedown="doMouseDown(event, 5);" onmouseup="doMouseUp(event, 5);"><tbody><tr valign="top" class="tRD"><th class="tHd" width="10" align="center" onmouseover="javascript:this.style.cursor='hand';" onmouseout="javascript:this.style.cursor='default';" id="tdId#R2_5"><div id="sCol" name="sCol" style="width:10;height:100%" onmouseover="javascript:this.style.cursor='hand';this.style.cursor='pointer';" onmouseout="javascript:this.style.cursor='default';">
<span style="display:none">
<input name="R2_5" value="true" type="CHECKBOX" class="" size="8" id="R2_5">
</span>&nbsp;
</div></th>
<td width="20"><div id="X_0_5" name="X_0_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="20"><div id="X_1_5" name="X_1_5" style="width:20;overflow:hidden;text-overflow:ellipsis;"><a name="R2_-5_5" href="javascript:getBOAttachment('MainForm', 447996551, 1, '443702540', '89624673', '19A1058701-01-CAD.cad', 443705182, 'FOLDER0002729805', 1);" class="tL" id="R2_-5_5"><img name="GetAttachment" title="Get" border="0" src="images/Get.gif" alt="Get" id="GetAttachment"></a></div></td><td width="20"><div id="X_2_5" name="X_2_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="20"><div id="X_3_5" name="X_3_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="20"><div id="X_4_5" name="X_4_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="20"><div id="X_5_5" name="X_5_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="20"><div id="X_6_5" name="X_6_5" style="width:20;overflow:hidden;text-overflow:ellipsis;"><a name="R2_-7_5" href="javascript:showAttachmentVersions('10000', '433672420', '447996551', '1');" class="tL" id="R2_-7_5"><img name="ShowVersion" title="Show Versions" border="0" src="images/versions.gif" alt="Show Versions" id="ShowVersion"></a></div></td><td width="20"><div id="X_7_5" name="X_7_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="188"><div id="X_8_5" name="X_8_5" style="width:188;overflow:hidden;text-overflow:ellipsis;">CAD FILE</div></td><td width="0"></td><td width="748"><div id="X_9_5" name="X_9_5" style="width:748;overflow:hidden;text-overflow:ellipsis;"><a name="R2_1046_5" class="tL" id="R2_1046_5"><img name="Document" title="Document" border="0" src="images/DocumentGeneric.gif" alt="Document" id="Document"></a><a href="javascript:openAttachments('MainForm', 447996551, 1, 5, 1);">19A1058701-01-CAD.cad</a></div></td><td width="0"></td><td width="100"><div id="X_10_5" name="X_10_5" style="width:100;overflow:hidden;text-overflow:ellipsis;">Gerber</div></td><td width="0"></td><td width="75"><div id="X_11_5" name="X_11_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">89,624,673</div></td><td width="0"></td><td width="100"><div id="X_12_5" name="X_12_5" style="width:100;overflow:hidden;text-overflow:ellipsis;">cad</div></td><td width="0"></td><td width="75"><div id="X_13_5" name="X_13_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">1</div></td><td width="0"></td><td width="100"><div id="X_14_5" name="X_14_5" style="width:100;overflow:hidden;text-overflow:ellipsis;">FOLDER0002729805</div></td><td width="0"></td><td width="100"><div id="X_15_5" name="X_15_5" style="width:100;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="0"></td><td width="75"><div id="X_16_5" name="X_16_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="0"></td><td width="75"><div id="X_17_5" name="X_17_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="0"></td><td width="75"><div id="X_18_5" name="X_18_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">11/05/2020 11:13:32 AM CST</div></td><td width="0"></td><td width="75"><div id="X_19_5" name="X_19_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">11/05/2020 11:13:32 AM CST</div></td><td width="0"></td><td width="100"><div id="X_20_5" name="X_20_5" style="width:100;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="0"></td><td width="30"><div id="dColRow_5" name="dColRow_5" style="width:20">&nbsp;</div></td>
</tr>
<script>addRow('5', 'R2', '', "6159_443705182_447996551", '1', false,false,false,true,true);</script></tbody></table><input name="R3_1234567_5" value="fileId=443702541&amp;directEditable=false" type="HIDDEN" class="formElm" size="8" id="R3_1234567_5"><table id="rT_5_2" name="rT_5_2" cellspacing="0" cellpadding="3" title="FOLDER0002729806" onclick="doOnClick(event, 5)" onmousedown="doMouseDown(event, 5);" onmouseup="doMouseUp(event, 5);"><tbody><tr valign="top" class="tRL"><th class="tHd" width="10" align="center" onmouseover="javascript:this.style.cursor='hand';" onmouseout="javascript:this.style.cursor='default';" id="tdId#R3_5"><div id="sCol" name="sCol" style="width:10;height:100%" onmouseover="javascript:this.style.cursor='hand';this.style.cursor='pointer';" onmouseout="javascript:this.style.cursor='default';">
<span style="display:none">
<input name="R3_5" value="true" type="CHECKBOX" class="" size="8" id="R3_5">
</span>&nbsp;
</div></th>
<td width="20"><div id="X_0_5" name="X_0_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="20"><div id="X_1_5" name="X_1_5" style="width:20;overflow:hidden;text-overflow:ellipsis;"><a name="R3_-5_5" href="javascript:getBOAttachment('MainForm', 447996552, 1, '443702541', '317223', '19A1058701-01-CD.RPT', 443705195, 'FOLDER0002729806', 1);" class="tL" id="R3_-5_5"><img name="GetAttachment" title="Get" border="0" src="images/Get.gif" alt="Get" id="GetAttachment"></a></div></td><td width="20"><div id="X_2_5" name="X_2_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="20"><div id="X_3_5" name="X_3_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="20"><div id="X_4_5" name="X_4_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="20"><div id="X_5_5" name="X_5_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="20"><div id="X_6_5" name="X_6_5" style="width:20;overflow:hidden;text-overflow:ellipsis;"><a name="R3_-7_5" href="javascript:showAttachmentVersions('10000', '433672420', '447996552', '1');" class="tL" id="R3_-7_5"><img name="ShowVersion" title="Show Versions" border="0" src="images/versions.gif" alt="Show Versions" id="ShowVersion"></a></div></td><td width="20"><div id="X_7_5" name="X_7_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="188"><div id="X_8_5" name="X_8_5" style="width:188;overflow:hidden;text-overflow:ellipsis;">Coordinate</div></td><td width="0"></td><td width="748"><div id="X_9_5" name="X_9_5" style="width:748;overflow:hidden;text-overflow:ellipsis;"><a name="R3_1046_5" class="tL" id="R3_1046_5"><img name="Document" title="Document" border="0" src="images/DocumentGeneric.gif" alt="Document" id="Document"></a><a href="javascript:openAttachments('MainForm', 447996552, 1, 5, 1);">19A1058701-01-CD.RPT</a></div></td><td width="0"></td><td width="100"><div id="X_10_5" name="X_10_5" style="width:100;overflow:hidden;text-overflow:ellipsis;">Gerber</div></td><td width="0"></td><td width="75"><div id="X_11_5" name="X_11_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">317,223</div></td><td width="0"></td><td width="100"><div id="X_12_5" name="X_12_5" style="width:100;overflow:hidden;text-overflow:ellipsis;">RPT</div></td><td width="0"></td><td width="75"><div id="X_13_5" name="X_13_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">1</div></td><td width="0"></td><td width="100"><div id="X_14_5" name="X_14_5" style="width:100;overflow:hidden;text-overflow:ellipsis;">FOLDER0002729806</div></td><td width="0"></td><td width="100"><div id="X_15_5" name="X_15_5" style="width:100;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="0"></td><td width="75"><div id="X_16_5" name="X_16_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="0"></td><td width="75"><div id="X_17_5" name="X_17_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="0"></td><td width="75"><div id="X_18_5" name="X_18_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">11/05/2020 11:13:33 AM CST</div></td><td width="0"></td><td width="75"><div id="X_19_5" name="X_19_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">11/05/2020 11:13:33 AM CST</div></td><td width="0"></td><td width="100"><div id="X_20_5" name="X_20_5" style="width:100;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="0"></td><td width="30"><div id="dColRow_5" name="dColRow_5" style="width:20">&nbsp;</div></td>
</tr>
<script>addRow('5', 'R3', '', "6159_443705195_447996552", '1', false,false,false,true,true);</script></tbody></table><input name="R4_1234567_5" value="fileId=443702542&amp;directEditable=false" type="HIDDEN" class="formElm" size="8" id="R4_1234567_5"><table id="rT_5_3" name="rT_5_3" cellspacing="0" cellpadding="3" title="FOLDER0002729807" onclick="doOnClick(event, 5)" onmousedown="doMouseDown(event, 5);" onmouseup="doMouseUp(event, 5);"><tbody><tr valign="top" class="tRD"><th class="tHd" width="10" align="center" onmouseover="javascript:this.style.cursor='hand';" onmouseout="javascript:this.style.cursor='default';" id="tdId#R4_5"><div id="sCol" name="sCol" style="width:10;height:100%" onmouseover="javascript:this.style.cursor='hand';this.style.cursor='pointer';" onmouseout="javascript:this.style.cursor='default';">
<span style="display:none">
<input name="R4_5" value="true" type="CHECKBOX" class="" size="8" id="R4_5">
</span>&nbsp;
</div></th>
<td width="20"><div id="X_0_5" name="X_0_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="20"><div id="X_1_5" name="X_1_5" style="width:20;overflow:hidden;text-overflow:ellipsis;"><a name="R4_-5_5" href="javascript:getBOAttachment('MainForm', 447996553, 1, '443702542', '1388698', '19A1058701-01-GBR.7z', 443705209, 'FOLDER0002729807', 1);" class="tL" id="R4_-5_5"><img name="GetAttachment" title="Get" border="0" src="images/Get.gif" alt="Get" id="GetAttachment"></a></div></td><td width="20"><div id="X_2_5" name="X_2_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="20"><div id="X_3_5" name="X_3_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="20"><div id="X_4_5" name="X_4_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="20"><div id="X_5_5" name="X_5_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="20"><div id="X_6_5" name="X_6_5" style="width:20;overflow:hidden;text-overflow:ellipsis;"><a name="R4_-7_5" href="javascript:showAttachmentVersions('10000', '433672420', '447996553', '1');" class="tL" id="R4_-7_5"><img name="ShowVersion" title="Show Versions" border="0" src="images/versions.gif" alt="Show Versions" id="ShowVersion"></a></div></td><td width="20"><div id="X_7_5" name="X_7_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="188"><div id="X_8_5" name="X_8_5" style="width:188;overflow:hidden;text-overflow:ellipsis;">Gerber</div></td><td width="0"></td><td width="748"><div id="X_9_5" name="X_9_5" style="width:748;overflow:hidden;text-overflow:ellipsis;"><a name="R4_1046_5" class="tL" id="R4_1046_5"><img name="Document" title="Document" border="0" src="images/DocumentGeneric.gif" alt="Document" id="Document"></a><a href="javascript:openAttachments('MainForm', 447996553, 1, 5, 1);">19A1058701-01-GBR.7z</a></div></td><td width="0"></td><td width="100"><div id="X_10_5" name="X_10_5" style="width:100;overflow:hidden;text-overflow:ellipsis;">Gerber</div></td><td width="0"></td><td width="75"><div id="X_11_5" name="X_11_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">1,388,698</div></td><td width="0"></td><td width="100"><div id="X_12_5" name="X_12_5" style="width:100;overflow:hidden;text-overflow:ellipsis;">7z</div></td><td width="0"></td><td width="75"><div id="X_13_5" name="X_13_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">1</div></td><td width="0"></td><td width="100"><div id="X_14_5" name="X_14_5" style="width:100;overflow:hidden;text-overflow:ellipsis;">FOLDER0002729807</div></td><td width="0"></td><td width="100"><div id="X_15_5" name="X_15_5" style="width:100;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="0"></td><td width="75"><div id="X_16_5" name="X_16_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="0"></td><td width="75"><div id="X_17_5" name="X_17_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="0"></td><td width="75"><div id="X_18_5" name="X_18_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">11/05/2020 11:13:33 AM CST</div></td><td width="0"></td><td width="75"><div id="X_19_5" name="X_19_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">11/05/2020 11:13:33 AM CST</div></td><td width="0"></td><td width="100"><div id="X_20_5" name="X_20_5" style="width:100;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="0"></td><td width="30"><div id="dColRow_5" name="dColRow_5" style="width:20">&nbsp;</div></td>
</tr>
<script>addRow('5', 'R4', '', "6159_443705209_447996553", '1', false,false,false,true,true);</script></tbody></table><input name="R5_1234567_5" value="fileId=443702543&amp;directEditable=false" type="HIDDEN" class="formElm" size="8" id="R5_1234567_5"><table id="rT_5_4" name="rT_5_4" cellspacing="0" cellpadding="3" title="FOLDER0002729808" onclick="doOnClick(event, 5)" onmousedown="doMouseDown(event, 5);" onmouseup="doMouseUp(event, 5);"><tbody><tr valign="top" class="tRL"><th class="tHd" width="10" align="center" onmouseover="javascript:this.style.cursor='hand';" onmouseout="javascript:this.style.cursor='default';" id="tdId#R5_5"><div id="sCol" name="sCol" style="width:10;height:100%" onmouseover="javascript:this.style.cursor='hand';this.style.cursor='pointer';" onmouseout="javascript:this.style.cursor='default';">
<span style="display:none">
<input name="R5_5" value="true" type="CHECKBOX" class="" size="8" id="R5_5">
</span>&nbsp;
</div></th>
<td width="20"><div id="X_0_5" name="X_0_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="20"><div id="X_1_5" name="X_1_5" style="width:20;overflow:hidden;text-overflow:ellipsis;"><a name="R5_-5_5" href="javascript:getBOAttachment('MainForm', 447996554, 1, '443702543', '4371144', '19A1058701-01-GBR_PDF.pdf', 443705224, 'FOLDER0002729808', 1);" class="tL" id="R5_-5_5"><img name="GetAttachment" title="Get" border="0" src="images/Get.gif" alt="Get" id="GetAttachment"></a></div></td><td width="20"><div id="X_2_5" name="X_2_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="20"><div id="X_3_5" name="X_3_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="20"><div id="X_4_5" name="X_4_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="20"><div id="X_5_5" name="X_5_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="20"><div id="X_6_5" name="X_6_5" style="width:20;overflow:hidden;text-overflow:ellipsis;"><a name="R5_-7_5" href="javascript:showAttachmentVersions('10000', '433672420', '447996554', '1');" class="tL" id="R5_-7_5"><img name="ShowVersion" title="Show Versions" border="0" src="images/versions.gif" alt="Show Versions" id="ShowVersion"></a></div></td><td width="20"><div id="X_7_5" name="X_7_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="188"><div id="X_8_5" name="X_8_5" style="width:188;overflow:hidden;text-overflow:ellipsis;">Gerber PDF</div></td><td width="0"></td><td width="748"><div id="X_9_5" name="X_9_5" style="width:748;overflow:hidden;text-overflow:ellipsis;"><a name="R5_1046_5" class="tL" id="R5_1046_5"><img name="Document" title="Document" border="0" src="images/DocumentGeneric.gif" alt="Document" id="Document"></a><a href="javascript:openAttachments('MainForm', 447996554, 1, 5, 1);">19A1058701-01-GBR_PDF.pdf</a></div></td><td width="0"></td><td width="100"><div id="X_10_5" name="X_10_5" style="width:100;overflow:hidden;text-overflow:ellipsis;">File</div></td><td width="0"></td><td width="75"><div id="X_11_5" name="X_11_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">4,371,144</div></td><td width="0"></td><td width="100"><div id="X_12_5" name="X_12_5" style="width:100;overflow:hidden;text-overflow:ellipsis;">pdf</div></td><td width="0"></td><td width="75"><div id="X_13_5" name="X_13_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">1</div></td><td width="0"></td><td width="100"><div id="X_14_5" name="X_14_5" style="width:100;overflow:hidden;text-overflow:ellipsis;">FOLDER0002729808</div></td><td width="0"></td><td width="100"><div id="X_15_5" name="X_15_5" style="width:100;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="0"></td><td width="75"><div id="X_16_5" name="X_16_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="0"></td><td width="75"><div id="X_17_5" name="X_17_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="0"></td><td width="75"><div id="X_18_5" name="X_18_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">11/05/2020 11:13:33 AM CST</div></td><td width="0"></td><td width="75"><div id="X_19_5" name="X_19_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">11/05/2020 11:13:33 AM CST</div></td><td width="0"></td><td width="100"><div id="X_20_5" name="X_20_5" style="width:100;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="0"></td><td width="30"><div id="dColRow_5" name="dColRow_5" style="width:20">&nbsp;</div></td>
</tr>
<script>addRow('5', 'R5', '', "6159_443705224_447996554", '1', false,false,false,true,true);</script></tbody></table><input name="R6_1234567_5" value="fileId=443702544&amp;directEditable=false" type="HIDDEN" class="formElm" size="8" id="R6_1234567_5"><table id="rT_5_5" name="rT_5_5" cellspacing="0" cellpadding="3" title="FOLDER0002729809" onclick="doOnClick(event, 5)" onmousedown="doMouseDown(event, 5);" onmouseup="doMouseUp(event, 5);"><tbody><tr valign="top" class="tRD"><th class="tHd" width="10" align="center" onmouseover="javascript:this.style.cursor='hand';" onmouseout="javascript:this.style.cursor='default';" id="tdId#R6_5"><div id="sCol" name="sCol" style="width:10;height:100%" onmouseover="javascript:this.style.cursor='hand';this.style.cursor='pointer';" onmouseout="javascript:this.style.cursor='default';">
<span style="display:none">
<input name="R6_5" value="true" type="CHECKBOX" class="" size="8" id="R6_5">
</span>&nbsp;
</div></th>
<td width="20"><div id="X_0_5" name="X_0_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="20"><div id="X_1_5" name="X_1_5" style="width:20;overflow:hidden;text-overflow:ellipsis;"><a name="R6_-5_5" href="javascript:getBOAttachment('MainForm', 447996555, 1, '443702544', '230017', '19A1058701-01-IMP.xlsx', 443705328, 'FOLDER0002729809', 1);" class="tL" id="R6_-5_5"><img name="GetAttachment" title="Get" border="0" src="images/Get.gif" alt="Get" id="GetAttachment"></a></div></td><td width="20"><div id="X_2_5" name="X_2_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="20"><div id="X_3_5" name="X_3_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="20"><div id="X_4_5" name="X_4_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="20"><div id="X_5_5" name="X_5_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="20"><div id="X_6_5" name="X_6_5" style="width:20;overflow:hidden;text-overflow:ellipsis;"><a name="R6_-7_5" href="javascript:showAttachmentVersions('10000', '433672420', '447996555', '1');" class="tL" id="R6_-7_5"><img name="ShowVersion" title="Show Versions" border="0" src="images/versions.gif" alt="Show Versions" id="ShowVersion"></a></div></td><td width="20"><div id="X_7_5" name="X_7_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="188"><div id="X_8_5" name="X_8_5" style="width:188;overflow:hidden;text-overflow:ellipsis;">IMP file</div></td><td width="0"></td><td width="748"><div id="X_9_5" name="X_9_5" style="width:748;overflow:hidden;text-overflow:ellipsis;"><a name="R6_1046_5" class="tL" id="R6_1046_5"><img name="Document" title="Document" border="0" src="images/DocumentGeneric.gif" alt="Document" id="Document"></a><a href="javascript:openAttachments('MainForm', 447996555, 1, 5, 1);">19A1058701-01-IMP.xlsx</a></div></td><td width="0"></td><td width="100"><div id="X_10_5" name="X_10_5" style="width:100;overflow:hidden;text-overflow:ellipsis;">File</div></td><td width="0"></td><td width="75"><div id="X_11_5" name="X_11_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">230,017</div></td><td width="0"></td><td width="100"><div id="X_12_5" name="X_12_5" style="width:100;overflow:hidden;text-overflow:ellipsis;">xlsx</div></td><td width="0"></td><td width="75"><div id="X_13_5" name="X_13_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">1</div></td><td width="0"></td><td width="100"><div id="X_14_5" name="X_14_5" style="width:100;overflow:hidden;text-overflow:ellipsis;">FOLDER0002729809</div></td><td width="0"></td><td width="100"><div id="X_15_5" name="X_15_5" style="width:100;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="0"></td><td width="75"><div id="X_16_5" name="X_16_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="0"></td><td width="75"><div id="X_17_5" name="X_17_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="0"></td><td width="75"><div id="X_18_5" name="X_18_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">11/05/2020 11:16:00 AM CST</div></td><td width="0"></td><td width="75"><div id="X_19_5" name="X_19_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">11/05/2020 11:16:00 AM CST</div></td><td width="0"></td><td width="100"><div id="X_20_5" name="X_20_5" style="width:100;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="0"></td><td width="30"><div id="dColRow_5" name="dColRow_5" style="width:20">&nbsp;</div></td>
</tr>
<script>addRow('5', 'R6', '', "6159_443705328_447996555", '1', false,false,false,true,true);</script></tbody></table><input name="R7_1234567_5" value="fileId=443702545&amp;directEditable=false" type="HIDDEN" class="formElm" size="8" id="R7_1234567_5"><table id="rT_5_6" name="rT_5_6" cellspacing="0" cellpadding="3" title="FOLDER0002729810" onclick="doOnClick(event, 5)" onmousedown="doMouseDown(event, 5);" onmouseup="doMouseUp(event, 5);"><tbody><tr valign="top" class="tRL"><th class="tHd" width="10" align="center" onmouseover="javascript:this.style.cursor='hand';" onmouseout="javascript:this.style.cursor='default';" id="tdId#R7_5"><div id="sCol" name="sCol" style="width:10;height:100%" onmouseover="javascript:this.style.cursor='hand';this.style.cursor='pointer';" onmouseout="javascript:this.style.cursor='default';">
<span style="display:none">
<input name="R7_5" value="true" type="CHECKBOX" class="" size="8" id="R7_5">
</span>&nbsp;
</div></th>
<td width="20"><div id="X_0_5" name="X_0_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="20"><div id="X_1_5" name="X_1_5" style="width:20;overflow:hidden;text-overflow:ellipsis;"><a name="R7_-5_5" href="javascript:getBOAttachment('MainForm', 447996556, 1, '443702545', '63256628', '19A1058701-01-JOB.brd', 443705422, 'FOLDER0002729810', 1);" class="tL" id="R7_-5_5"><img name="GetAttachment" title="Get" border="0" src="images/Get.gif" alt="Get" id="GetAttachment"></a></div></td><td width="20"><div id="X_2_5" name="X_2_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="20"><div id="X_3_5" name="X_3_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="20"><div id="X_4_5" name="X_4_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="20"><div id="X_5_5" name="X_5_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="20"><div id="X_6_5" name="X_6_5" style="width:20;overflow:hidden;text-overflow:ellipsis;"><a name="R7_-7_5" href="javascript:showAttachmentVersions('10000', '433672420', '447996556', '1');" class="tL" id="R7_-7_5"><img name="ShowVersion" title="Show Versions" border="0" src="images/versions.gif" alt="Show Versions" id="ShowVersion"></a></div></td><td width="20"><div id="X_7_5" name="X_7_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="188"><div id="X_8_5" name="X_8_5" style="width:188;overflow:hidden;text-overflow:ellipsis;">JOB</div></td><td width="0"></td><td width="748"><div id="X_9_5" name="X_9_5" style="width:748;overflow:hidden;text-overflow:ellipsis;"><a name="R7_1046_5" class="tL" id="R7_1046_5"><img name="Document" title="Document" border="0" src="images/DocumentGeneric.gif" alt="Document" id="Document"></a><a href="javascript:openAttachments('MainForm', 447996556, 1, 5, 1);">19A1058701-01-JOB.brd</a></div></td><td width="0"></td><td width="100"><div id="X_10_5" name="X_10_5" style="width:100;overflow:hidden;text-overflow:ellipsis;">Design Job File</div></td><td width="0"></td><td width="75"><div id="X_11_5" name="X_11_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">63,256,628</div></td><td width="0"></td><td width="100"><div id="X_12_5" name="X_12_5" style="width:100;overflow:hidden;text-overflow:ellipsis;">brd</div></td><td width="0"></td><td width="75"><div id="X_13_5" name="X_13_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">1</div></td><td width="0"></td><td width="100"><div id="X_14_5" name="X_14_5" style="width:100;overflow:hidden;text-overflow:ellipsis;">FOLDER0002729810</div></td><td width="0"></td><td width="100"><div id="X_15_5" name="X_15_5" style="width:100;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="0"></td><td width="75"><div id="X_16_5" name="X_16_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="0"></td><td width="75"><div id="X_17_5" name="X_17_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="0"></td><td width="75"><div id="X_18_5" name="X_18_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">11/05/2020 11:16:00 AM CST</div></td><td width="0"></td><td width="75"><div id="X_19_5" name="X_19_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">11/05/2020 11:16:00 AM CST</div></td><td width="0"></td><td width="100"><div id="X_20_5" name="X_20_5" style="width:100;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="0"></td><td width="30"><div id="dColRow_5" name="dColRow_5" style="width:20">&nbsp;</div></td>
</tr>
<script>addRow('5', 'R7', '', "6159_443705422_447996556", '1', false,false,false,true,true);</script></tbody></table><input name="R8_1234567_5" value="fileId=443702546&amp;directEditable=false" type="HIDDEN" class="formElm" size="8" id="R8_1234567_5"><table id="rT_5_7" name="rT_5_7" cellspacing="0" cellpadding="3" title="FOLDER0002729811" onclick="doOnClick(event, 5)" onmousedown="doMouseDown(event, 5);" onmouseup="doMouseUp(event, 5);"><tbody><tr valign="top" class="tRD"><th class="tHd" width="10" align="center" onmouseover="javascript:this.style.cursor='hand';" onmouseout="javascript:this.style.cursor='default';" id="tdId#R8_5"><div id="sCol" name="sCol" style="width:10;height:100%" onmouseover="javascript:this.style.cursor='hand';this.style.cursor='pointer';" onmouseout="javascript:this.style.cursor='default';">
<span style="display:none">
<input name="R8_5" value="true" type="CHECKBOX" class="" size="8" id="R8_5">
</span>&nbsp;
</div></th>
<td width="20"><div id="X_0_5" name="X_0_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="20"><div id="X_1_5" name="X_1_5" style="width:20;overflow:hidden;text-overflow:ellipsis;"><a name="R8_-5_5" href="javascript:getBOAttachment('MainForm', 447996698, 1, '443702546', '191012', '19A1058701-01-PNL_DWG.pdf', 443705435, 'FOLDER0002729811', 1);" class="tL" id="R8_-5_5"><img name="GetAttachment" title="Get" border="0" src="images/Get.gif" alt="Get" id="GetAttachment"></a></div></td><td width="20"><div id="X_2_5" name="X_2_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="20"><div id="X_3_5" name="X_3_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="20"><div id="X_4_5" name="X_4_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="20"><div id="X_5_5" name="X_5_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="20"><div id="X_6_5" name="X_6_5" style="width:20;overflow:hidden;text-overflow:ellipsis;"><a name="R8_-7_5" href="javascript:showAttachmentVersions('10000', '433672420', '447996698', '1');" class="tL" id="R8_-7_5"><img name="ShowVersion" title="Show Versions" border="0" src="images/versions.gif" alt="Show Versions" id="ShowVersion"></a></div></td><td width="20"><div id="X_7_5" name="X_7_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="188"><div id="X_8_5" name="X_8_5" style="width:188;overflow:hidden;text-overflow:ellipsis;">PD</div></td><td width="0"></td><td width="748"><div id="X_9_5" name="X_9_5" style="width:748;overflow:hidden;text-overflow:ellipsis;"><a name="R8_1046_5" class="tL" id="R8_1046_5"><img name="Document" title="Document" border="0" src="images/DocumentGeneric.gif" alt="Document" id="Document"></a><a href="javascript:openAttachments('MainForm', 447996698, 1, 5, 1);">19A1058701-01-PNL_DWG.pdf</a></div></td><td width="0"></td><td width="100"><div id="X_10_5" name="X_10_5" style="width:100;overflow:hidden;text-overflow:ellipsis;">File</div></td><td width="0"></td><td width="75"><div id="X_11_5" name="X_11_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">191,012</div></td><td width="0"></td><td width="100"><div id="X_12_5" name="X_12_5" style="width:100;overflow:hidden;text-overflow:ellipsis;">pdf</div></td><td width="0"></td><td width="75"><div id="X_13_5" name="X_13_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">1</div></td><td width="0"></td><td width="100"><div id="X_14_5" name="X_14_5" style="width:100;overflow:hidden;text-overflow:ellipsis;">FOLDER0002729811</div></td><td width="0"></td><td width="100"><div id="X_15_5" name="X_15_5" style="width:100;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="0"></td><td width="75"><div id="X_16_5" name="X_16_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="0"></td><td width="75"><div id="X_17_5" name="X_17_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="0"></td><td width="75"><div id="X_18_5" name="X_18_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">11/05/2020 11:16:00 AM CST</div></td><td width="0"></td><td width="75"><div id="X_19_5" name="X_19_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">11/05/2020 11:16:00 AM CST</div></td><td width="0"></td><td width="100"><div id="X_20_5" name="X_20_5" style="width:100;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="0"></td><td width="30"><div id="dColRow_5" name="dColRow_5" style="width:20">&nbsp;</div></td>
</tr>
<script>addRow('5', 'R8', '', "6159_443705435_447996698", '1', false,false,false,true,true);</script></tbody></table><input name="R9_1234567_5" value="fileId=443702547&amp;directEditable=false" type="HIDDEN" class="formElm" size="8" id="R9_1234567_5"><table id="rT_5_8" name="rT_5_8" cellspacing="0" cellpadding="3" title="FOLDER0002729812" onclick="doOnClick(event, 5)" onmousedown="doMouseDown(event, 5);" onmouseup="doMouseUp(event, 5);"><tbody><tr valign="top" class="tRL"><th class="tHd" width="10" align="center" onmouseover="javascript:this.style.cursor='hand';" onmouseout="javascript:this.style.cursor='default';" id="tdId#R9_5"><div id="sCol" name="sCol" style="width:10;height:100%" onmouseover="javascript:this.style.cursor='hand';this.style.cursor='pointer';" onmouseout="javascript:this.style.cursor='default';">
<span style="display:none">
<input name="R9_5" value="true" type="CHECKBOX" class="" size="8" id="R9_5">
</span>&nbsp;
</div></th>
<td width="20"><div id="X_0_5" name="X_0_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="20"><div id="X_1_5" name="X_1_5" style="width:20;overflow:hidden;text-overflow:ellipsis;"><a name="R9_-5_5" href="javascript:getBOAttachment('MainForm', 447996699, 1, '443702547', '2465497', '19A1058701-01-SCH.7z', 443705449, 'FOLDER0002729812', 1);" class="tL" id="R9_-5_5"><img name="GetAttachment" title="Get" border="0" src="images/Get.gif" alt="Get" id="GetAttachment"></a></div></td><td width="20"><div id="X_2_5" name="X_2_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="20"><div id="X_3_5" name="X_3_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="20"><div id="X_4_5" name="X_4_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="20"><div id="X_5_5" name="X_5_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="20"><div id="X_6_5" name="X_6_5" style="width:20;overflow:hidden;text-overflow:ellipsis;"><a name="R9_-7_5" href="javascript:showAttachmentVersions('10000', '433672420', '447996699', '1');" class="tL" id="R9_-7_5"><img name="ShowVersion" title="Show Versions" border="0" src="images/versions.gif" alt="Show Versions" id="ShowVersion"></a></div></td><td width="20"><div id="X_7_5" name="X_7_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="188"><div id="X_8_5" name="X_8_5" style="width:188;overflow:hidden;text-overflow:ellipsis;">SCHEMATIC(DSN)</div></td><td width="0"></td><td width="748"><div id="X_9_5" name="X_9_5" style="width:748;overflow:hidden;text-overflow:ellipsis;"><a name="R9_1046_5" class="tL" id="R9_1046_5"><img name="Document" title="Document" border="0" src="images/DocumentGeneric.gif" alt="Document" id="Document"></a><a href="javascript:openAttachments('MainForm', 447996699, 1, 5, 1);">19A1058701-01-SCH.7z</a></div></td><td width="0"></td><td width="100"><div id="X_10_5" name="X_10_5" style="width:100;overflow:hidden;text-overflow:ellipsis;">Design Source Code</div></td><td width="0"></td><td width="75"><div id="X_11_5" name="X_11_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">2,465,497</div></td><td width="0"></td><td width="100"><div id="X_12_5" name="X_12_5" style="width:100;overflow:hidden;text-overflow:ellipsis;">7z</div></td><td width="0"></td><td width="75"><div id="X_13_5" name="X_13_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">1</div></td><td width="0"></td><td width="100"><div id="X_14_5" name="X_14_5" style="width:100;overflow:hidden;text-overflow:ellipsis;">FOLDER0002729812</div></td><td width="0"></td><td width="100"><div id="X_15_5" name="X_15_5" style="width:100;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="0"></td><td width="75"><div id="X_16_5" name="X_16_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="0"></td><td width="75"><div id="X_17_5" name="X_17_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="0"></td><td width="75"><div id="X_18_5" name="X_18_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">11/05/2020 11:16:00 AM CST</div></td><td width="0"></td><td width="75"><div id="X_19_5" name="X_19_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">11/05/2020 11:16:00 AM CST</div></td><td width="0"></td><td width="100"><div id="X_20_5" name="X_20_5" style="width:100;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="0"></td><td width="30"><div id="dColRow_5" name="dColRow_5" style="width:20">&nbsp;</div></td>
</tr>
<script>addRow('5', 'R9', '', "6159_443705449_447996699", '1', false,false,false,true,true);</script></tbody></table><input name="R10_1234567_5" value="fileId=443702548&amp;directEditable=false" type="HIDDEN" class="formElm" size="8" id="R10_1234567_5"><table id="rT_5_9" name="rT_5_9" cellspacing="0" cellpadding="3" title="FOLDER0002729813" onclick="doOnClick(event, 5)" onmousedown="doMouseDown(event, 5);" onmouseup="doMouseUp(event, 5);"><tbody><tr valign="top" class="tRD"><th class="tHd" width="10" align="center" onmouseover="javascript:this.style.cursor='hand';" onmouseout="javascript:this.style.cursor='default';" id="tdId#R10_5"><div id="sCol" name="sCol" style="width:10;height:100%" onmouseover="javascript:this.style.cursor='hand';this.style.cursor='pointer';" onmouseout="javascript:this.style.cursor='default';">
<span style="display:none">
<input name="R10_5" value="true" type="CHECKBOX" class="" size="8" id="R10_5">
</span>&nbsp;
</div></th>
<td width="20"><div id="X_0_5" name="X_0_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="20"><div id="X_1_5" name="X_1_5" style="width:20;overflow:hidden;text-overflow:ellipsis;"><a name="R10_-5_5" href="javascript:getBOAttachment('MainForm', 447996700, 1, '443702548', '4637341', '19A1058701-01-SCH.pdf', 443705463, 'FOLDER0002729813', 1);" class="tL" id="R10_-5_5"><img name="GetAttachment" title="Get" border="0" src="images/Get.gif" alt="Get" id="GetAttachment"></a></div></td><td width="20"><div id="X_2_5" name="X_2_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="20"><div id="X_3_5" name="X_3_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="20"><div id="X_4_5" name="X_4_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="20"><div id="X_5_5" name="X_5_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="20"><div id="X_6_5" name="X_6_5" style="width:20;overflow:hidden;text-overflow:ellipsis;"><a name="R10_-7_5" href="javascript:showAttachmentVersions('10000', '433672420', '447996700', '1');" class="tL" id="R10_-7_5"><img name="ShowVersion" title="Show Versions" border="0" src="images/versions.gif" alt="Show Versions" id="ShowVersion"></a></div></td><td width="20"><div id="X_7_5" name="X_7_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="188"><div id="X_8_5" name="X_8_5" style="width:188;overflow:hidden;text-overflow:ellipsis;">SCHEMATIC(PDF)</div></td><td width="0"></td><td width="748"><div id="X_9_5" name="X_9_5" style="width:748;overflow:hidden;text-overflow:ellipsis;"><a name="R10_1046_5" class="tL" id="R10_1046_5"><img name="Document" title="Document" border="0" src="images/DocumentGeneric.gif" alt="Document" id="Document"></a><a href="javascript:openAttachments('MainForm', 447996700, 1, 5, 1);">19A1058701-01-SCH.pdf</a></div></td><td width="0"></td><td width="100"><div id="X_10_5" name="X_10_5" style="width:100;overflow:hidden;text-overflow:ellipsis;">Schematic</div></td><td width="0"></td><td width="75"><div id="X_11_5" name="X_11_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">4,637,341</div></td><td width="0"></td><td width="100"><div id="X_12_5" name="X_12_5" style="width:100;overflow:hidden;text-overflow:ellipsis;">pdf</div></td><td width="0"></td><td width="75"><div id="X_13_5" name="X_13_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">1</div></td><td width="0"></td><td width="100"><div id="X_14_5" name="X_14_5" style="width:100;overflow:hidden;text-overflow:ellipsis;">FOLDER0002729813</div></td><td width="0"></td><td width="100"><div id="X_15_5" name="X_15_5" style="width:100;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="0"></td><td width="75"><div id="X_16_5" name="X_16_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="0"></td><td width="75"><div id="X_17_5" name="X_17_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="0"></td><td width="75"><div id="X_18_5" name="X_18_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">11/05/2020 11:16:01 AM CST</div></td><td width="0"></td><td width="75"><div id="X_19_5" name="X_19_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">11/05/2020 11:16:01 AM CST</div></td><td width="0"></td><td width="100"><div id="X_20_5" name="X_20_5" style="width:100;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="0"></td><td width="30"><div id="dColRow_5" name="dColRow_5" style="width:20">&nbsp;</div></td>
</tr>
<script>addRow('5', 'R10', '', "6159_443705463_447996700", '1', false,false,false,true,true);</script></tbody></table><input name="R11_1234567_5" value="fileId=443702549&amp;directEditable=false" type="HIDDEN" class="formElm" size="8" id="R11_1234567_5"><table id="rT_5_10" name="rT_5_10" cellspacing="0" cellpadding="3" title="FOLDER0002729814" onclick="doOnClick(event, 5)" onmousedown="doMouseDown(event, 5);" onmouseup="doMouseUp(event, 5);"><tbody><tr valign="top" class="tRL"><th class="tHd" width="10" align="center" onmouseover="javascript:this.style.cursor='hand';" onmouseout="javascript:this.style.cursor='default';" id="tdId#R11_5"><div id="sCol" name="sCol" style="width:10;height:100%" onmouseover="javascript:this.style.cursor='hand';this.style.cursor='pointer';" onmouseout="javascript:this.style.cursor='default';">
<span style="display:none">
<input name="R11_5" value="true" type="CHECKBOX" class="" size="8" id="R11_5">
</span>&nbsp;
</div></th>
<td width="20"><div id="X_0_5" name="X_0_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="20"><div id="X_1_5" name="X_1_5" style="width:20;overflow:hidden;text-overflow:ellipsis;"><a name="R11_-5_5" href="javascript:getBOAttachment('MainForm', 447996701, 1, '443702549', '1097365', 'ME.7z', 443705476, 'FOLDER0002729814', 1);" class="tL" id="R11_-5_5"><img name="GetAttachment" title="Get" border="0" src="images/Get.gif" alt="Get" id="GetAttachment"></a></div></td><td width="20"><div id="X_2_5" name="X_2_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="20"><div id="X_3_5" name="X_3_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="20"><div id="X_4_5" name="X_4_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="20"><div id="X_5_5" name="X_5_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="20"><div id="X_6_5" name="X_6_5" style="width:20;overflow:hidden;text-overflow:ellipsis;"><a name="R11_-7_5" href="javascript:showAttachmentVersions('10000', '433672420', '447996701', '1');" class="tL" id="R11_-7_5"><img name="ShowVersion" title="Show Versions" border="0" src="images/versions.gif" alt="Show Versions" id="ShowVersion"></a></div></td><td width="20"><div id="X_7_5" name="X_7_5" style="width:20;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="188"><div id="X_8_5" name="X_8_5" style="width:188;overflow:hidden;text-overflow:ellipsis;">ME</div></td><td width="0"></td><td width="748"><div id="X_9_5" name="X_9_5" style="width:748;overflow:hidden;text-overflow:ellipsis;"><a name="R11_1046_5" class="tL" id="R11_1046_5"><img name="Document" title="Document" border="0" src="images/DocumentGeneric.gif" alt="Document" id="Document"></a><a href="javascript:openAttachments('MainForm', 447996701, 1, 5, 1);">ME.7z</a></div></td><td width="0"></td><td width="100"><div id="X_10_5" name="X_10_5" style="width:100;overflow:hidden;text-overflow:ellipsis;">File</div></td><td width="0"></td><td width="75"><div id="X_11_5" name="X_11_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">1,097,365</div></td><td width="0"></td><td width="100"><div id="X_12_5" name="X_12_5" style="width:100;overflow:hidden;text-overflow:ellipsis;">7z</div></td><td width="0"></td><td width="75"><div id="X_13_5" name="X_13_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">1</div></td><td width="0"></td><td width="100"><div id="X_14_5" name="X_14_5" style="width:100;overflow:hidden;text-overflow:ellipsis;">FOLDER0002729814</div></td><td width="0"></td><td width="100"><div id="X_15_5" name="X_15_5" style="width:100;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="0"></td><td width="75"><div id="X_16_5" name="X_16_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="0"></td><td width="75"><div id="X_17_5" name="X_17_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="0"></td><td width="75"><div id="X_18_5" name="X_18_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">11/05/2020 11:16:12 AM CST</div></td><td width="0"></td><td width="75"><div id="X_19_5" name="X_19_5" style="width:75;overflow:hidden;text-overflow:ellipsis;">11/05/2020 11:16:12 AM CST</div></td><td width="0"></td><td width="100"><div id="X_20_5" name="X_20_5" style="width:100;overflow:hidden;text-overflow:ellipsis;">&nbsp;</div></td><td width="0"></td><td width="30"><div id="dColRow_5" name="dColRow_5" style="width:20">&nbsp;</div></td>
</tr>
<script>addRow('5', 'R11', '', "6159_443705476_447996701", '1', false,false,false,true,true);</script></tbody></table><script>doRowStyling('5');</script><table cellspacing="0" cellpadding="0" border="0" width="100%">	<tbody><tr><td class="tabLine"><img src="/Agile/static/a7b0b983243512d0201c46ff50f651c9/images/dot.gif" width="400" height="1" border="0" alt=""></td></tr></tbody></table><!-- BEGIN PAGINATION  -->









<script language="JavaScript" src="/Agile/static/f95fdd7c2a966750c44ccd47484d0c89/includes/jsMessages.js"></script>


<div id="pageViewContent" name="pageViewContent" style="position: relative; width: 1039px;">
<table border="0" height="15" cellpadding="0" cellspacing="0" width="100%">
<tbody><tr valign="middle" height="20">

   
    <td valign="middle" align="right" class="pagination">
      <table width="30%" border="0">
      <tbody><tr>

         <td valign="middle" class="pagination" nowrap="">
            Rows per page:
         </td>

         <td valign="middle" class="pagination" nowrap="">

		   <select class="pagination" onchange="javascript:setRowsPerPage('MainForm', this, '5');" size="1" name="userRowsPerPageSelection" align="absmiddle">

			
						<option value="10">10</option>
					
						<option value="15">15</option>
					
						<option value="20">20</option>
					
						<option value="25">25</option>
					
						<option value="50">50</option>
					
						<option value="100">100</option>
					
						<option value="250" selected="">250</option>
					
            </select>

         </td>
      </tr>
      </tbody></table>
   </td>
   

    
	<td valign="middle" align="left" width="30" nowrap="nowrap" class="pagination">
		<table cellpadding="0" cellspacing="0" border="0">
		<tbody><tr>
			<td>&nbsp;</td>
		</tr>
		</tbody></table>
	</td>
	

	<td valign="middle" align="left" width="68%" nowrap="nowrap" class="pagination">
		<table cellpadding="0" cellspacing="0" border="0">
		<tbody><tr>
			<td>&nbsp;</td>
		</tr>
		</tbody></table>
	</td>

     
    <td valign="middle" align="right" class="pagination">
      <table width="30%" border="0">
      <tbody><tr>

    <td valign="middle" class="pagination" align="right" nowrap="nowrap">&nbsp;&nbsp;&nbsp;
     </td>

    <td class="pagination">&nbsp;&nbsp;</td>

         <td valign="middle" class="pagination" nowrap="">
         
               <img src="/Agile/static/d671e92c8ec22f475895c663a1a4264e/images/PaginStartInactive.gif" width="10" height="10" alt="Go to first page" border="0" align="absmiddle">
               <img src="/Agile/static/c64c2da800a5e27c4402e43f8a6fff3c/images/PaginLeftInactive.gif" width="10" height="10" alt="Go to previous page" border="0" align="absmiddle">
         
         </td>
         <td valign="middle" class="pagination" nowrap="">
            Page:
         </td>
         <td valign="middle" class="pagination">
            
               <select class="pagination" disabled="true" onchange="javascript:null;" size="1" name="userPageSelection" align="absmiddle">
            
            
                  <option value="1" selected="true">1</option>
            
            </select>
         </td>
         <td valign="middle" class="pagination" nowrap="">
            of  1
         </td>
         <td valign="middle" class="pagination" nowrap="">
            
            <img src="/Agile/static/41ce26a9ff232409c256ef76ca161d73/images/PaginRightInactive.gif" width="10" height="10" alt="Go to next page" border="0" align="absmiddle">
            <img src="/Agile/static/61250787f3b923dcc79e943b6de27f9e/images/PaginEndInactive.gif" width="10" height="10" alt="Go to last page" border="0" align="absmiddle">
            
         </td>
        <td valign="middle" width="55" class="pagination" align="right" nowrap="nowrap">&nbsp;&nbsp;&nbsp;
        </td>
      </tr>
      </tbody></table>
   </td>
   

</tr>
</tbody></table>
</div>

<!-- END PAGINATION -->
    </td>
</tr>
</tbody></table>
<script language="Javascript">
initSelect();
</script>
<input name="browserType" type="HIDDEN">
<input name="yesNoFlag" type="HIDDEN">
<input name="changedrowid" type="HIDDEN">
<input name="version" type="HIDDEN">
<input name="rowstobedeleted" type="HIDDEN">
<input name="currentrowid" type="HIDDEN">
<input name="filepath" type="HIDDEN">
<input name="printattachment" type="HIDDEN">
<input name="filetype" type="HIDDEN">
<input name="fileid" type="HIDDEN">
<input name="fileName" type="HIDDEN">
<input name="showMarkup" type="HIDDEN">
<input name="tableId" type="HIDDEN">
<input name="tablename" type="HIDDEN" value="null">
<input name="versionControlItemObjId" type="HIDDEN">
<input name="versionControlItemClassId" type="HIDDEN">
<input name="versionControlItemRowId" type="HIDDEN" value="">
<input name="attachmentNumber" type="HIDDEN">
<input name="jvueAction" type="HIDDEN">
<input name="fromPCViewer" type="HIDDEN">
<input name="browserType" type="HIDDEN">
<input name="needGetFile" type="HIDDEN">
<input name="checkinFolderVersion" type="HIDDEN">
<input name="checkinFolderTableID" type="HIDDEN">
<input name="checkoutFolderVersion" type="HIDDEN">
<input name="checkoutFolderTableID" type="HIDDEN">
<input name="checkoutFolderFileID" type="HIDDEN">
<input name="checkoutFolderFileSize" type="HIDDEN">
<input name="checkoutFolderfileName" type="HIDDEN">

<input name="checkoutLocation" type="HIDDEN" value="">
<input name="boFileId" type="HIDDEN">
<input name="fileRowIds" type="HIDDEN">
<input name="fileIds" type="HIDDEN" value="">
<input name="fileNames" type="HIDDEN">
<input name="fileSizes" type="HIDDEN">
<input name="asLatest" type="HIDDEN">
<input name="asAllFiles" type="HIDDEN">

<!--<input name="viewerUnloaded" type="HIDDEN" value="false"></input>-->
<input name="checkincheckoutoperate" type="HIDDEN" value="">


<!-- END ITEM ATTACHMENTS CONTENT -->


	
	

	<!-- div end of tabContents -->
	</div>

	

        
        
		
		<table width="100%" cellspacing="0" cellpadding="0" border="0">
		
        <tbody><tr width="100%" row="6">
            <td colspan="2">
                









            </td>
        </tr>
		
		</tbody></table>
		
        
		


<p>




<input type="hidden" name="setSequentialWarning" value="false">
<input type="hidden" name="currentWarningCode" value="">
<input type="hidden" name="commonWarnCode" value="">
<input type="hidden" name="LOAD_TABLE_FAILED" value="false">



<script language="javascript">
var res = eval("document." + "MainForm");
var doYesProceed;





function yesProceed(){
  setWarningCodes();
  if(eval(res.stepCommand))
    eval(res.stepCommand).value = "null";
  if(eval(res.deleteRowsTableId))
    eval(res.deleteRowsTableId).value = "null";
  disableButtons();
  if (doYesProceed != null) {
    doYesProceed();
  }
  if (disableTDButtons != null) {
      disableTDButton('Save');
      disableTDButton('Validate');
  }
  submitForm(document.forms[0].name,"ItemHandler","displayObject", "_self");
}

function disableButtons() {

} // fn

function noProceed(){
  setRepWarningCodes()
  if(eval(res.stepCommand))
    eval(res.stepCommand).value = "null";
  submitForm(document.forms[0].name,"ItemHandler","displayObject", "_self");
}
function noNext(){
  
    clearWarningCodes("null");
   
}
function setWarningCodes(){
  res.pgWarnID.value = "null";
  res.pgWarnCode.value = "null";
  res.commonWarnCode.value = "null";
}
function setRepWarningCodes(){
  res.pgWarnID.value = "null";
  res.pgWarnCode.value = "null";
}
function clearWarningCodes(wCode){
  if (wCode != null && wCode.length > 0) {
    var allCodeIds = "null";
    var allCodes = "null";      
    var arrCodeIds = allCodeIds.split(";")
    var arrCodes = allCodes.split(";")
    var rCodeIds = "";
    var rCodes = "";
    for (var i=0; i<arrCodes.length; i++ ){
        if(wCode == arrCodes[i]) {
            continue;
        }
        rCodeIds = arrCodeIds[i] +";"+rCodeIds;
        rCodes = arrCodes[i] +";"+rCodes;
    }
    res.pgWarnID.value = rCodeIds;
    res.pgWarnCode.value = rCodes;

  } else {
  res.pgWarnID.value = "";
  res.pgWarnCode.value = "";
  res.commonWarnCode.value = "";
  }

}
function cancelWarning(){
  clearWarningCodes();
  submitForm('MainForm', '', '', '_self');
}
</script>

<input name="registeredTables" value="5" type="HIDDEN" class="formElm" size="8" id="registeredTables">
<input name="registeredTableNames" value="ATTACHMENTS_FILELIST" type="HIDDEN" class="formElm" size="8" id="registeredTableNames">
<input name="deleteRowsTableId" value="" type="HIDDEN" class="formElm" size="8" id="deleteRowsTableId">
</p></form><script>
</script>
<script>
</script>
<form name="MainForm_2__" method="POST" action="PCMServlet" enctype="application/x-www-form-urlencoded" onsubmit="return false;" target="RightPane">
<!-- Begin Form Standard Attributes -->
<input name="module" value="ItemHandler" type="HIDDEN" class="formElm" size="8" id="module">
<input name="opcode" value="displayObject" type="HIDDEN" class="formElm" size="8" id="opcode">
<input name="defaultAction" value="" type="HIDDEN" class="formElm" size="8" id="defaultAction">
<input name="addlParam" value="&amp;START&amp;tableDivHeight=414&amp;tableDivWidth=997&amp;END&amp;" type="HIDDEN" class="formElm" size="8" id="addlParam">
<input name="popup" value="" type="HIDDEN" class="formElm" size="8" id="popup">
<input name="objver" value="159" type="HIDDEN" class="formElm" size="8" id="objver">
<input name="objid" value="433672420" type="HIDDEN" class="formElm" size="8" id="objid">
<input name="classid" value="10000" type="HIDDEN" class="formElm" size="8" id="classid">
<input name="subclsid" value="27826" type="HIDDEN" class="formElm" size="8" id="subclsid">
<input name="tabid" value="11" type="HIDDEN" class="formElm" size="8" id="tabid">
<input name="viewid" value="0" type="HIDDEN" class="formElm" size="8" id="viewid">
<input name="displayMode" value="0" type="HIDDEN" class="formElm" size="8" id="displayMode">
<input name="refresh" value="false" type="HIDDEN" class="formElm" size="8" id="refresh">
<input name="pgWarnID" value="" type="HIDDEN" class="formElm" size="8" id="pgWarnID">
<input name="pgWarnCode" value="" type="HIDDEN" class="formElm" size="8" id="pgWarnCode">
<input name="warningString" value="" type="HIDDEN" class="formElm" size="8" id="warningString">
<input name="fullrev" value="" type="HIDDEN" class="formElm" size="8" id="fullrev">
<input name="process_actionId" value="" type="HIDDEN" class="formElm" size="8" id="process_actionId">
<input name="pageName" value="" type="HIDDEN" class="formElm" size="8" id="pageName">
<input name="formChanged" value="0" type="HIDDEN" class="formElm" size="8" id="formChanged">
<input name="currentToken" value="" type="HIDDEN" class="formElm" size="8" id="currentToken">
<input name="isTokenRequired" value="false" type="HIDDEN" class="formElm" size="8" id="isTokenRequired">
<input name="ContextName" value="19A1058701-01" type="HIDDEN" class="formElm" size="8" id="ContextName">
<input name="ContextType" value="19A NPb PCB/ENTEK" type="HIDDEN" class="formElm" size="8" id="ContextType">
<input name="helpID" value="1100" type="HIDDEN" class="formElm" size="8" id="helpID">
<input name="tableIds" value="5" type="HIDDEN" class="formElm" size="8" id="tableIds">
<input name="showTips" value="" type="HIDDEN" class="formElm" size="8" id="showTips">
<input name="refreshFromDB" value="" type="HIDDEN" class="formElm" size="8" id="refreshFromDB">
<input name="isPageDirty" value="" type="HIDDEN" class="formElm" size="8" id="isPageDirty">
<input name="iv" value="" type="HIDDEN" class="formElm" size="8" id="iv">
<!-- End Form Standard Attributes -->
<!-- Begin ModuleSpecific Form Attributes -->
<input name="cgToItemRevObjId" value="" type="HIDDEN" class="formElm" size="8" id="cgToItemRevObjId">
<input name="cgToItemRevClassId" value="" type="HIDDEN" class="formElm" size="8" id="cgToItemRevClassId">
<input name="cgToItemRevSiteId" value="" type="HIDDEN" class="formElm" size="8" id="cgToItemRevSiteId">
<input name="revchangeclass" value="6000" type="HIDDEN" class="formElm" size="8" id="revchangeclass">
<input name="revchangeid" value="447996547" type="HIDDEN" class="formElm" size="8" id="revchangeid">
<input name="siteId" value="-8" type="HIDDEN" class="formElm" size="8" id="siteId">
<input name="oldSiteId" value="-8" type="HIDDEN" class="formElm" size="8" id="oldSiteId">
<input name="siteOrRevChanged" value="" type="HIDDEN" class="formElm" size="8" id="siteOrRevChanged">
<input name="objectname" value="19A1058701-01" type="HIDDEN" class="formElm" size="8" id="objectname">
<input name="loadingMode" value="" type="HIDDEN" class="formElm" size="8" id="loadingMode">
<input name="expandLevel" value="" type="HIDDEN" class="formElm" size="8" id="expandLevel">
<input name="expandReferenceLevel" value="" type="HIDDEN" class="formElm" size="8" id="expandReferenceLevel">
<input name="rLeftPane" value="false" type="HIDDEN" class="formElm" size="8" id="rLeftPane">
<input name="objectname" value="19A1058701-01" type="HIDDEN" class="formElm" size="8" id="objectname">
<input name="sQueryId" value="false" type="HIDDEN" class="formElm" size="8" id="sQueryId">
<!-- End ModuleSpecific Form Attributes -->
</form><script>isPageLoading=false;</script>





</body></html>'''

# %%
for i in soup.select("#X_8_5"):
#     print(i.get_text())
    if re.search("SCHEMATIC\(PDF\)", i.get_text()):
        id = i.parent.parent.select("#X_1_5")[0].a.get('id')
        id_all = 'id=' + id
        print(id_all)
        break
# Out:
# id=R10_-5_5

# %%
for i in soup.select(".download-item"):
    print(i.a.get_text())
# Out:
# Win7 driver for AIMB-781
# WinXP driver for AIMB-781

# %%
for i in soup.select(".downloadItem"):
    print(i.h4.get_text())
    print(i.h5.a.get('href'))
# Out:
# AIMB-781_Chipset_win7(32&64bit)
# https://downloadt.advantech.com/download/downloadsr.aspx?File_Id=1-L21ZLB
# AIMB-781_Audio_win7(32&64bit)
# https://downloadt.advantech.com/download/downloadsr.aspx?File_Id=1-L22ZIN
# AIMB-781_Graphic_win7(32&64bit)
# https://downloadt.advantech.com/download/downloadsr.aspx?File_Id=1-L22ZIR
# AIMB-781_LAN_win7(32&64bit)
# https://downloadt.advantech.com/download/downloadsr.aspx?File_Id=1-L24OXR
# AIMB-781_Others_win7(32&64bit)
# https://downloadt.advantech.com/download/downloadsr.aspx?File_Id=1-L24OXU
#
# None

# %%
href = soup.select(".downloadItem")[0].a.get("href")

# %%
text ="123={}gsg{}".format(href,"ddd")

# %%
text
# Out:
# '123=https://downloadt.advantech.com/download/downloadsr.aspx?File_Id=1-L21ZLBgsgddd'

# %%
soup.select(".box-wrap")[1].get("id")
# Out:
# 'solution-1'

# %%
soup.select(".box-wrap")[1].div.get("class")
# Out:
# ['box-inner']

# %%
soup.select(".downloadItem")
# Out:
# [<div class="downloadItem clearfix">
#  <div class="downloadTXT">
#  <h4 class="downloadTitle">MIC-770V2_Chipset</h4>
#  <span class="date">2021-02-23</span>
#  <p></p>
#  </div>
#  <div class="btnWrap">
#  <h5 class="btn">
#  <a href="https://downloadt.advantech.com/download/downloadsr.aspx?File_Id=1-21MXUGP" target="_blank">Download</a>
#  </h5>
#  </div>
#  </div>,
#  <div class="downloadItem clearfix">
#  <div class="downloadTXT">
#  <h4 class="downloadTitle">MIC-770V2_AUDIO</h4>
#  <span class="date">2021-02-23</span>
#  <p></p>
#  </div>
#  <div class="btnWrap">
#  <h5 class="btn">
#  <a href="https://downloadt.advantech.com/download/downloadsr.aspx?File_Id=1-21MXURB" target="_blank">Download</a>
#  </h5>
#  </div>
#  </div>,
#  <div class="downloadItem clearfix">
#  <div class="downloadTXT">
#  <h4 class="downloadTitle">MIC-770V2_COM</h4>
#  <span class="date">2021-02-23</span>
#  <p></p>
#  </div>
#  <div class="btnWrap">
#  <h5 class="btn">
# ...

# %%
import asyncio
import time

async def say_after(delay, what):
    await asyncio.sleep(delay)
    print(what)

# %%
async def main():
    print(f"started at {time.strftime('%X')}")
    await say_after(1, 'hello')
    await say_after(2, 'world')
    print(f"finished at {time.strftime('%X')}")
await main()
# Out:
# started at 16:27:06
# hello
# world
# finished at 16:27:09

# %%
async def main():
    task1 = asyncio.create_task(
        say_after(1, 'hello'))

    task2 = asyncio.create_task(
        say_after(2, 'world'))

    print(f"started at {time.strftime('%X')}")

    # Wait until both tasks are completed (should take
    # around 2 seconds.)
    await task1
    await task2

    print(f"finished at {time.strftime('%X')}")
await main()
# Out:
# started at 16:28:41
# hello
# world
# finished at 16:28:43

# %%
def tt():
    print("1")
def yy():
    print("2")
for i in [tt(),yy()]:
    i
# Out:
# 1
# 2

# %%
if a == None:
    print(a)

# %%
for a in range(1,5):
    print(a)
# Out:
# 1
# 2
# 3
# 4

# %%
a = [1,2]
a = str(a)
a
# Out:
# '[1, 2]'
