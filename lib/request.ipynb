# %%
import requests
from bs4 import BeautifulSoup

# %%
href="https://downloadt.advantech.com/download/downloadsr.aspx?File_Id=1-21MXUGP"
response = requests.get(href, allow_redirects=True)
# d = response.headers
# d['content-disposition']

response.headers
# Out:
# {'Cache-Control': 'public, max-age=1209600', 'Content-Length': '3514856', 'Content-Type': 'application/zip', 'Content-MD5': 'B7OPjdibi0FXMq6OToXdcA==', 'Last-Modified': 'Thu, 15 Jul 2021 10:31:07 GMT', 'ETag': '0x8D9477BA816EFD2', 'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0', 'X-Cache': 'TCP_HIT', 'x-ms-request-id': 'b955837e-f01e-00c6-7d29-7ae853000000', 'x-ms-version': '2009-09-19', 'x-ms-lease-status': 'unlocked', 'x-ms-blob-type': 'BlockBlob', 'Access-Control-Expose-Headers': 'x-ms-request-id,Server,x-ms-version,Content-Type,Cache-Control,Last-Modified,ETag,Content-MD5,x-ms-lease-status,x-ms-blob-type,Content-Length,Date,Transfer-Encoding', 'Access-Control-Allow-Origin': '*', 'X-Azure-Ref-OriginShield': '0gVjxYAAAAABkSE4L0OQjQbo1wIqAw3jnSEsyRURHRTA1MTMANzU0NzBiZTAtMmIwOC00MTcwLTgwYTYtNDZiZmRjNTkyY2Fl', 'X-Azure-Ref': '06KLxYAAAAACmrKtviNFQSJPHJXJ5qEn+VFBFMzFFREdFMDgxMgA3NTQ3MGJlMC0yYjA4LTQxNzAtODBhNi00NmJmZGM1OTJjYWU=', 'Date': 'Fri, 16 Jul 2021 15:16:55 GMT'}

# %%
url = 'insert url'
response = requests.get(url, allow_redirects=True)
with open('filename.pdf') as pypdf:
    pypdf.write(response.content)

# %%
# result = requests.get('https://opendata.cwb.gov.tw/api/v1/rest/datastore/F-C0032-001?Authorization=CWB-5B414EA1-34DB-4168-8B56-7EBFE0BBACCF')
result = requests.get('https://weather.com/zh-TW/weather/today/l/fe7393b7f2c8eed2cf692bd079361df362d9f0c1c0f896e6e46a649295e15c7d')
soup = BeautifulSoup(result.text,'html.parser')

# %%
print(soup.body.prettify())
# Out:
# <body>
#  <div class="appWrapper DaybreakLargeScreen LargeScreen lightTheme DaybreakLargeScreen--appWrapper--3sKDm gradients--cloudyFoggyDay--1bU0n gradients--cloudyFoggyDay-top--2cO5u" id="appWrapper">
#   <div class="region-meta">
#    <div class="removeIfEmpty" id="WxuHtmlHead-meta-">
#    </div>
#    <div class="removeIfEmpty" id="WxuNewsroom-meta-bc9f40d5-d941-4fd8-bae2-2d8d63a38bb3">
#    </div>
#   </div>
#   <div class="region-topAds regionTopAds DaybreakLargeScreen--regionTopAds--2bh4V">
#    <div class="removeIfEmpty" id="WxuAd-topAds-53dce052-5465-4609-a555-c3a20ab64ab0">
#     <div class="adWrapper BaseAd--adWrapper--2_t07 BaseAd--card---Omy- BaseAd--hide--_au39">
#      <div class="adLabel">
#       Advertisement
#      </div>
#      <div class="ad_module BaseAd--ad_module--iBlaA subs-undefined BaseAd--placeholder--jHIDq" id="WX_Hidden">
#      </div>
#     </div>
#    </div>
#   </div>
# ...

# %% [markdown]
# # search all tag named div

# %%
soup.select('div')
# Out:
# [<div id="wra_bg">
#  <div id="wrapper">
#  <div class="container">
#  <div class="container_top">
#  <div class="logo"><img alt="亞東紀念醫院" height="96" src="../images/bg/logo.jpg" width="201"/><!-- logo--></div><div class="top_link"><!-- top_link-->
#  <table border="0" cellpadding="0" cellspacing="0" width="654">
#  <tr>
#  <td width="95"></td>
#  <td width="30"><a accesskey="U" href="https://www.femh.org.tw/sitemap/sitemap.aspx" style="font-size: .7em" title="上方選單連結區，鍵盤瀏覽按 Alt+U">:::</a></td>
#  <td width="80"><a href="https://hos.femh.org.tw/newfemh/NetFemhEn/index_about_xml.aspx?sub=5" onmouseout="MM_swapImgRestore()" onmouseover="MM_swapImage('english','','../images/top/english_s.jpg',1)"><img alt="english" border="0" height="31" id="english" name="english" src="../images/top/english.jpg" width="60"/></a></td>
# ...

# %%
soup.select('#style')
# Out:
# []

# %%
soup.select('#font-size:12px')
# Out:
# ---------------------------------------------------------------------------
# SelectorSyntaxError                       Traceback (most recent call last)
# <ipython-input-8-a7cc878691de> in <module>
# ----> 1 soup.select('#font-size:12px')
#
# ~\anaconda3\lib\site-packages\bs4\element.py in select(self, selector, namespaces, limit, **kwargs)
#    1867             )
#    1868
# -> 1869         results = soupsieve.select(selector, self, namespaces, limit, **kwargs)
#    1870
#    1871         # We do this because it's more consistent and because
#
# ~\anaconda3\lib\site-packages\soupsieve\__init__.py in select(select, tag, namespaces, limit, flags, **kwargs)
#      96     """Select the specified tags."""
#      97
# ---> 98     return compile(select, namespaces, flags, **kwargs).select(tag, limit)
#      99
#     100
#
# ~\anaconda3\lib\site-packages\soupsieve\__init__.py in compile(pattern, namespaces, flags, **kwargs)
#      60         return pattern
#      61
# ...

# %%
soup.select("title")
# Out:
# [<title data-react-helmet="true">臺北市天氣預報和天氣狀況—The Weather Channel | Weather.com </title>,
#  <title>The Weather Channel</title>,
#  <title>Search</title>,
#  <title>Globe</title>,
#  <title>Arrow down</title>,
#  <title>Arrow Down</title>,
#  <title>Arrow Down</title>,
#  <title>Arrow Down</title>,
#  <title>Arrow Down</title>,
#  <title>Arrow Down</title>,
#  <title>Mostly Cloudy</title>,
#  <title>Arrow Left</title>,
#  <title>Arrow Right</title>,
#  <title>Arrow down</title>,
#  <title>External Link</title>,
#  <title>Mostly Cloudy</title>,
#  <title>Mostly Cloudy</title>,
#  <title>Scattered Showers</title>,
#  <title>Cloudy</title>,
#  <title>Rain</title>,
#  <title>Mostly Cloudy Night</title>,
#  <title>Rain</title>,
#  <title>Daylight</title>,
#  <title>Sun Rise</title>,
#  <title>Sunset</title>,
#  <title>Temperature</title>,
#  <title>Wind</title>,
#  <title>Wind Direction</title>,
#  <title>Humidity</title>,
#  <title>Dew Point</title>,
#  <title>Pressure</title>,
# ...

# %% [markdown]
# # 搜索在body标签内部的a标签的div标签

# %%
soup.select("body a div")
# Out:
# [<div class="Column--temp--2v_go" data-testid="SegmentHighTemp"><span data-testid="TemperatureValue">29°</span></div>,
#  <div class="Column--icon--1fMZT"><svg aria-hidden="true" class="Icon--icon--2AbGu Icon--fullTheme--3jU2v" data-testid="Icon" role="img" set="weather" skycode="28" theme="full" viewbox="0 0 200 200"><title>Mostly Cloudy</title><use mask="url(#mostly-cloudy-mask)" transform="matrix(.56 0 0 .56 0 34)" xlink:href="#svg-symbol-sun"></use><use transform="matrix(1 0 0 1 2 62)" xlink:href="#svg-symbol-cloud-junior"></use><use transform="matrix(.9 0 0 .9 0 34)" xlink:href="#svg-symbol-cloud"></use></svg></div>,
#  <div class="Column--precip--2H5Iw" data-testid="SegmentPrecipPercentage"><span class="Column--precip--2H5Iw">--</span></div>,
#  <div class="Column--temp--2v_go" data-testid="SegmentHighTemp"><span data-testid="TemperatureValue">25°</span></div>,
# ...

# %% [markdown]
# # 获得所有class为footer的标签

# %%
soup.select(".footer")
# Out:
# [<div class="footer">
#  <table border="0" cellpadding="0" cellspacing="0" width="1005">
#  <tr>
#  <td class="left_line" height="119" valign="top"><table border="0" cellpadding="0" cellspacing="0">
#  <tr>
#  <td><p class="link"><a href="http://www.femh.org.tw/Q_naire/conta.aspx">顧客意見反映信箱</a></p><p class="link"><a href="http://www.femh.org.tw/Q_naire/default.aspx">服務滿意度問卷調查</a></p>
#  <p class="link"><a href="http://elearn.femh.org.tw/cltcms/ctms.do" target="_blank" title="亞東數位學習網(另開新視窗)">亞東數位學習網  </a></p><p class="link"><a href="http://depart.femh.org.tw/ml/" target="_blank" title="(另開新視窗)">明倫社會福利慈善基金會</a></p></td>
#  </tr>
#  </table></td>
#  <td class="left_line" valign="top"><table border="0" cellpadding="0" cellspacing="0">
#  <tr>
# ...

# %% [markdown]
# # 获得所有style="font-size:12px"

# %%
soup.select('[style="font-size:12px"]')
# Out:
# [<font style="font-size:12px">網路掛號<br/>--已約：5人<br/>--尚有餘額<br/>現場掛號<br/>--尚有餘額</font>,
#  <font style="font-size:12px">網路掛號<br/>--已約：14人<br/>--尚有餘額<br/>現場掛號<br/>--尚有餘額</font>,
#  <font style="font-size:12px">網路掛號<br/>--已約：14人<br/>--尚有餘額<br/>現場掛號<br/>--尚有餘額</font>,
#  <font style="font-size:12px">網路掛號<br/>--已約：9人<br/>--尚有餘額<br/>現場掛號<br/>--尚有餘額</font>,
#  <font style="font-size:12px">網路掛號<br/>--已約：3人<br/>--尚有餘額<br/>現場掛號<br/>--尚有餘額</font>,
#  <font style="font-size:12px">網路掛號<br/>--已約：10人<br/>--尚有餘額<br/>現場掛號<br/>--尚有餘額</font>,
#  <font style="font-size:12px">網路掛號<br/>--已約：18人<br/>--尚有餘額<br/>現場掛號<br/>--尚有餘額</font>,
#  <font style="font-size:12px">網路掛號<br/>--已約：5人<br/>--尚有餘額<br/>現場掛號<br/>--尚有餘額</font>,
#  <font style="font-size:12px">網路掛號<br/>--已約：0人<br/>--尚有餘額<br/>現場掛號<br/>--尚有餘額</font>,
#  <font style="font-size:12px">網路掛號<br/>--已約：6人<br/>--尚有餘額<br/>現場掛號<br/>--尚有餘額</font>,
#  <font style="font-size:12px">網路掛號<br/>--已約：6人<br/>--尚有餘額<br/>現場掛號<br/>--尚有餘額</font>,
# ...

# %% [markdown]
# # 获得所有href

# %%
soup.select('[href]')[:2]
# Out:
# [<link as="script" href="//s.w-x.co/static/confiant/confiant-tag.js" rel="preload"/>,
#  <link as="script" href="//c.amazon-adsystem.com/aax2/apstag.js" rel="preload"/>]

# %% [markdown]
# # 获得所有href的link

# %%
for i in soup.select('[href]')[:2]:
    print(i.get('href'))
# Out:
# //s.w-x.co/static/confiant/confiant-tag.js
# //c.amazon-adsystem.com/aax2/apstag.js

# %% [markdown]
# # 获得id="home"

# %%
soup.select("#home")
# Out:
# [<img alt="回首頁" border="0" height="37" id="home" name="home" src="../images/but/home.jpg" width="43"/>]

# %%
soup.select("a")
# Out:
# [<a accesskey="U" href="https://www.femh.org.tw/sitemap/sitemap.aspx" style="font-size: .7em" title="上方選單連結區，鍵盤瀏覽按 Alt+U">:::</a>,
#  <a href="https://hos.femh.org.tw/newfemh/NetFemhEn/index_about_xml.aspx?sub=5" onmouseout="MM_swapImgRestore()" onmouseover="MM_swapImage('english','','../images/top/english_s.jpg',1)"><img alt="english" border="0" height="31" id="english" name="english" src="../images/top/english.jpg" width="60"/></a>,
#  <a href="https://hos.femh.org.tw/newfemh/mobile/" onmouseout="MM_swapImgRestore()" onmouseover="MM_swapImage('mobile','','../images/top/mobile_s.jpg',1)"><img alt="行動版" border="0" height="31" id="mobile" name="mobile" src="../images/top/mobile.jpg" width="52"/></a>,
#  <a href="https://www.femh.org.tw/sitemap/sitemap.aspx" onmouseout="MM_swapImgRestore()" onmouseover="MM_swapImage('sitemap','','../images/top/sitemap_s.jpg',1)"><img alt="網站地圖" border="0" height="31" id="sitemap" name="sitemap" src="../images/top/sitemap.jpg" width="67"/></a>,
# ...

# %%
soup.select("p  a")
# Out:
# [<a href="http://www.femh.org.tw/Q_naire/conta.aspx">顧客意見反映信箱</a>,
#  <a href="http://www.femh.org.tw/Q_naire/default.aspx">服務滿意度問卷調查</a>,
#  <a href="http://elearn.femh.org.tw/cltcms/ctms.do" target="_blank" title="亞東數位學習網(另開新視窗)">亞東數位學習網  </a>,
#  <a href="http://depart.femh.org.tw/ml/" target="_blank" title="(另開新視窗)">明倫社會福利慈善基金會</a>,
#  <a href="http://www.femh.org.tw/job/job.aspx">人才招募 </a>,
#  <a href="http://depart.femh.org.tw/affairs/transfer/index.htm" target="_blank" title="轉診中心(另開新視窗)">轉診中心 </a>,
#  <a href="http://www.femh.org.tw/mainpage/contact.aspx">聯絡我們</a>,
#  <a href="http://www.femh.org.tw/sitemap/sitemap.aspx">網站導覽</a>]

# %%
soup.select("p")
# Out:
# [<p>網站快速導引：包含如何來亞東醫院、我想要網路掛號、查詢門診時間表、網路門診進度查詢、查詢醫師網頁、亞東最新消息、亞東行事曆、訂閱電子報、院長信箱</p>,
#  <p>Google Analytics (分析)</p>,
#  <p class="link"><a href="http://www.femh.org.tw/Q_naire/conta.aspx">顧客意見反映信箱</a></p>,
#  <p class="link"><a href="http://www.femh.org.tw/Q_naire/default.aspx">服務滿意度問卷調查</a></p>,
#  <p class="link"><a href="http://elearn.femh.org.tw/cltcms/ctms.do" target="_blank" title="亞東數位學習網(另開新視窗)">亞東數位學習網  </a></p>,
#  <p class="link"><a href="http://depart.femh.org.tw/ml/" target="_blank" title="(另開新視窗)">明倫社會福利慈善基金會</a></p>,
#  <p class="link"><a href="http://www.femh.org.tw/job/job.aspx">人才招募 </a></p>,
#  <p class="link"><a href="http://depart.femh.org.tw/affairs/transfer/index.htm" target="_blank" title="轉診中心(另開新視窗)">轉診中心 </a></p>,
#  <p class="link"><a href="http://www.femh.org.tw/mainpage/contact.aspx">聯絡我們</a></p>,
#  <p class="link"><a href="http://www.femh.org.tw/sitemap/sitemap.aspx">網站導覽</a></p>,
#  <p class="inf">院址：220新北市板橋區南雅南路二段21號</p>,
# ...
