# %%
from __future__ import print_function
import datetime
import os.path
# from googleapiclient.discovery import build
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import pandas as pd
import re

# ! pip install gspread_formatting
# import gspread to op google sheet
import gspread
from oauth2client.service_account import ServiceAccountCredentials

#gsprade_* for save and  get data from goole sheet
# from  import get_as_dataframe, set_with_dataframe
# from gspread_formatting.dataframe import format_with_dataframe

# %%
def save_to_gs():
        # --------------authorize google sheet---------------------
    scopes = ["https://spreadsheets.google.com/feeds"]
    credentials = ServiceAccountCredentials.from_json_keyfile_name("credentials_gs.json", scopes)
    gc = gspread.authorize(credentials)
#     sh = gc.open_by_key("1590Pln7GfV3vvcvvsRNLbMHJzM78Bmtnh9mvTpXBVi4")#juhao
#     sh = gc.open_by_key("1LMoh8cbY2-KdP40Z98DYGWs6r5Dd0aDJWSgxo2f6AII")#english word
    sh = gc.open_by_key("1_H56ZVPGKxAU00pSy4OE1lSZCFHRVCaj40ydWHLmBKY")#stock
#     sh = gc.open('note')
    note_index = sh.worksheet("index")
    return note_index

# %%
worksheet = save_to_gs()
sheet = worksheet.get_all_records()
sheet
# Out:
# [{'worksheet': 'note', 'key': '1_H56ZVPGKxAU00pSy4OE1lSZCFHRVCaj40ydWHLmBKY'},
#  {'worksheet': 'ATP', 'key': '10oKmncNypB_P5xxvc5_vkT65GUwyWFMHrh02Nocw73Q'},
#  {'worksheet': 'covid', 'key': '1SUwLkiMrhL0NkWyiZ1b6zYpfortcaF-mKsrRKypNRP0'},
#  {'worksheet': 'hospital',
#   'key': '1590Pln7GfV3vvcvvsRNLbMHJzM78Bmtnh9mvTpXBVi4'},
#  {'worksheet': 'Levent',
#   'key': '1xmrT8w3eRyuWne2UltG2Lgtw6N4ygYNQgW1x72d-f9s'},
#  {'worksheet': 'stock', 'key': '1zwoDKbf4g8oUmS8oOu_RtdDa7G5kVVG_9ruu8VNtyKw'},
#  {'worksheet': 'weather',
#   'key': '1VqJPzS8pA89MmzdqkYMyrROxQlNfdrtLH-XV2vNU-CU'},
#  {'worksheet': 'eng_word',
#   'key': '1LMoh8cbY2-KdP40Z98DYGWs6r5Dd0aDJWSgxo2f6AII'},
#  {'worksheet': 'clock', 'key': '1u7guGdA79_GGPF1sv5WHpJQH8ZFd0B9ndVGYREyemYQ'},
#  {'worksheet': 'eng_word1',
#   'key': '1CIdYxgMsUCJOOBD1LDbQGNdx7_Yrlo_rzw2263MPL10'}]

# %%
dataframe = pd.DataFrame(worksheet.get_all_records())
dataframe.set_index("worksheet", inplace=True)
dataframe.loc["ATP",'key']
# Out:
# '10oKmncNypB_P5xxvc5_vkT65GUwyWFMHrh02Nocw73Q'

# %%
dataframe
# Out:
#                                                     key
# worksheet
# note       1_H56ZVPGKxAU00pSy4OE1lSZCFHRVCaj40ydWHLmBKY
# ATP        10oKmncNypB_P5xxvc5_vkT65GUwyWFMHrh02Nocw73Q
# covid      1SUwLkiMrhL0NkWyiZ1b6zYpfortcaF-mKsrRKypNRP0
# hospital   1590Pln7GfV3vvcvvsRNLbMHJzM78Bmtnh9mvTpXBVi4
# Levent     1xmrT8w3eRyuWne2UltG2Lgtw6N4ygYNQgW1x72d-f9s
# stock      1zwoDKbf4g8oUmS8oOu_RtdDa7G5kVVG_9ruu8VNtyKw
# weather    1VqJPzS8pA89MmzdqkYMyrROxQlNfdrtLH-XV2vNU-CU
# eng_word   1LMoh8cbY2-KdP40Z98DYGWs6r5Dd0aDJWSgxo2f6AII
# clock      1u7guGdA79_GGPF1sv5WHpJQH8ZFd0B9ndVGYREyemYQ
# eng_word1  1CIdYxgMsUCJOOBD1LDbQGNdx7_Yrlo_rzw2263MPL10

# %%
worksheet.clear()
worksheet.update([{'worksheet': 'note', 'key': '1_H56ZVPGKxAU00pSy4OE1lSZCFHRVCaj40ydWHLmBKY'}])
# Out:
# {'spreadsheetId': '1_H56ZVPGKxAU00pSy4OE1lSZCFHRVCaj40ydWHLmBKY',
#  'clearedRange': 'index!A1:Z1001'}
# ---------------------------------------------------------------------------
# APIError                                  Traceback (most recent call last)
# <ipython-input-34-ed3ead14b3d2> in <module>
#       1 worksheet.clear()
# ----> 2 worksheet.update([{'worksheet': 'note', 'key': '1_H56ZVPGKxAU00pSy4OE1lSZCFHRVCaj40ydWHLmBKY'}])
#
# ~\.conda\envs\linebot\lib\site-packages\gspread\utils.py in wrapper(*args, **kwargs)
#     590                 kwargs.setdefault(k, v)
#     591
# --> 592             return f(*args, **kwargs)
#     593
#     594         return wrapper
#
# ~\.conda\envs\linebot\lib\site-packages\gspread\models.py in update(self, range_name, values, **kwargs)
#    1121         )
#    1122
# -> 1123         response = self.spreadsheet.values_update(
#    1124             range_name,
#    1125             params=params,
#
# ~\.conda\envs\linebot\lib\site-packages\gspread\models.py in values_update(self, range, params, body)
#     234         """
#     235         url = SPREADSHEET_VALUES_URL % (self.id, quote(range))
# --> 236         r = self.client.request('put', url, params=params, json=body)
#     237         return r.json()
#     238
#
# ~\.conda\envs\linebot\lib\site-packages\gspread\client.py in request(self, method, endpoint, params, data, json, files, headers)
#      74             return response
#      75         else:
# ---> 76             raise APIError(response)
#      77
#      78     def list_spreadsheet_files(self, title=None):
#
# APIError: {'code': 400, 'message': 'Invalid JSON payload received. Unknown name "worksheet" at \'data.values[0]\': Cannot find field.\nInvalid JSON payload received. Unknown name "key" at \'data.values[0]\': Cannot find field.', 'status': 'INVALID_ARGUMENT', 'details': [{'@type': 'type.googleapis.com/google.rpc.BadRequest', 'fieldViolations': [{'field': 'data.values[0]', 'description': 'Invalid JSON payload received. Unknown name "worksheet" at \'data.values[0]\': Cannot find field.'}, {'field': 'data.values[0]', 'description': 'Invalid JSON payload received. Unknown name "key" at \'data.values[0]\': Cannot find field.'}]}]}

# %% [markdown]
# # https://gspread.readthedocs.io/en/latest/user-guide.html#creating-a-worksheet

# %%
val = worksheet.acell('B2').value
type(val)
# Out:
# str

# %%
val = worksheet.cell(1, 3).value
val
# Out:
# 'Links 1'

# %%
cell = worksheet.acell('A1', value_render_option='FORMULA').value

# %%
cell
# Out:
# '=A4 +1+1+3'

# %% [markdown]
# # 取得一列column的所有值

# %%
values_list = worksheet.col_values(2)
values_list
# Out:
# ['Group 1',
#  'abound',
#  'amorphous',
#  'austere',
#  'belie',
#  'capricious',
#  'cerebral',
#  'congenial',
#  'conspicuous',
#  'cursory',
#  'daunting',
#  'deify',
#  'didactic',
#  'disseminate',
#  'feasible',
#  'flout',
#  'homogeneous',
#  'humdrum',
#  'insipid',
#  'loquacious',
#  'misanthropic',
#  'misnomer',
#  'negligent',
#  'obsequious',
#  'placate',
#  'proclivity',
#  'puerile',
#  'quixotic',
#  'spendthrift',
#  'taciturn',
#  'wary',
#  '',
#  'Group 2',
#  'adulterate',
#  'advocate',
#  'aggrandize',
#  'alacrity',
#  'ambivalent',
#  'ameliorate',
#  'amenable',
#  'anachronistic',
#  'audacious',
#  'avaricious',
#  'banal',
#  'benign',
#  'brazen',
#  'calumny',
#  'candid',
#  'castigate',
#  'caustic',
#  'construe',
#  'contrite',
#  'convoluted',
#  'covet',
#  'craven',
#  'decorum',
#  'deft',
#  'demur',
#  'derivative',
#  'desiccate',
#  'diatribe',
#  'incredulous',
#  'ingenuous',
#  '',
#  'Group 3',
#  'abate',
#  'abjure',
#  'anomalous',
#  'antipathy',
#  'arcane',
#  'arduous',
#  'artless',
#  'ascetic',
#  'assuage',
#  'betray',
#  'bucolic',
#  'burgeon',
#  'cacophonous',
#  'canonize',
#  'censure',
#  'chicanery',
#  'coalesce',
#  'cogent',
#  'compelling',
#  'contend',
#  'copious',
#  'cosmopolitan',
#  'deference',
#  'desultory',
#  'diffident',
#  'dilatory',
#  'equivocate',
#  'polarize',
#  'prodigal',
#  'verbose',
#  '',
#  'Group 4',
#  'abstain',
#  'approbation',
#  'cherish',
#  'corroborate',
#  'disparate',
#  'emulate',
#  'enervate',
#  'ephemeral',
#  'fervid',
#  'garrulous',
#  'incendiary',
#  'inimical',
#  'intimate',
#  'invigorate',
#  'mitigate',
#  'obsolete',
#  'opaque',
#  'paradigmatic',
#  'pedantic',
#  'placid',
#  'polemical',
#  'precipitate',
#  'profundity',
#  'prophetic',
#  'prudent',
#  'punctilious',
#  'recondite',
#  'scrupulous',
#  'tranquil',
#  'vacillate',
#  '',
#  'Group 5',
#  'aloof',
#  'clangor',
#  'conventional',
#  'debunk',
#  'diminutive',
#  'discernible',
#  'enigmatic',
#  'estranged',
#  'extravagant',
#  'fanciful',
#  'frivolous',
#  'heterogeneous',
#  'imperious',
#  'impertinent',
#  'invasive',
#  'irresolute',
#  'laudable',
#  'lax',
#  'marginalize',
#  'panache',
#  'plodding',
#  'prosaic',
#  'remedial',
#  'restive',
#  'sporadic',
#  'stigmatize',
#  'undermine',
#  'utterly',
#  'weary',
#  'zealous',
#  '',
#  'Group 6',
#  'admonish',
#  'aesthetic',
#  'affectation',
#  'alleviate',
#  'analogous',
#  'bolster',
#  'chauvinistic',
#  'connoisseur',
#  'dissemble',
#  'dogged',
#  'dupe',
#  'empirical',
#  'engender',
#  'entitled',
#  'pertinacious',
#  'presumptuous',
#  'probity',
#  'proliferate',
#  'specious',
#  'spurious',
#  'subjective',
#  'subvert',
#  'timorous',
#  'tortuous',
#  'tractable',
#  'transient',
#  'ubiquitous',
#  'underscore',
#  'venal',
#  'venerate',
#  '',
#  'Group 7',
#  'appease',
#  'arbitrary',
#  'archaic',
#  'clamorous',
#  'dearth',
#  'explicable',
#  'hyperbole',
#  'immutable',
#  'indefatigable',
#  'indolent',
#  'insular',
#  'intransigent',
#  'intrepid',
#  'irreverent',
#  'loathe',
#  'malign',
#  'malleable',
#  'neophyte',
#  'plastic',
#  'platitude',
#  'prescient',
#  'pristine',
#  'reproach',
#  'robust',
#  'salubrious',
#  'sanction',
#  'sedulous',
#  'soporific',
#  'stern',
#  'tendentious',
#  '',
#  'Group 8',
#  'accentuate',
#  'conjectural',
#  'convivial',
#  'decadent',
#  'egregious',
#  'evanescent',
#  'flamboyant',
#  'forestall',
#  'gainsay',
#  'galvanize',
#  'indiscriminate',
#  'innocuous',
#  'momentary',
#  'mundane',
#  'nettlesome',
#  'nullify',
#  'obviate',
#  'omnipresent',
#  'oust',
#  'palpable',
#  'perfidy',
#  'profuse',
#  'pugnacious',
#  'sagacious',
#  'sanguine',
#  'scant',
#  'skullduggery',
#  'trivial',
#  'utilitarian',
#  'vapid',
#  '',
#  'Group 9',
#  'boorish',
#  'brook',
#  'circumspect',
#  'comity',
#  'commensurate',
#  'cordial',
#  'deleterious',
#  'dichotomy',
#  'edify',
#  'elicit',
#  'erudite',
#  'fecund',
#  'feeble',
#  'felicitous',
#  'forbear',
#  'haphazard',
#  'hodgepodge',
#  'impede',
#  'impetuous',
#  'irascible',
#  'mercenary',
#  'meticulous',
#  'mordant',
#  'outstrip',
#  'precarious',
#  'quirky',
#  'repudiate',
#  'tact',
#  'trifling',
#  'turbulent',
#  '',
#  'Group 10',
#  'acumen',
#  'antithesis',
#  'ascribe',
#  'befuddled',
#  'eschew',
#  'esoteric',
#  'evasive',
#  'exculpate',
#  'expedite',
#  'fastidious',
#  'feign',
#  'furtive',
#  'hamper',
#  'indispensable',
#  'lament',
#  'myopic',
#  'nonchalant',
#  'partial',
#  'pensive',
#  'portend',
#  'provincial',
#  'rudimentary',
#  'salutary',
#  'sever',
#  'slight',
#  'somnolent',
#  'stoic',
#  'supersede',
#  'tout',
#  'wane',
#  '',
#  'Group 11',
#  'abhor',
#  'boisterous',
#  'chivalrous',
#  'churlish',
#  'clandestine',
#  'complacent',
#  'cumbersome',
#  'debilitating',
#  'deliberate',
#  'droll',
#  'eccentric',
#  'fractious',
#  'limpid',
#  'mawkish',
#  'obeisance',
#  'ostentatious',
#  'panacea',
#  'perfunctory',
#  'perilous',
#  'pervasive',
#  'preclude',
#  'predilection',
#  'rapacious',
#  'relish',
#  'satirical',
#  'sham',
#  'skirt',
#  'sluggish',
#  'spartan',
#  'truculent',
#  '',
#  'Group 12',
#  'acrimonious',
#  'belligerent',
#  'beneficent',
#  'canny',
#  'cavalier',
#  'distressed',
#  'dwindling',
#  'eclipse',
#  'encyclopedic',
#  'exacerbate',
#  'exasperated',
#  'fungible',
#  'hackneyed',
#  'incongruous',
#  'interchangeable',
#  'laconic',
#  'lucrative',
#  'magisterial',
#  'onerous',
#  'opprobrium',
#  'parsimonious',
#  'peripheral',
#  'provocative',
#  'renounce',
#  'tempestuous',
#  'tenable',
#  'transgression',
#  'urbane',
#  'verisimilitude',
#  'vitiate',
#  '',
#  'Group 13',
#  'affinity',
#  'altruistic',
#  'baroque',
#  'byzantine',
#  'compromise',
#  'conciliatory',
#  'countenance',
#  'covert',
#  'credible',
#  'diffuse',
#  'documentary',
#  'exhaustive',
#  'exhilarating',
#  'extraneous',
#  'fervor',
#  'futile',
#  'illusory',
#  'invidious',
#  'lethargic',
#  'metaphorical',
#  'mimic',
#  'numinous',
#  'obscure',
#  'overt',
#  'pellucid',
#  'perpetuate',
#  'rational',
#  'scathing',
#  'subtle',
#  'superficial',
#  '',
#  'Group 14',
#  'acquiesce',
#  'adroit',
#  'amend',
#  'animus',
#  'apologist',
#  'astringent',
#  'collaborate',
#  'competent',
#  'correlate',
#  'deride',
#  'dictate',
#  'discreet',
#  'divorced',
#  'elitist',
#  'exacting',
#  'flummoxed',
#  'fruitful',
#  'inborn',
#  'polymath',
#  'reticent',
#  'stringent',
#  'subservient',
#  'surreptitious',
#  'tantalizing',
#  'tantamount',
#  'torpor',
#  'trenchant',
#  'umbrage',
#  'versatile',
#  'wayward',
#  '',
#  'Group 15',
#  'alienate',
#  'apathy',
#  'apropos',
#  'apt',
#  'cloak',
#  'consensus',
#  'distort',
#  'divergent',
#  'elated',
#  'enchant',
#  'entrenched',
#  'exotic',
#  'exploitative',
#  'foreseeable',
#  'forsake',
#  'gratify',
#  'heed',
#  'judicious',
#  'lucid',
#  'pertinent',
#  'propriety',
#  'scintillating',
#  'sensational',
#  'sophisticated',
#  'strife',
#  'understated',
#  'unscrupulous',
#  'veracity',
#  'virulent',
#  'volatile',
#  '',
#  'Group 16',
#  'antedate',
#  'banish',
#  'bridle',
#  'comply',
#  'crestfallen',
#  'curtail',
#  'elucidate',
#  'evade',
#  'feckless',
#  'fester',
#  'iconoclastic',
#  'immure',
#  'improvise',
#  'inhibit',
#  'inscrutable',
#  'lionize',
#  'monotonous',
#  'peculiar',
#  'premeditate',
#  'profligate',
#  'reconcile',
#  'refine',
#  'relinquish',
#  'ruminate',
#  'skittish',
#  'superfluous',
#  'synoptic',
#  'thorough',
#  'visionary',
#  'vociferous',
#  '',
#  'Group 17',
#  'acclaim',
#  'ascertain',
#  'assertive',
#  'bogus',
#  'cataclysmic',
#  'circumscribe',
#  'complementary',
#  'contentious',
#  'disingenuous',
#  'divulge',
#  'dogmatic',
#  'fallacious',
#  'foolhardy',
#  'hinder',
#  'impair',
#  'impugn',
#  'incessant',
#  'inclined',
#  'inveterate',
#  'miserly',
#  'patent',
#  'petulant',
#  'pithy',
#  'pliant',
#  'sanctimonious',
#  'sound',
#  'tarnish',
#  'tepid',
#  'upbraid',
#  'vexation',
#  '',
#  'Group 18',
#  'abet',
#  'accessible',
#  'acquisitive',
#  'amalgamate',
#  'attenuate',
#  'augment',
#  'aversion',
#  'blithe',
#  'contempt',
#  'dawdle',
#  'deflect',
#  'discount',
#  'dissident',
#  'efficacious',
#  'equitable',
#  'erratic',
#  'industrious',
#  'inform',
#  'irksome',
#  'manacle',
#  'modest',
#  'noxious',
#  'pernicious',
#  'predicament',
#  'proficient',
#  'prolix',
#  'scorn',
#  'subordinate',
#  'unseemly',
#  'veritable',
#  '',
#  'Group 19',
#  'acolyte',
#  'anoint',
#  'base',
#  'coercion',
#  'coin',
#  'cunning',
#  'discomfit',
#  'dissent',
#  'distill',
#  'dubious',
#  'ebullient',
#  'facetious',
#  'fallible',
#  'florid',
#  'gawky',
#  'inveigle',
#  'jettison',
#  'mendacity',
#  'munificent',
#  'naive',
#  'noble',
#  'parochial',
#  'pedestrian',
#  'prevaricate',
#  'prime',
#  'radical',
#  'recrudescent',
#  'temporal',
#  'transitory',
#  'viable',
#  '',
#  'Group 20',
#  'abreast',
#  'confound',
#  'digression',
#  'discrepancy',
#  'duplicitous',
#  'expedient',
#  'fabricate',
#  'glum',
#  'harbinger',
#  'intrinsic',
#  'largesse',
#  'libertine',
#  'malfeasance',
#  'manifest',
#  'minute',
#  'modish',
#  'nascent',
#  'perennial',
#  'pious',
#  'providential',
#  'prowess',
#  'schism',
#  'slander',
#  'stalwart',
#  'supplicate',
#  'terse',
#  'tirade',
#  'universal',
#  'vanquish',
#  'woeful',
#  '',
#  'Group 21',
#  'abject',
#  'amicable',
#  'animosity',
#  'aver',
#  'barrage',
#  'cathartic',
#  'decipher',
#  'delusion',
#  'dispense',
#  'eloquent',
#  'enthrall',
#  'eradicate',
#  'fledgling',
#  'fortitude',
#  'fortuitous',
#  'goad',
#  'imminent',
#  'incontrovertible',
#  'itinerant',
#  'magnanimous',
#  'meritorious',
#  'mutiny',
#  'paradoxical',
#  'perseverance',
#  'render',
#  'repertoire',
#  'resilient',
#  'resolute',
#  'supple',
#  'valor',
#  '',
#  'Group 22',
#  'cumbersome',
#  'unprecedented',
#  'stinting',
#  'extrapolate',
#  'liability',
#  'euphoric',
#  'elementary',
#  'heterodox',
#  'fervent',
#  'gaffe',
#  'temper',
#  'painstaking',
#  'economy',
#  'qualm',
#  'exonerate',
#  'implicit',
#  'phlegmatic',
#  'propensity',
#  'foment',
#  'embellish',
#  'inviolate',
#  'renege',
#  'arresting',
#  'obstinate',
#  'vivacious',
#  'histrionic',
#  'prodigious',
#  'tentative',
#  'falter',
#  'chastise',
#  '',
#  'Group 23',
#  'intermittent',
#  'profound',
#  'propagate',
#  'allusive',
#  'glib',
#  'curb',
#  'lull',
#  'mettlesome',
#  'astute',
#  'fawn',
#  'precipitous',
#  'repercussion',
#  'regress',
#  'refute',
#  'replenish',
#  'evoke',
#  'ire',
#  'languid',
#  'mollify',
#  'pretentious',
#  'duress',
#  'vigilant',
#  'headstrong',
#  'convalescent',
#  'nonplussed',
#  'fret',
#  'decry',
#  'recourse',
#  'commence',
#  'neutralize',
#  '',
#  'Group 24',
#  'exorcise',
#  'finicky',
#  'assail',
#  'contravene',
#  'reiterate',
#  'poignant',
#  'inundate',
#  'oblivious',
#  'ironclad',
#  'plaintive',
#  'surmount',
#  'escalate',
#  'denounce',
#  'foil',
#  'deviate',
#  'buoyant',
#  'benevolent',
#  'intertwined',
#  'berate',
#  'quiescent',
#  'mercurial',
#  'despotic',
#  'perpetrate',
#  'subsume',
#  'subside',
#  'condone',
#  'tangential',
#  'jeopardize',
#  'disinterested',
#  'buttress',
#  '',
#  'Group 25',
#  'bereft',
#  'frailty',
#  'disentangle',
#  'pomposity',
#  'delineate',
#  'conclusive',
#  'vitality',
#  'steadfast',
#  'archetype',
#  'relent',
#  'grievance',
#  'harangue',
#  'auspicious',
#  'yield',
#  'appropriate',
#  'rhetoric',
#  'conspire',
#  'whimsical',
#  'proxy',
#  'sparse',
#  'adverse',
#  'exhort',
#  'poise',
#  'adept',
#  'tedious',
#  'rigor',
#  'articulate',
#  'suspect',
#  'ploy',
#  'captious',
#  '',
#  'Group 26',
#  'lugubrious',
#  'transcend',
#  'flustered',
#  'incidental',
#  'axiomatic',
#  'macabre',
#  'gullible',
#  'ingrained',
#  'tacit',
#  'exorbitant',
#  'serene',
#  'treatise',
#  'corporeal',
#  'figurative',
#  'morose',
#  'fickle',
#  'ramification',
#  'eclectic',
#  'apprehension',
#  'idiosyncratic',
#  'insolent',
#  'ardent',
#  'doctrinaire',
#  'officious',
#  'cease',
#  'lavish',
#  'conducive',
#  'equanimity',
#  'supplant',
#  'lampoon',
#  '',
#  'Group 27',
#  'bombastic',
#  'lambaste',
#  'undercut',
#  'euphemism',
#  'turpitude',
#  'peccadillo',
#  'antagonize',
#  'barren',
#  'philistine',
#  'relegate',
#  'dirge',
#  'imperturbable',
#  'excoriate',
#  'curmudgeon',
#  'swindle',
#  'wheedle',
#  'sentimental',
#  'miscreant',
#  'implacable',
#  'haughty',
#  'estimable',
#  'tangible',
#  'chary',
#  'repugnant',
#  'xenophobic',
#  'squander',
#  'cajole',
#  'unalloyed',
#  'heady',
#  'exigent',
#  '',
#  'Group 28',
#  'hysterical',
#  'endemic',
#  'disdain',
#  'quash',
#  'august',
#  'quibble',
#  'recant',
#  'inchoate',
#  'abeyance',
#  'redoubtable',
#  'coy',
#  'disperse',
#  'shrill',
#  'impudent',
#  'burnish',
#  'wily',
#  'quandary',
#  'enmity',
#  'substantiate',
#  'agitate',
#  'abstract',
#  'retiring',
#  'quarantine',
#  'distend',
#  'ravage',
#  'sophistry',
#  'penchant',
#  'gauche',
#  'deprecate',
#  'affront']

# %% [markdown]
# # 取得一列column的所有值

# %%
values_list = worksheet.row_values(2)
values_list
# Out:
# ['0',
#  'abound',
#  'https://www.youtube.com/watch?v=6kp2K467kLE',
#  "{'Verb': ['be abundant or plentiful; exist in large quantities', 'be in a state of movement or action']}"]

# %% [markdown]
# # 取得所有值

# %%
values_list = worksheet.get_all_values() #list
values_list
# Out:
# [['CLICK ME!', 'Group 1', 'Links 1', 'Meaning 1'],
#  ['0',
#   'abound',
#   'https://www.youtube.com/watch?v=6kp2K467kLE',
#   "{'Verb': ['be abundant or plentiful; exist in large quantities', 'be in a state of movement or action']}"],
#  ['1',
#   'amorphous',
#   'https://www.youtube.com/watch?v=jQXQdMWWwuw',
#   "{'Adjective': ['having no definite form or distinct shape', 'lacking the system or structure characteristic of living bodies', '(of a group of people or an organization', 'unclear because vague or badly organized', 'without real or apparent crystalline form']}"],
#  ['2',
#   'austere',
#   'https://www.youtube.com/watch?v=pjt67GZngDQ',
#   "{'Adjective': ['severely simple', 'of a stern or strict bearing or demeanor; forbidding in aspect', 'practicing great self-denial']}"],
#  ['3',
#   'belie',
#   'https://www.youtube.com/watch?v=f1m0XNCbwko',
#   "{'Verb': ['be in contradiction with', 'represent falsely']}"],
#  ['4',
#   'capricious',
#   'https://www.youtube.com/watch?v=MMXQlz7IFp4',
#   "{'Adjective': ['changeable', 'determined by chance or impulse or whim rather than by necessity or reason']}"],
#  ['5',
#   'cerebral',
#   'https://www.youtube.com/watch?v=ZyVUMe3Zn30',
#   "{'Adjective': ['involving intelligence rather than emotions or instinct', 'of or relating to the cerebrum or brain']}"],
#  ['6',
#   'congenial',
#   'https://www.youtube.com/watch?v=cPYMl_a0QB8',
#   "{'Adjective': ['suitable to your needs', '(used of plants']}"],
#  ['7',
#   'conspicuous',
#   'https://www.youtube.com/watch?v=lYsY7qOtH-M',
#   "{'Adjective': ['obvious to the eye or mind', 'without any attempt at concealment; completely obvious']}"],
#  ['8',
#   'cursory',
#   'https://www.youtube.com/watch?v=J2zTykFJ010',
#   "{'Adjective': ['hasty and without attention to detail; not thorough', 'or cursory']}"],
#  ['9',
#   'daunting',
#   'https://www.youtube.com/watch?v=L2P9zmCPYa4',
#   "{'Verb': ['cause to lose courage'], 'Adjective': ['discouraging through fear']}"],
#  ['10',
#   'deify',
#   'https://www.youtube.com/watch?v=0Pirai2nXew',
#   "{'Verb': ['consider as a god or godlike', 'exalt to the position of a God']}"],
#  ['11',
#   'didactic',
#   'https://www.youtube.com/watch?v=xJPQGNBtobI',
#   "{'Adjective': ['instructive (especially excessively']}"],
#  ['12',
#   'disseminate',
#   'https://www.youtube.com/watch?v=JlnuzGCDjOY',
#   "{'Verb': ['cause to become widely known']}"],
#  ['13',
#   'feasible',
#   'https://www.youtube.com/watch?v=eSN87FHRj_4',
#   "{'Adjective': ['capable of being done with means at hand and circumstances as they are']}"],
#  ['14',
#   'flout',
#   'https://www.youtube.com/watch?v=2hpMW2DCQSA',
#   "{'Verb': ['treat with contemptuous disregard', 'laugh at with contempt and derision']}"],
#  ['15',
#   'homogeneous',
#   'https://www.youtube.com/watch?v=tjUZ1zvIrcA',
#   "{'Adjective': ['all of the same or similar kind or nature']}"],
#  ['16',
#   'humdrum',
#   'https://www.youtube.com/watch?v=WRsyw4Of7gA',
#   "{'Noun': ['the quality of wearisome constancy, routine, and lack of variety'], 'Adjective': ['not challenging; dull and lacking excitement', 'tediously repetitious or lacking in variety']}"],
#  ['17',
#   'insipid',
#   'https://www.youtube.com/watch?v=6iweYQXrWUI',
#   "{'Adjective': ['lacking taste or flavor or tang', 'lacking interest or significance or impact']}"],
#  ['18',
#   'loquacious',
#   'https://www.youtube.com/watch?v=WYCtqOre6HA',
#   "{'Adjective': ['full of trivial conversation']}"],
#  ['19',
#   'misanthropic',
#   'https://www.youtube.com/watch?v=4hQrCpJkcM4',
#   "{'Adjective': ['believing the worst of human nature and motives; having a sneering disbelief in e.g. selflessness of others', 'hating mankind in general']}"],
#  ['20',
#   'misnomer',
#   'https://www.youtube.com/watch?v=33KD8MaNeL0',
#   "{'Noun': ['an incorrect or unsuitable name']}"],
#  ['21', 'negligent', 'https://www.youtube.com/watch?v=KRqwN2qGFJw', ''],
#  ['22',
#   'obsequious',
#   'https://www.youtube.com/watch?v=8cvDhqKSjcw',
#   "{'Adjective': ['attempting to win favor from influential people by flattery', 'attentive in an ingratiating or servile manner']}"],
#  ['23',
#   'placate',
#   'https://www.youtube.com/watch?v=5KPELNjXPzE',
#   "{'Verb': ['cause to be more favorably inclined; gain the good will of']}"],
#  ['24',
#   'proclivity',
#   'https://www.youtube.com/watch?v=NrbLtDjPRI4',
#   "{'Noun': ['a natural inclination']}"],
#  ['25',
#   'puerile',
#   'https://www.youtube.com/watch?v=uDwla695xVM',
#   "{'Adjective': ['of or characteristic of a child', 'displaying or suggesting a lack of maturity']}"],
#  ['26',
#   'quixotic',
#   'https://www.youtube.com/watch?v=yqzVl7q-O4Q',
#   "{'Adjective': ['not sensible about practical matters; idealistic and unrealistic']}"],
#  ['27',
#   'spendthrift',
#   'https://www.youtube.com/watch?v=--cqwqrcgXk',
#   "{'Noun': ['someone who spends money prodigally'], 'Adjective': ['recklessly wasteful']}"],
#  ['28',
#   'taciturn',
#   'https://www.youtube.com/watch?v=W3CYtkDs9qY',
#   "{'Adjective': ['habitually reserved and uncommunicative']}"],
#  ['29',
#   'wary',
#   'https://www.youtube.com/watch?v=arRvJ8dgnkY',
#   "{'Adjective': ['marked by keen caution and watchful prudence', 'openly distrustful and unwilling to confide']}"],
#  ['', '', '', ''],
#  ['', 'Group 2', 'Links 2', 'Meaning 2'],
#  ['0',
#   'adulterate',
#   'https://www.youtube.com/watch?v=WN3Tmauj7kQ',
#   "{'Verb': ['corrupt, debase, or make impure by adding a foreign or inferior substance; often by replacing valuable ingredients with inferior ones'], 'Adjective': ['mixed with impurities']}"],
#  ['1',
#   'advocate',
#   'https://www.youtube.com/watch?v=IGTlWtFD87E',
#   "{'Noun': ['a person who pleads for a cause or propounds an idea', 'a lawyer who pleads cases in court'], 'Verb': ['push for something', 'speak, plead, or argue in favor of']}"],
#  ['2',
#   'aggrandize',
#   'https://www.youtube.com/watch?v=GxSyKNxLbNQ',
#   "{'Verb': ['add details to']}"],
#  ['3',
#   'alacrity',
#   'https://www.youtube.com/watch?v=oJ4h3r68S6Q',
#   "{'Noun': ['liveliness and eagerness']}"],
#  ['4',
#   'ambivalent',
#   'https://www.youtube.com/watch?v=H9Gnqf2gGcs',
#   "{'Adjective': ['uncertain or unable to decide about what course to follow']}"],
#  ['5',
#   'ameliorate',
#   'https://www.youtube.com/watch?v=iCMOMeDy4Ys',
#   "{'Verb': ['to make better', 'get better']}"],
#  ['6',
#   'amenable',
#   'https://www.youtube.com/watch?v=9y7MS37_PdM',
#   "{'Adjective': ['disposed or willing to conform', 'responsive to suggestions and influences', 'open to being acted upon in a certain way', 'liable to answer to a higher authority']}"],
#  ['7',
#   'anachronistic',
#   'https://www.youtube.com/watch?v=iJL4tTK1mqg',
#   "{'Adjective': ['chronologically misplaced']}"],
#  ['8',
#   'audacious',
#   'https://www.youtube.com/watch?v=8SaOEWiwPo8',
#   "{'Adjective': ['invulnerable to fear or intimidation', 'unrestrained by convention or propriety', 'disposed to venture or take risks']}"],
#  ['9',
#   'avaricious',
#   'https://www.youtube.com/watch?v=yOO2UDhMCR0',
#   "{'Adjective': ['immoderately desirous of acquiring e.g. wealth']}"],
#  ['10',
#   'banal',
#   'https://www.youtube.com/watch?v=5w24Bs3b_Mw',
#   "{'Adjective': ['repeated too often; overfamiliar through overuse']}"],
#  ['11',
#   'benign',
#   'https://www.youtube.com/watch?v=GBqql6u4laI',
#   "{'Adjective': ['not dangerous to health; not recurrent or progressive (especially of a tumor', 'pleasant and beneficial in nature or influence', 'kindness of disposition or manner']}"],
#  ['12',
#   'brazen',
#   'https://www.youtube.com/watch?v=cSYgLXz4KKA',
#   "{'Verb': ['face with defiance or impudence'], 'Adjective': ['unrestrained by convention or propriety', 'made of or resembling brass (as in color or hardness']}"],
#  ['13',
#   'calumny',
#   'https://www.youtube.com/watch?v=hAn4Tkg0EQA',
#   '{\'Noun\': ["a false accusation of an offense or a malicious misrepresentation of someone\'s words or actions", "an abusive attack on a person\'s character or good name"]}'],
#  ['14',
#   'candid',
#   'https://www.youtube.com/watch?v=WGsy2ORWnG4',
#   "{'Adjective': ['characterized by directness in manner or speech; without subtlety or evasion', 'informal or natural; especially caught off guard or unprepared', 'openly straightforward and direct without reserve or secretiveness']}"],
#  ['15',
#   'castigate',
#   'https://www.youtube.com/watch?v=HOMML7IwdK4',
#   "{'Verb': ['censure severely', 'inflict severe punishment on']}"],
#  ['16',
#   'caustic',
#   'https://www.youtube.com/watch?v=w1_djifAXVU',
#   "{'Noun': ['any chemical substance that burns or destroys living tissue'], 'Adjective': ['harsh or corrosive in tone', 'of a substance, especially a strong acid; capable of destroying or eating away by chemical action']}"],
#  ['17',
#   'construe',
#   'https://www.youtube.com/watch?v=Hw8Mul2FmtY',
#   "{'Verb': ['make sense of; assign a meaning to']}"],
#  ['18',
#   'contrite',
#   'https://www.youtube.com/watch?v=eu5ORKLNP5k',
#   "{'Adjective': ['feeling or expressing pain or sorrow for sins or offenses']}"],
#  ['19',
#   'convoluted',
#   'https://www.youtube.com/watch?v=ZCmo0C5WCh0',
#   "{'Verb': ['curl, wind, or twist together', 'practice sophistry; change the meaning of or be vague about in order to mislead or deceive'], 'Adjective': ['rolled longitudinally upon itself', 'highly complex or intricate and occasionally devious']}"],
#  ['20',
#   'covet',
#   'https://www.youtube.com/watch?v=T23Olkjggj0',
#   "{'Verb': ['wish, long, or crave for (something, especially the property of another person']}"],
#  ['21',
#   'craven',
#   'https://www.youtube.com/watch?v=vju6jmFv3xo',
#   "{'Noun': ['an abject coward'], 'Adjective': ['lacking even the rudiments of courage; abjectly fearful']}"],
#  ['22',
#   'decorum',
#   'https://www.youtube.com/watch?v=MNWrDY_OzE0',
#   "{'Noun': ['propriety in manners and conduct']}"],
#  ['23',
#   'deft',
#   'https://www.youtube.com/watch?v=VtaqiWBi4Xw',
#   "{'Adjective': ['skillful in physical movements; especially of the hands']}"],
#  ['24',
#   'demur',
#   'https://www.youtube.com/watch?v=iWbxj2YdiUI',
#   "{'Noun': [], 'Verb': ['take exception to', 'enter a demurrer']}"],
#  ['25',
#   'derivative',
#   'https://www.youtube.com/watch?v=gnQ-QXeZa-0',
#   "{'Noun': ['the result of mathematical differentiation; the instantaneous change of one quantity relative to another; df(x', 'a compound obtained from, or regarded as derived from, another compound', 'a financial instrument whose value is based on another security', '(linguistics'], 'Adjective': ['resulting from or employing derivation']}"],
#  ['26',
#   'desiccate',
#   'https://www.youtube.com/watch?v=s35p88xMNDw',
#   "{'Verb': ['preserve by removing all water and liquids from', 'remove water from', 'lose water or moisture'], 'Adjective': ['lacking vitality or spirit; lifeless']}"],
#  ['27',
#   'diatribe',
#   'https://www.youtube.com/watch?v=akOBOdcCfBc',
#   "{'Noun': ['thunderous verbal attack']}"],
#  ['28',
#   'incredulous',
#   'https://www.youtube.com/watch?v=HbMnT_BtnBw',
#   "{'Adjective': ['not disposed or willing to believe; unbelieving']}"],
#  ['29',
#   'ingenuous',
#   'https://www.youtube.com/watch?v=obsc9MeunDc',
#   "{'Adjective': ['characterized by an inability to mask your feelings; not devious', 'lacking in sophistication or worldliness']}"],
#  ['', '', '', ''],
#  ['', 'Group 3', 'Links 3', 'Meaning 3'],
#  ['0',
#   'abate',
#   'https://www.youtube.com/watch?v=ePzRRIe0EEY',
#   "{'Verb': ['make less active or intense', 'become less in amount or intensity']}"],
#  ['1',
#   'abjure',
#   'https://www.youtube.com/watch?v=hhMbzGL2seY',
#   "{'Verb': ['formally reject or disavow a formerly held belief, usually under pressure']}"],
#  ['2',
#   'anomalous',
#   'https://www.youtube.com/watch?v=6yeAFTDfuKg',
#   "{'Adjective': ['deviating from the general or common order or type']}"],
#  ['3',
#   'antipathy',
#   'https://www.youtube.com/watch?v=z2ZAdkV7oCc',
#   "{'Noun': ['a feeling of intense dislike', 'the object of a feeling of intense aversion; something to be avoided']}"],
#  ['4',
#   'arcane',
#   'https://www.youtube.com/watch?v=0sZlddTCXxc',
#   "{'Adjective': ['requiring secret or mysterious knowledge']}"],
#  ['5',
#   'arduous',
#   'https://www.youtube.com/watch?v=e0AaiZzTB8M',
#   "{'Adjective': ['characterized by effort to the point of exhaustion; especially physical effort', 'taxing to the utmost; testing powers of endurance', 'difficult to accomplish; demanding considerable mental effort and skill']}"],
#  ['6',
#   'artless',
#   'https://www.youtube.com/watch?v=PDhyxWVd_jI',
#   "{'Adjective': ['characterized by an inability to mask your feelings; not devious', 'simple and natural; without cunning or deceit', 'showing lack of art', '(of persons']}"],
#  ['7',
#   'ascetic',
#   'https://www.youtube.com/watch?v=7exH0X48MD4',
#   "{'Noun': ['someone who practices self denial as a spiritual discipline'], 'Adjective': ['pertaining to or characteristic of an ascetic or the practice of rigorous self-discipline', 'practicing great self-denial']}"],
#  ['8',
#   'assuage',
#   'https://www.youtube.com/watch?v=EMLIhxo9ENs',
#   "{'Verb': ['cause to be more favorably inclined; gain the good will of', 'satisfy (thirst', 'provide physical relief, as from pain']}"],
#  ['9',
#   'betray',
#   'https://www.youtube.com/watch?v=ch4mQnnMVRI',
#   '{\'Verb\': [\'reveal unintentionally\', \'deliver to an enemy by treachery\', \'disappoint, prove undependable to; abandon, forsake\', "be sexually unfaithful to one\'s partner in marriage", \'give away information about somebody\', \'cause someone to believe an untruth\']}'],
#  ['10',
#   'bucolic',
#   'https://www.youtube.com/watch?v=Gs94rKKWFUQ',
#   "{'Noun': ['a country person', 'a short poem descriptive of rural or pastoral life'], 'Adjective': ['(used with regard to idealized country life', 'relating to shepherds or herdsmen or devoted to raising sheep or cattle']}"],
#  ['11',
#   'burgeon',
#   'https://www.youtube.com/watch?v=FdXoQGOMgNE',
#   "{'Verb': ['grow and flourish']}"],
#  ['12',
#   'cacophonous',
#   'https://www.youtube.com/watch?v=-qz4-CAVdf0',
#   "{'Adjective': ['having an unpleasant sound']}"],
#  ['13',
#   'canonize',
#   'https://www.youtube.com/watch?v=nJClNDsAiqY',
#   "{'Verb': ['declare (a dead person', 'treat as a sacred person']}"],
#  ['14',
#   'censure',
#   'https://www.youtube.com/watch?v=RLMjvhD_GZ8',
#   "{'Noun': ['harsh criticism or disapproval', 'the state of being excommunicated'], 'Verb': ['rebuke formally']}"],
#  ['15',
#   'chicanery',
#   'https://www.youtube.com/watch?v=FQx3D-9Wpuo',
#   "{'Noun': ['the use of tricks to deceive someone (usually to extract money from them']}"],
#  ['16',
#   'coalesce',
#   'https://www.youtube.com/watch?v=RIohpmrQA44',
#   "{'Verb': ['mix together different elements', 'fuse or cause to grow together']}"],
#  ['17',
#   'cogent',
#   'https://www.youtube.com/watch?v=BAXeJqENrdA',
#   "{'Adjective': ['powerfully persuasive']}"],
#  ['18',
#   'compelling',
#   'https://www.youtube.com/watch?v=7zTCu2NCPvc',
#   "{'Verb': ['force somebody to do something', 'necessitate or exact'], 'Adjective': ['driving or forcing', 'tending to persuade by forcefulness of argument']}"],
#  ['19',
#   'contend',
#   'https://www.youtube.com/watch?v=MU7xbHfuiHA',
#   "{'Verb': ['maintain or assert', 'have an argument about something', 'to make the subject of dispute, contention, or litigation', 'succeed in doing, achieving, or producing (something', 'compete for something; engage in a contest; measure oneself against others', 'be engaged in a fight; carry on a fight']}"],
#  ['20',
#   'copious',
#   'https://www.youtube.com/watch?v=N6qAC2mAOek',
#   "{'Adjective': ['large in number or quantity (especially of discourse', 'affording an abundant supply']}"],
#  ['21',
#   'cosmopolitan',
#   'https://www.youtube.com/watch?v=o6U7d-_2VdQ',
#   "{'Noun': ['a sophisticated person who has travelled in many countries'], 'Adjective': ['growing or occurring in many parts of the world', 'composed of people from or at home in many parts of the world; especially not provincial in attitudes or interests', 'of worldwide scope or applicability']}"],
#  ['22',
#   'deference',
#   'https://www.youtube.com/watch?v=BHvzf-FZIIw',
#   '{\'Noun\': [\'a courteous expression (by word or deed\', "courteous regard for people\'s feelings", \'a disposition or tendency to yield to the will of others\']}'],
#  ['23', 'desultory', 'https://www.youtube.com/watch?v=QVmxYz02DKA', ''],
#  ['24',
#   'diffident',
#   'https://www.youtube.com/watch?v=WtG8YUiPB5A',
#   "{'Adjective': ['showing modest reserve', 'lacking self-confidence']}"],
#  ['25',
#   'dilatory',
#   'https://www.youtube.com/watch?v=IdKaBsWPI_8',
#   "{'Adjective': ['wasting time']}"],
#  ['26',
#   'equivocate',
#   'https://www.youtube.com/watch?v=YXRyUjl7w_c',
#   "{'Verb': ['be deliberately ambiguous or unclear in order to mislead or withhold information']}"],
#  ['27',
#   'polarize',
#   'https://www.youtube.com/watch?v=c9ew1J0PY-M',
#   "{'Verb': ['cause to vibrate in a definite pattern', 'cause to concentrate about two conflicting or contrasting positions', 'become polarized in a conflict or contrasting situation']}"],
#  ['28',
#   'prodigal',
#   'https://www.youtube.com/watch?v=lT4u0Wu0p9U',
#   "{'Noun': ['a recklessly extravagant consumer'], 'Adjective': ['recklessly wasteful']}"],
#  ['29',
#   'verbose',
#   'https://www.youtube.com/watch?v=k0HfHhkt6EU',
#   "{'Adjective': ['using or containing too many words', 'or windy']}"],
#  ['', '', '', ''],
#  ['', 'Group 4', 'Links 4', 'Meaning 4'],
#  ['0',
#   'abstain',
#   'https://www.youtube.com/watch?v=-na9TNcSDBM',
#   "{'Verb': ['refrain from voting', 'choose not to consume']}"],
#  ['1',
#   'approbation',
#   'https://www.youtube.com/watch?v=gcty-qlM0ao',
#   "{'Noun': ['official approval', 'official recognition or approval']}"],
#  ['2',
#   'cherish',
#   'https://www.youtube.com/watch?v=6JNfffViWR4',
#   "{'Verb': ['be fond of; be attached to']}"],
#  ['3',
#   'corroborate',
#   'https://www.youtube.com/watch?v=wj3TtWLHdaA',
#   "{'Verb': ['establish or strengthen as with new evidence or facts', 'give evidence for', 'support with evidence or authority or make more certain or confirm']}"],
#  ['4',
#   'disparate',
#   'https://www.youtube.com/watch?v=WSvgS5fIXhA',
#   "{'Adjective': ['fundamentally different or distinct in quality or kind', 'including markedly dissimilar elements']}"],
#  ['5',
#   'emulate',
#   'https://www.youtube.com/watch?v=VEkWavG5rKc',
#   "{'Verb': ['strive to equal or match, especially by imitating', 'imitate the function of (another system', 'compete with successfully; approach or reach equality with']}"],
#  ['6',
#   'enervate',
#   'https://www.youtube.com/watch?v=tzffrtf7h6c',
#   "{'Verb': ['weaken mentally or morally', 'disturb the composure of']}"],
#  ['7',
#   'ephemeral',
#   'https://www.youtube.com/watch?v=uMSWmFYS76s',
#   "{'Noun': ['anything short-lived, as an insect that lives only for a day in its winged form'], 'Adjective': ['lasting a very short time']}"],
#  ['8',
#   'fervid',
#   'https://www.youtube.com/watch?v=TW5IhOWd_ps',
#   "{'Adjective': ['characterized by intense emotion', '(archaic']}"],
#  ['9',
#   'garrulous',
#   'https://www.youtube.com/watch?v=0d8kzlX7DCk',
#   "{'Adjective': ['full of trivial conversation']}"],
#  ['10',
#   'incendiary',
#   'https://www.youtube.com/watch?v=eJruwrV1_rg',
#   "{'Noun': ['a criminal who illegally sets fire to property', 'a bomb that is designed to start fires; is most effective against flammable targets (such as fuel'], 'Adjective': ['involving deliberate burning of property', 'arousing to action or rebellion', 'capable of catching fire spontaneously or causing fires or burning readily']}"],
#  ['11',
#   'inimical',
#   'https://www.youtube.com/watch?v=xtog-W28Tx0',
#   "{'Adjective': ['not friendly']}"],
#  ['12',
#   'intimate',
#   'https://www.youtube.com/watch?v=r9Z4YzqJABQ',
#   "{'Noun': ['someone to whom private matters are confided'], 'Verb': ['give to understand', 'imply as a possibility'], 'Adjective': ['marked by close acquaintance, association, or familiarity', 'concerning things deeply private and personal', 'having or fostering a warm or friendly and informal atmosphere', 'having mutual interests or affections; of established friendship', 'used euphemistically to refer to the genitals', 'involved in a sexual relationship', 'or sexual', 'innermost or essential', 'thoroughly acquainted through study or experience']}"],
#  ['13',
#   'invigorate',
#   'https://www.youtube.com/watch?v=VpQHUPNuUdY',
#   "{'Verb': ['heighten or intensify', 'give life or energy to', 'make lively', 'impart vigor, strength, or vitality to']}"],
#  ['14',
#   'mitigate',
#   'https://www.youtube.com/watch?v=TUjR6waP3qU',
#   "{'Verb': ['lessen or to try to lessen the seriousness or extent of', 'make less severe or harsh']}"],
#  ['15',
#   'obsolete',
#   'https://www.youtube.com/watch?v=Xnch-zEV-9s',
#   "{'Adjective': ['no longer in use']}"],
#  ['16',
#   'opaque',
#   'https://www.youtube.com/watch?v=9V0x8nL4bsc',
#   "{'Adjective': ['not transmitting or reflecting light or radiant energy; impenetrable to sight', 'hard or impossible to understand']}"],
#  ['17',
#   'paradigmatic',
#   'https://www.youtube.com/watch?v=zTJcXlNzH2U',
#   "{'Adjective': ['of or relating to a grammatical paradigm', 'of or relating to a typical example', 'related as members of a substitution class']}"],
#  ['18',
#   'pedantic',
#   'https://www.youtube.com/watch?v=dd3oLq3JUdg',
#   "{'Adjective': ['marked by a narrow focus on or display of learning especially its trivial aspects']}"],
#  ['19',
#   'placid',
#   'https://www.youtube.com/watch?v=tD-1LgK3Qao',
#   "{'Adjective': ['(of a body of water', 'not easily irritated']}"],
#  ['20',
#   'polemical',
#   'https://www.youtube.com/watch?v=tLTmJ2RgGow',
#   "{'Adjective': ['of or involving dispute or controversy']}"],
#  ['21',
#   'precipitate',
#   'https://www.youtube.com/watch?v=lJH0YCX8KEE',
#   "{'Noun': ['a precipitated solid substance in suspension or after settling or filtering'], 'Verb': ['bring about abruptly', 'separate as a fine suspension of solid particles', 'fall from clouds', 'fall vertically, sharply, or headlong', 'hurl or throw violently'], 'Adjective': ['done with very great haste and without due deliberation']}"],
#  ['22',
#   'profundity',
#   'https://www.youtube.com/watch?v=eTh2WyYYj0o',
#   "{'Noun': ['wisdom that is recondite and abstruse and profound', 'intellectual depth; penetrating knowledge; keen insight; etc', 'the intellectual ability to penetrate deeply into ideas', 'the quality of being physically deep']}"],
#  ['23',
#   'prophetic',
#   'https://www.youtube.com/watch?v=W6X4cjEPOKc',
#   "{'Adjective': ['foretelling events as if by supernatural intervention']}"],
#  ['24',
#   'prudent',
#   'https://www.youtube.com/watch?v=woCcwlP2R_Q',
#   "{'Adjective': ['careful and sensible; marked by sound judgment']}"],
#  ['25',
#   'punctilious',
#   'https://www.youtube.com/watch?v=lNHRxxx939U',
#   "{'Adjective': ['marked by precise accordance with details']}"],
#  ['26',
#   'recondite',
#   'https://www.youtube.com/watch?v=-eUS0g2gf9w',
#   "{'Adjective': ['difficult to penetrate; incomprehensible to one of ordinary understanding or knowledge']}"],
#  ['27',
#   'scrupulous',
#   'https://www.youtube.com/watch?v=DZ73s8BbEdc',
#   "{'Adjective': ['having scruples; arising from a sense of right and wrong; principled', 'characterized by extreme care and great effort']}"],
#  ['28',
#   'tranquil',
#   'https://www.youtube.com/watch?v=Sw7Wys5U3cY',
#   "{'Adjective': ['(of a body of water', 'not agitated; without losing self-possession']}"],
#  ['29',
#   'vacillate',
#   'https://www.youtube.com/watch?v=CsBaaq8-44Q',
#   "{'Verb': ['be undecided about something; waver between conflicting positions or courses of action', 'move or sway in a rising and falling or wavelike pattern']}"],
#  ['', '', '', ''],
#  ['', 'Group 5', 'Links 5', 'Meaning 5'],
#  ['0',
#   'aloof',
#   'https://www.youtube.com/watch?v=_1JCwdO1ulA',
#   "{'Adjective': ['remote in manner'], 'Adverb': ['in an aloof manner']}"],
#  ['1',
#   'clangor',
#   'https://www.youtube.com/watch?v=pId6jWScnMA',
#   "{'Noun': ['a loud resonant repeating noise'], 'Verb': ['make a loud resonant noise', 'make a loud noise']}"],
#  ['2',
#   'conventional',
#   'https://www.youtube.com/watch?v=P1eY7bf9AJE',
#   "{'Adjective': ['following accepted customs and proprieties', 'conforming with accepted standards', '(weapons', 'unimaginative and conformist', 'represented in simplified or symbolic form', 'in accord with or being a tradition or practice accepted from the past', 'rigidly formal or bound by convention']}"],
#  ['3',
#   'debunk',
#   'https://www.youtube.com/watch?v=TiOOARF_1f8',
#   "{'Verb': ['expose while ridiculing; especially of pretentious or false claims and ideas']}"],
#  ['4',
#   'diminutive',
#   'https://www.youtube.com/watch?v=QEEBlqcTJfU',
#   "{'Noun': ['a word that is formed with a suffix (such as -let or -kin'], 'Adjective': ['very small']}"],
#  ['5',
#   'discernible',
#   'https://www.youtube.com/watch?v=UXWHR4keXb4',
#   "{'Adjective': ['perceptible by the senses or intellect', 'capable of being perceived clearly', 'capable of being seen or noticed']}"],
#  ['6',
#   'enigmatic',
#   'https://www.youtube.com/watch?v=XuTeleLKlLc',
#   "{'Adjective': ['not clear to the understanding', 'resembling an oracle in obscurity of thought']}"],
#  ['7',
#   'estranged',
#   'https://www.youtube.com/watch?v=-8J1Ox1V_Us',
#   "{'Verb': ['remove from customary environment or associations', 'arouse hostility or indifference in where there had formerly been love, affection, or friendliness'], 'Adjective': ['caused to be unloved']}"],
#  ['8',
#   'extravagant',
#   'https://www.youtube.com/watch?v=NhngYYYOktI',
#   "{'Adjective': ['unrestrained, especially with regard to feelings', 'recklessly wasteful']}"],
#  ['9',
#   'fanciful',
#   'https://www.youtube.com/watch?v=88p-pOAfqEw',
#   "{'Adjective': ['indulging in or influenced by fancy', 'not based on fact; existing only in the imagination', 'having a curiously intricate quality']}"],
#  ['10',
#   'frivolous',
#   'https://www.youtube.com/watch?v=drajTKbJlco',
#   "{'Adjective': ['not serious in content or attitude or behavior']}"],
#  ['11',
#   'heterogeneous',
#   'https://www.youtube.com/watch?v=U3PXksMUJSw',
#   "{'Adjective': ['consisting of elements that are not of the same kind or nature', 'originating outside the body']}"],
#  ['12',
#   'imperious',
#   'https://www.youtube.com/watch?v=cd9ZfhVNvCQ',
#   "{'Adjective': ['having or showing arrogant superiority to and disdain of those one views as unworthy']}"],
#  ['13',
#   'impertinent',
#   'https://www.youtube.com/watch?v=w4qDJ3_Vn2M',
#   "{'Adjective': ['characterized by a lightly pert and exuberant quality', 'not pertinent to the matter under consideration', 'improperly forward or bold']}"],
#  ['14',
#   'invasive',
#   'https://www.youtube.com/watch?v=PjzI3f3SGXA',
#   "{'Adjective': ['relating to a technique in which the body is entered by puncture or incision', 'marked by a tendency to spread especially into healthy tissue', 'involving invasion or aggressive attack', 'gradually intrusive without right or permission']}"],
#  ['15',
#   'irresolute',
#   'https://www.youtube.com/watch?v=6iVYKaniYtg',
#   "{'Adjective': ['uncertain how to act or proceed']}"],
#  ['16',
#   'laudable',
#   'https://www.youtube.com/watch?v=1kJeZeSO7mE',
#   "{'Adjective': ['worthy of high praise']}"],
#  ['17',
#   'lax',
#   'https://www.youtube.com/watch?v=1yM2jtJmfV0',
#   '{\'Adjective\': [\'lacking in rigor or strictness\', "pronounced with muscles of the tongue and jaw relatively relaxed (e.g., the vowel sound in `bet\'", \'lacking in firmness or tension; not taut\', \'emptying easily or excessively\']}'],
#  ['18',
#   'marginalize',
#   'https://www.youtube.com/watch?v=e0gnolvkc5o',
#   "{'Verb': ['relegate to a lower or outer edge, as of specific groups of people']}"],
#  ['19',
#   'panache',
#   'https://www.youtube.com/watch?v=soRKc0SshBo',
#   "{'Noun': ['distinctive and stylish elegance', 'a feathered plume on a helmet']}"],
#  ['20',
#   'plodding',
#   'https://www.youtube.com/watch?v=bsiVsSfNoyU',
#   "{'Noun': ['hard monotonous routine work', 'the act of walking with a slow heavy gait'], 'Verb': ['walk heavily and firmly, as when weary, or through mud'], 'Adjective': ['(of movement']}"],
#  ['21',
#   'prosaic',
#   'https://www.youtube.com/watch?v=W8i8EPPZ7Ig',
#   "{'Adjective': ['not fanciful or imaginative', 'lacking wit or imagination', 'not challenging; dull and lacking excitement']}"],
#  ['22',
#   'remedial',
#   'https://www.youtube.com/watch?v=pqDinoYRJVo',
#   "{'Adjective': ['tending or intended to rectify or improve', 'tending to cure or restore to health']}"],
#  ['23',
#   'restive',
#   'https://www.youtube.com/watch?v=em9V5Di5qY8',
#   "{'Adjective': ['being in a tense state', 'impatient especially under restriction or delay']}"],
#  ['24',
#   'sporadic',
#   'https://www.youtube.com/watch?v=ukKBj0dJZYM',
#   "{'Adjective': ['recurring in scattered and irregular or unpredictable instances']}"],
#  ['25',
#   'stigmatize',
#   'https://www.youtube.com/watch?v=ncZzzNQ-X-g',
#   "{'Verb': ['to accuse or condemn or openly or formally or brand as disgraceful', 'mark with a stigma or stigmata']}"],
#  ['26',
#   'undermine',
#   'https://www.youtube.com/watch?v=Re3NZ4GksB8',
#   "{'Verb': ['destroy property or hinder normal operations', 'hollow out as if making a cave or opening']}"],
#  ['27',
#   'utterly',
#   'https://www.youtube.com/watch?v=3Fb807J7ACs',
#   "{'Adverb': ['completely and without qualification; used informally as intensifiers']}"],
#  ['28',
#   'weary',
#   'https://www.youtube.com/watch?v=arRvJ8dgnkY',
#   "{'Verb': ['exhaust or get tired through overuse or great strain or stress', 'lose interest or become bored with something or somebody'], 'Adjective': ['physically and mentally fatigued']}"],
#  ['29',
#   'zealous',
#   'https://www.youtube.com/watch?v=AwTS_IMpBLs',
#   "{'Adjective': ['marked by active interest and enthusiasm']}"],
#  ['', '', '', ''],
#  ['', 'Group 6', 'Links 6', 'Meaning 6'],
#  ['0',
#   'admonish',
#   'https://www.youtube.com/watch?v=xXcEjXKTei0',
#   '{\'Verb\': ["advise or counsel in terms of someone\'s behavior", \'warn strongly; put on guard\', \'take to task\']}'],
#  ['1',
#   'aesthetic',
#   'https://www.youtube.com/watch?v=2u3Mb7agrNE',
#   "{'Noun': ['(philosophy'], 'Adjective': ['relating to or dealing with the subject of aesthetics', 'concerning or characterized by an appreciation of beauty or good taste', 'aesthetically pleasing']}"],
#  ['2',
#   'affectation',
#   'https://www.youtube.com/watch?v=9-_mB3ZyzlI',
#   "{'Noun': ['a deliberate pretense or exaggerated display']}"],
#  ['3',
#   'alleviate',
#   'https://www.youtube.com/watch?v=3pAm6xxDEBI',
#   "{'Verb': ['provide physical relief, as from pain', 'make easier']}"],
#  ['4',
#   'analogous',
#   'https://www.youtube.com/watch?v=dtxY8kqtRCQ',
#   "{'Adjective': ['similar or equivalent in some respects though otherwise dissimilar', 'corresponding in function but not in evolutionary origin']}"],
#  ['5',
#   'bolster',
#   'https://www.youtube.com/watch?v=uyb50nAca5s',
#   "{'Noun': ['a pillow that is often put across a bed underneath the regular pillows'], 'Verb': ['support and strengthen', 'prop up with a pillow or bolster', 'add padding to']}"],
#  ['6',
#   'chauvinistic',
#   'https://www.youtube.com/watch?v=QDyexjEKVC8',
#   "{'Adjective': ['of or relating to persons convinced of the superiority of their own gender or kind', 'fanatically patriotic']}"],
#  ['7',
#   'connoisseur',
#   'https://www.youtube.com/watch?v=gL0xDd5AZeo',
#   "{'Noun': ['an expert able to appreciate a field; especially in the fine arts']}"],
#  ['8',
#   'dissemble',
#   'https://www.youtube.com/watch?v=Et91ZfecEeU',
#   "{'Verb': ['make believe with the intent to deceive', 'hide under a false appearance', 'behave unnaturally or affectedly']}"],
#  ['9',
#   'dogged',
#   'https://www.youtube.com/watch?v=dOwjYXgGNow',
#   "{'Verb': ['go after with the intent to catch'], 'Adjective': ['stubbornly unyielding']}"],
#  ['10',
#   'dupe',
#   'https://www.youtube.com/watch?v=q3Yt-IBO0-g',
#   "{'Noun': ['a person who is tricked or swindled'], 'Verb': ['fool or hoax']}"],
#  ['11',
#   'empirical',
#   'https://www.youtube.com/watch?v=7w510lmtpJE',
#   "{'Adjective': ['derived from experiment and observation rather than theory', 'relying on medical quackery']}"],
#  ['12',
#   'engender',
#   'https://www.youtube.com/watch?v=49nGn-nAOow',
#   "{'Verb': ['call forth', 'make (offspring']}"],
#  ['13',
#   'entitled',
#   'https://www.youtube.com/watch?v=Mg2RxBZyM5s',
#   "{'Verb': ['give the right to', 'give a title to', 'give a title to someone; make someone a member of the nobility'], 'Adjective': ['qualified for by right according to law']}"],
#  ['14',
#   'pertinacious',
#   'https://www.youtube.com/watch?v=Wbmiiwo8LkM',
#   "{'Adjective': ['stubbornly unyielding']}"],
#  ['15',
#   'presumptuous',
#   'https://www.youtube.com/watch?v=0uv0DJt8wlw',
#   "{'Adjective': ['excessively forward']}"],
#  ['16',
#   'probity',
#   'https://www.youtube.com/watch?v=ZqzRoZddqhs',
#   "{'Noun': ['complete and confirmed integrity; having strong moral principles']}"],
#  ['17',
#   'proliferate',
#   'https://www.youtube.com/watch?v=oEQnCQCXgzk',
#   "{'Verb': ['grow rapidly', 'cause to grow or increase rapidly']}"],
#  ['18',
#   'specious',
#   'https://www.youtube.com/watch?v=xwng6xMG4mA',
#   "{'Adjective': ['plausible but false', 'based on pretense; deceptively pleasing']}"],
#  ['19',
#   'spurious',
#   'https://www.youtube.com/watch?v=qzttl5RSOJQ',
#   "{'Adjective': ['ostensibly valid, but not actually valid', 'plausible but false', 'born out of wedlock', 'false or fake; not what it appears to be']}"],
#  ['20',
#   'subjective',
#   'https://www.youtube.com/watch?v=jlutlCrVQN4',
#   "{'Adjective': ['taking place within the mind and modified by individual bias', 'of a mental act performed entirely within the mind']}"],
#  ['21',
#   'subvert',
#   'https://www.youtube.com/watch?v=zhgtvmFnjwU',
#   "{'Verb': ['cause the downfall of; of rulers', 'corrupt morally or by intemperance or sensuality', 'destroy property or hinder normal operations', 'destroy completely']}"],
#  ['22',
#   'timorous',
#   'https://www.youtube.com/watch?v=AAvknjGzoEY',
#   "{'Adjective': ['timid by nature or revealing timidity']}"],
#  ['23',
#   'tortuous',
#   'https://www.youtube.com/watch?v=Ea-qxDIVzTY',
#   "{'Adjective': ['highly complex or intricate and occasionally devious', 'marked by repeated turns and bends', 'not straightforward']}"],
#  ['24',
#   'tractable',
#   'https://www.youtube.com/watch?v=TvRFND8pWpQ',
#   "{'Adjective': ['easily managed (controlled or taught or molded', 'responsive to suggestions and influences']}"],
#  ['25',
#   'transient',
#   'https://www.youtube.com/watch?v=2VBMgwwCj2M',
#   "{'Noun': ['one who stays for only a short time', '(physics'], 'Adjective': ['of a mental act; causing effects outside the mind', 'lasting a very short time']}"],
#  ['26',
#   'ubiquitous',
#   'https://www.youtube.com/watch?v=ORD54rKF_y0',
#   "{'Adjective': ['being present everywhere at once']}"],
#  ['27',
#   'underscore',
#   'https://www.youtube.com/watch?v=U_wlfkp9qPo',
#   "{'Noun': ['a line drawn underneath (especially under written matter'], 'Verb': ['give extra weight to (a communication', 'draw a line or lines underneath to call attention to']}"],
#  ['28',
#   'venal',
#   'https://www.youtube.com/watch?v=IrL6VK6gdvs',
#   "{'Adjective': ['capable of being corrupted']}"],
#  ['29',
#   'venerate',
#   'https://www.youtube.com/watch?v=pmfjQy0tg3k',
#   "{'Verb': ['regard with feelings of respect and reverence; consider hallowed or exalted or be in awe of']}"],
#  ['', '', '', ''],
#  ['', 'Group 7', 'Links 7', 'Meaning 7'],
#  ['0',
#   'appease',
#   'https://www.youtube.com/watch?v=qD3J-yjPYVQ',
#   "{'Verb': ['cause to be more favorably inclined; gain the good will of', 'overcome or allay', 'make peace with']}"],
#  ['1',
#   'arbitrary',
#   'https://www.youtube.com/watch?v=9yocU2t-avE',
#   "{'Adjective': ['based on or subject to individual discretion or preference or sometimes impulse or caprice']}"],
#  ['2',
#   'archaic',
#   'https://www.youtube.com/watch?v=h67KFLfdOo4',
#   "{'Adjective': ['so extremely old as seeming to belong to an earlier period', 'little evolved from or characteristic of an earlier ancestral type']}"],
#  ['3',
#   'clamorous',
#   'https://www.youtube.com/watch?v=BebQZxcuLXA',
#   "{'Adjective': ['conspicuously and offensively loud; given to vehement outcry']}"],
#  ['4',
#   'dearth',
#   'https://www.youtube.com/watch?v=7aECqtedSHg',
#   "{'Noun': ['an acute insufficiency', 'an insufficient quantity or number']}"],
#  ['5',
#   'explicable',
#   'https://www.youtube.com/watch?v=lm-t6qg-Isg',
#   "{'Adjective': ['capable of being explicated or accounted for']}"],
#  ['6',
#   'hyperbole',
#   'https://www.youtube.com/watch?v=lJulrou3V6M',
#   "{'Noun': ['extravagant exaggeration']}"],
#  ['7',
#   'immutable',
#   'https://www.youtube.com/watch?v=zR8bYVPd5vI',
#   "{'Adjective': ['not subject or susceptible to change or variation in form or quality or nature', 'constant and unchanging']}"],
#  ['8',
#   'indefatigable',
#   'https://www.youtube.com/watch?v=n1pGym29SC8',
#   "{'Adjective': ['showing sustained enthusiastic action with unflagging vitality']}"],
#  ['9',
#   'indolent',
#   'https://www.youtube.com/watch?v=P-XoEuaynus',
#   "{'Adjective': ['disinclined to work or exertion', '(of tumors, e.g.']}"],
#  ['10',
#   'insular',
#   'https://www.youtube.com/watch?v=cZipjwq72Yg',
#   "{'Adjective': ['relating to or characteristic of or situated on an island', 'suggestive of the isolated life of an island', 'narrowly restricted in outlook or scope']}"],
#  ['11',
#   'intransigent',
#   'https://www.youtube.com/watch?v=6u48wDxSoIY',
#   "{'Adjective': ['impervious to pleas, persuasion, requests, reason']}"],
#  ['12',
#   'intrepid',
#   'https://www.youtube.com/watch?v=G2igsSZXIm4',
#   "{'Adjective': ['invulnerable to fear or intimidation']}"],
#  ['13',
#   'irreverent',
#   'https://www.youtube.com/watch?v=FH4QgvfwdqM',
#   "{'Adjective': ['showing lack of due respect or veneration', 'characterized by a lightly pert and exuberant quality', 'not revering god']}"],
#  ['14',
#   'loathe',
#   'https://www.youtube.com/watch?v=AeHC9t7YyGs',
#   "{'Verb': ['find repugnant']}"],
#  ['15',
#   'malign',
#   'https://www.youtube.com/watch?v=0Sc6toB2QjU',
#   "{'Verb': ['speak unfavorably about'], 'Adjective': ['evil or harmful in nature or influence', 'having or exerting a malignant influence']}"],
#  ['16',
#   'malleable',
#   'https://www.youtube.com/watch?v=92Zm3lKju9o',
#   "{'Adjective': ['easily influenced', 'capable of being shaped or bent or drawn out']}"],
#  ['17',
#   'neophyte',
#   'https://www.youtube.com/watch?v=tWDTxb7fp88',
#   "{'Noun': ['a plant that is found in an area where it had not been recorded previously', 'any new participant in some activity', 'a new convert being taught the principles of Christianity by a catechist']}"],
#  ['18',
#   'plastic',
#   'https://www.youtube.com/watch?v=04HiKUN21LU',
#   "{'Noun': ['generic name for certain synthetic or semisynthetic materials that can be molded or extruded into objects or films or filaments or used for making e.g. coatings and adhesives', 'a card (usually plastic'], 'Adjective': ['capable of being molded or modeled (especially of earth or clay or other soft material', 'capable of being influenced or formed', 'forming or capable of forming or molding or fashioning']}"],
#  ['19',
#   'platitude',
#   'https://www.youtube.com/watch?v=m0ewlh4Aiuw',
#   "{'Noun': ['a trite or obvious remark']}"],
#  ['20',
#   'prescient',
#   'https://www.youtube.com/watch?v=ja8eb_Zx2Ig',
#   "{'Adjective': ['perceiving the significance of events before they occur']}"],
#  ['21',
#   'pristine',
#   'https://www.youtube.com/watch?v=sAtwvxfMbDE',
#   "{'Adjective': ['completely free from dirt or contamination', 'immaculately clean and unused']}"],
#  ['22',
#   'reproach',
#   'https://www.youtube.com/watch?v=kqW_ypKtFh4',
#   "{'Noun': ['a mild rebuke or criticism', 'disgrace or shame'], 'Verb': ['express criticism towards']}"],
#  ['23',
#   'robust',
#   'https://www.youtube.com/watch?v=KXZGkwcAB60',
#   "{'Adjective': ['sturdy and strong in form, constitution, or construction', 'marked by richness and fullness of flavor', 'strong enough to withstand or overcome intellectual challenges or adversity', 'rough and crude']}"],
#  ['24',
#   'salubrious',
#   'https://www.youtube.com/watch?v=kC5mJ_g6kuU',
#   "{'Adjective': ['promoting health; healthful', 'favorable to health of mind or body']}"],
#  ['25',
#   'sanction',
#   'https://www.youtube.com/watch?v=MWlnKlKwVrY',
#   '{\'Noun\': [\'formal and explicit approval\', "a mechanism of social control for enforcing a society\'s standards", \'official permission or approval\', \'the act of final authorization\'], \'Verb\': [\'give sanction to\', \'give authority or permission to\', \'give religious sanction to, such as through on oath\']}'],
#  ['26',
#   'sedulous',
#   'https://www.youtube.com/watch?v=8FRKK1IFmCU',
#   "{'Adjective': ['marked by care and persistent effort']}"],
#  ['27',
#   'soporific',
#   'https://www.youtube.com/watch?v=c0TFveK7ncE',
#   "{'Noun': ['a drug that induces sleep'], 'Adjective': ['sleep inducing', 'inducing mental lethargy']}"],
#  ['28',
#   'stern',
#   'https://www.youtube.com/watch?v=cRFfK3Jfg8Y',
#   "{'Noun': ['the rear part of a ship', 'United States concert violinist (born in Russia in 1920', 'the fleshy part of the human body that you sit on'], 'Adjective': ['of a stern or strict bearing or demeanor; forbidding in aspect', 'not to be placated or appeased or moved by entreaty', 'severe and unremitting in making demands', 'severely simple']}"],
#  ['29',
#   'tendentious',
#   'https://www.youtube.com/watch?v=GXS62_n-zK8',
#   "{'Adjective': ['having or marked by a strong tendency especially a controversial one']}"],
#  ['', '', '', ''],
#  ['', 'Group 8', 'Links 8', 'Meaning 8'],
#  ['0',
#   'accentuate',
#   'https://www.youtube.com/watch?v=MCR02v6cRB0',
#   "{'Verb': ['to stress, single out as important', 'put stress on; utter with an accent']}"],
#  ['1',
#   'conjectural',
#   'https://www.youtube.com/watch?v=H_5zMBy8enM',
#   "{'Adjective': ['based primarily on surmise rather than adequate evidence']}"],
#  ['2',
#   'convivial',
#   'https://www.youtube.com/watch?v=w_OAPIYYbiY',
#   "{'Adjective': ['occupied with or fond of the pleasures of good company']}"],
#  ['3',
#   'decadent',
#   'https://www.youtube.com/watch?v=G4AQv1vEwBM',
#   "{'Noun': ['a person who has fallen into a decadent state (morally or artistically'], 'Adjective': ['luxuriously self-indulgent', 'marked by excessive self-indulgence and moral decay']}"],
#  ['4',
#   'egregious',
#   'https://www.youtube.com/watch?v=sUnKjyhBs5g',
#   "{'Adjective': ['conspicuously and outrageously bad or reprehensible']}"],
#  ['5',
#   'evanescent',
#   'https://www.youtube.com/watch?v=zqQaZGxAcMM',
#   "{'Adjective': ['tending to vanish like vapor']}"],
#  ['6',
#   'flamboyant',
#   'https://www.youtube.com/watch?v=OFmtADphLCg',
#   "{'Noun': ['showy tropical tree or shrub native to Madagascar; widely planted in tropical regions for its immense racemes of scarlet and orange flowers; sometimes placed in genus Poinciana'], 'Adjective': ['marked by ostentation but often tasteless', 'elaborately or excessively ornamented']}"],
#  ['7',
#   'forestall',
#   'https://www.youtube.com/watch?v=nTzBXn6XZlw',
#   "{'Verb': ['keep from happening or arising; make impossible', 'act in advance of; deal with ahead of time']}"],
#  ['8',
#   'gainsay',
#   'https://www.youtube.com/watch?v=yLpVoWUs0go',
#   "{'Verb': ['take exception to']}"],
#  ['9',
#   'galvanize',
#   'https://www.youtube.com/watch?v=wmOgcqJuvtY',
#   "{'Verb': ['to stimulate to action', 'cover with zinc', 'stimulate (muscles']}"],
#  ['10',
#   'indiscriminate',
#   'https://www.youtube.com/watch?v=WP1_RsLao_E',
#   "{'Adjective': ['failing to make or recognize distinctions', 'not marked by fine distinctions']}"],
#  ['11',
#   'innocuous',
#   'https://www.youtube.com/watch?v=TD1gRDGWjEA',
#   "{'Adjective': ['not injurious to physical or mental health', 'not causing disapproval', 'lacking intent or capacity to injure']}"],
#  ['12',
#   'momentary',
#   'https://www.youtube.com/watch?v=5p2Pev_TJ_c',
#   "{'Adjective': ['lasting for a markedly brief time']}"],
#  ['13',
#   'mundane',
#   'https://www.youtube.com/watch?v=0yZ209qJx84',
#   "{'Adjective': ['found in the ordinary course of events', 'concerned with the world or worldly matters', 'belonging to this earth or world; not ideal or heavenly']}"],
#  ['14',
#   'nettlesome',
#   'https://www.youtube.com/watch?v=WfrK47w2xHs',
#   "{'Adjective': ['causing irritation or annoyance', 'easily irritated or annoyed']}"],
#  ['15',
#   'nullify',
#   'https://www.youtube.com/watch?v=4cqi_Br2_KY',
#   "{'Verb': ['declare invalid', 'show to be invalid', 'make ineffective by counterbalancing the effect of']}"],
#  ['16',
#   'obviate',
#   'https://www.youtube.com/watch?v=3LAGc9kBsAw',
#   "{'Verb': ['do away with', 'prevent the occurrence of; prevent from happening']}"],
#  ['17',
#   'omnipresent',
#   'https://www.youtube.com/watch?v=yBZxtdTF36M',
#   "{'Adjective': ['being present everywhere at once']}"],
#  ['18',
#   'oust',
#   'https://www.youtube.com/watch?v=m3DNiravQaQ',
#   "{'Verb': ['remove from a position or office', 'remove and replace']}"],
#  ['19',
#   'palpable',
#   'https://www.youtube.com/watch?v=akzi37FEfrY',
#   "{'Adjective': ['capable of being perceived; especially capable of being handled or touched or felt', '(medicine', 'clearly revealed to the mind or the senses or judgment', 'so intense as to be almost touched or felt']}"],
#  ['20',
#   'perfidy',
#   'https://www.youtube.com/watch?v=t_skH_RK1-8',
#   "{'Noun': ['betrayal of a trust', 'an act of deliberate betrayal']}"],
#  ['21',
#   'profuse',
#   'https://www.youtube.com/watch?v=LHJY80YZu8s',
#   "{'Adjective': ['produced or growing in extreme abundance']}"],
#  ['22',
#   'pugnacious',
#   'https://www.youtube.com/watch?v=7DbfUqpwpjA',
#   "{'Adjective': ['tough and callous by virtue of experience', 'ready and able to resort to force or violence']}"],
#  ['23',
#   'sagacious',
#   'https://www.youtube.com/watch?v=Di-JKoRk8ho',
#   "{'Adjective': ['acutely insightful and wise', 'skillful in statecraft or management']}"],
#  ['24',
#   'sanguine',
#   'https://www.youtube.com/watch?v=6yLpy4LqSuY',
#   "{'Noun': ['a blood-red color'], 'Adjective': ['confidently optimistic and cheerful', 'inclined to a healthy reddish color often associated with outdoor life']}"],
#  ['25',
#   'scant',
#   'https://www.youtube.com/watch?v=7ruQdKovwSY',
#   "{'Verb': ['work hastily or carelessly; deal with inadequately and superficially', 'limit in quality or quantity', 'supply sparingly and with restricted quantities'], 'Adjective': ['less than the correct or legal or full amount often deliberately so']}"],
#  ['26',
#   'skullduggery',
#   'https://www.youtube.com/watch?v=MbiZ4S58tW0',
#   "{'Noun': ['verbal misrepresentation intended to take advantage of you in some way']}"],
#  ['27',
#   'trivial',
#   'https://www.youtube.com/watch?v=3JWGbQj2yEI',
#   "{'Adjective': ['(informal', 'or small', 'of little substance or significance', 'concerned with trivialities']}"],
#  ['28',
#   'utilitarian',
#   'https://www.youtube.com/watch?v=cfT-ZMB8OFQ',
#   "{'Noun': ['someone who believes that the value of a thing depends on its utility'], 'Adjective': ['having a useful function', 'having utility often to the exclusion of values']}"],
#  ['29',
#   'vapid',
#   'https://www.youtube.com/watch?v=IJmpSfyEkIY',
#   "{'Adjective': ['lacking taste or flavor or tang', 'lacking significance or liveliness or spirit or zest']}"],
#  ['', '', '', ''],
#  ['', 'Group 9', 'Links 9', 'Meaning 9'],
#  ['0',
#   'boorish',
#   'https://www.youtube.com/watch?v=hnnckVaLg8c',
#   "{'Adjective': ['ill-mannered and coarse and contemptible in behavior or appearance']}"],
#  ['1',
#   'brook',
#   'https://www.youtube.com/watch?v=Eqs-siDKMbc',
#   "{'Noun': ['a natural stream of water smaller than a river (and often a tributary of a river'], 'Verb': ['put up with something or somebody unpleasant']}"],
#  ['2',
#   'circumspect',
#   'https://www.youtube.com/watch?v=lJYZcYT3ii4',
#   "{'Adjective': ['heedful of potential consequences']}"],
#  ['3',
#   'comity',
#   'https://www.youtube.com/watch?v=6XGx8ej03KA',
#   "{'Noun': ['a state or atmosphere of harmony or mutual civility and respect']}"],
#  ['4',
#   'commensurate',
#   'https://www.youtube.com/watch?v=YXKMDx-xDno',
#   "{'Adjective': ['corresponding in size or degree or extent']}"],
#  ['5',
#   'cordial',
#   'https://www.youtube.com/watch?v=4GQt7TN_dtg',
#   "{'Noun': ['strong highly flavored sweet liquor usually drunk after a meal'], 'Adjective': ['diffusing warmth and friendliness', 'politely warm and friendly', 'sincerely or intensely felt']}"],
#  ['6',
#   'deleterious',
#   'https://www.youtube.com/watch?v=Dpa6zr8NSWg',
#   "{'Adjective': ['harmful to living things']}"],
#  ['7',
# ...
#   "{'Adjective': ['marked by erratic changeableness in affections or attachments', 'liable to sudden unpredictable change']}"],
#  ['16',
#   'ramification',
#   'https://www.youtube.com/watch?v=9dVcM15k7BE',
#   "{'Noun': ['the act of branching out or dividing into branches', 'a part of a forked or branching shape', 'a development that complicates a situation', 'an arrangement of branching parts']}"],
#  ['17',
#   'eclectic',
#   'https://www.youtube.com/watch?v=t5TMxS5SrTo',
#   "{'Noun': ['someone who selects according to the eclectic method'], 'Adjective': ['selecting what seems best of various styles or ideas']}"],
#  ['18',
#   'apprehension',
#   'https://www.youtube.com/watch?v=PIJD6OIL_20',
#   "{'Noun': ['fearful expectation or anticipation', 'the cognitive condition of someone who understands', 'painful expectation', 'the act of apprehending (especially apprehending a criminal']}"],
#  ['19',
#   'idiosyncratic',
#   'https://www.youtube.com/watch?v=ndkDz3kG-kE',
#   "{'Adjective': ['peculiar to the individual']}"],
#  ['20',
#   'insolent',
#   'https://www.youtube.com/watch?v=Wlzg_xtjuzQ',
#   "{'Adjective': ['marked by casual disrespect', 'unrestrained by convention or propriety']}"],
#  ['21',
#   'ardent',
#   'https://www.youtube.com/watch?v=usZ0ZC8rHVE',
#   "{'Adjective': ['characterized by intense emotion', 'characterized by strong enthusiasm', 'glowing or shining like fire']}"],
#  ['22',
#   'doctrinaire',
#   'https://www.youtube.com/watch?v=yr3D7ZUHft4',
#   "{'Noun': ['a stubborn person of arbitrary or arrogant opinions'], 'Adjective': ['stubbornly insistent on theory without regard for practicality or suitability']}"],
#  ['23',
#   'officious',
#   'https://www.youtube.com/watch?v=PKjVBlYOzg8',
#   "{'Adjective': ['intrusive in a meddling or offensive manner']}"],
#  ['24',
#   'cease',
#   'https://www.youtube.com/watch?v=ptEjVgEOJnI',
#   '{\'Noun\': ["(`cease\' is a noun only in the phrase `without cease\'"], \'Verb\': [\'put an end to a state or an activity\', \'have an end, in a temporal, spatial, or quantitative sense; either spatial or metaphorical\']}'],
#  ['25',
#   'lavish',
#   'https://www.youtube.com/watch?v=2R5mXDB4H0Y',
#   "{'Verb': ['expend profusely; also used with abstract nouns'], 'Adjective': ['very generous', 'characterized by extravagance and profusion']}"],
#  ['26',
#   'conducive',
#   'https://www.youtube.com/watch?v=D-SzZRdQJdo',
#   "{'Adjective': ['tending to bring about; being partly responsible for']}"],
#  ['27',
#   'equanimity',
#   'https://www.youtube.com/watch?v=0ziLWLQz5Hg',
#   "{'Noun': ['steadiness of mind under stress']}"],
#  ['28',
#   'supplant',
#   'https://www.youtube.com/watch?v=j8ZoWh5R91Q',
#   "{'Verb': ['take the place or move into the position of']}"],
#  ['29',
#   'lampoon',
#   'https://www.youtube.com/watch?v=lNoccHoswxw',
#   '{\'Noun\': ["a composition that imitates or misrepresents somebody\'s style, usually in a humorous way"], \'Verb\': [\'ridicule with satire\']}'],
#  ['', '', '', ''],
#  ['', 'Group 27', 'Links 27', 'Meaning 27'],
#  ['0',
#   'bombastic',
#   'https://www.youtube.com/watch?v=F1vWkrkDn_M',
#   "{'Adjective': ['ostentatiously lofty in style']}"],
#  ['1',
#   'lambaste',
#   'https://www.youtube.com/watch?v=dj1h3hNlpP8',
#   "{'Verb': ['beat with a cane', 'censure severely or angrily']}"],
#  ['2',
#   'undercut',
#   'https://www.youtube.com/watch?v=5Vip8P1Ezb0',
#   '{\'Noun\': [\'the material removed by a cut made underneath\', \'the tender meat of the loin muscle on each side of the vertebral column\', \'a notch cut in the trunk of tree in order to determine the direction of its fall\', \'(sports\', \'a cut made underneath to remove material\'], \'Verb\': ["sell cheaper than one\'s competition", \'cut away material from the underside of (an object\', \'cut away the underpart of\', \'strike (the ball\', \'cut obliquely into (a tree\']}'],
#  ['3',
#   'euphemism',
#   'https://www.youtube.com/watch?v=ODt_debEZ9U',
#   "{'Noun': ['an inoffensive or indirect expression that is substituted for one that is considered offensive or too harsh']}"],
#  ['4',
#   'turpitude',
#   'https://www.youtube.com/watch?v=fs6-mb44Hj4',
#   "{'Noun': ['a corrupt or depraved or degenerate act or practice']}"],
#  ['5',
#   'peccadillo',
#   'https://www.youtube.com/watch?v=2be2XLBHA14',
#   "{'Noun': ['a petty misdeed']}"],
#  ['6',
#   'antagonize',
#   'https://www.youtube.com/watch?v=BqsS4aQiq30',
#   "{'Verb': ['provoke the hostility of', 'act in opposition to']}"],
#  ['7',
#   'barren',
#   'https://www.youtube.com/watch?v=KESYF47ahL0',
#   "{'Noun': ['an uninhabited wilderness that is worthless for cultivation'], 'Adjective': ['providing no shelter or sustenance', 'not bearing offspring', 'completely wanting or lacking']}"],
#  ['8',
#   'philistine',
#   'https://www.youtube.com/watch?v=Qx6RFKrRCj4',
#   "{'Noun': ['a person who is uninterested in intellectual pursuits', 'a member of an Aegean people who settled ancient Philistia around the 12th century BC'], 'Adjective': ['of or relating to ancient Philistia or its culture or its people', 'smug and ignorant and indifferent or hostile to artistic and cultural values']}"],
#  ['9',
#   'relegate',
#   'https://www.youtube.com/watch?v=O7J1DUc7NWA',
#   "{'Verb': ['refer to another person for decision or judgment', 'assign to a lower position; reduce in rank', 'expel, as if by official decree', 'assign to a class or kind']}"],
#  ['10',
#   'dirge',
#   'https://www.youtube.com/watch?v=AWjW02EzoIM',
#   "{'Noun': ['a song or hymn of mourning composed or performed as a memorial to a dead person']}"],
#  ['11',
#   'imperturbable',
#   'https://www.youtube.com/watch?v=c87HxQkQ1f0',
#   "{'Adjective': ['not easily perturbed or excited or upset; marked by extreme calm and composure']}"],
#  ['12',
#   'excoriate',
#   'https://www.youtube.com/watch?v=BmLM56nWHlM',
#   "{'Verb': ['express strong disapproval of', 'tear or wear off the skin or make sore by abrading']}"],
#  ['13',
#   'curmudgeon',
#   'https://www.youtube.com/watch?v=n_PjCpvqJgM',
#   "{'Noun': ['a crusty irascible cantankerous old person full of stubborn ideas']}"],
#  ['14',
#   'swindle',
#   'https://www.youtube.com/watch?v=ub7_sofGQJg',
#   "{'Noun': ['the act of swindling by some fraudulent scheme'], 'Verb': ['deprive of by deceit']}"],
#  ['15',
#   'wheedle',
#   'https://www.youtube.com/watch?v=AbgbD958s5o',
#   "{'Verb': ['influence or urge by gentle urging, caressing, or flattering']}"],
#  ['16',
#   'sentimental',
#   'https://www.youtube.com/watch?v=gimOMQ4onmI',
#   "{'Adjective': ['given to or marked by sentiment or sentimentality', 'effusively or insincerely emotional']}"],
#  ['17',
#   'miscreant',
#   'https://www.youtube.com/watch?v=ahiwBqmmd48',
#   "{'Noun': ['a person without moral scruples']}"],
#  ['18',
#   'implacable',
#   'https://www.youtube.com/watch?v=LBv_b_gS-XQ',
#   "{'Adjective': ['incapable of being placated']}"],
#  ['19',
#   'haughty',
#   'https://www.youtube.com/watch?v=4W9Xqv-dAsE',
#   "{'Adjective': ['having or showing arrogant superiority to and disdain of those one views as unworthy']}"],
#  ['20',
#   'estimable',
#   'https://www.youtube.com/watch?v=VPBKzPPypfI',
#   "{'Adjective': ['deserving of respect or high regard', 'deserving of esteem and respect', 'may be computed or estimated']}"],
#  ['21',
#   'tangible',
#   'https://www.youtube.com/watch?v=b7dUKwBESUk',
#   "{'Adjective': ['perceptible by the senses especially the sense of touch', 'capable of being treated as fact', '(of especially business assets', 'capable of being perceived; especially capable of being handled or touched or felt']}"],
#  ['22',
#   'chary',
#   'https://www.youtube.com/watch?v=CZrnMEedYi0',
#   "{'Adjective': ['characterized by great caution and wariness']}"],
#  ['23',
#   'repugnant',
#   'https://www.youtube.com/watch?v=KPyxnFEjhFI',
#   "{'Adjective': ['offensive to the mind']}"],
#  ['24',
#   'xenophobic',
#   'https://www.youtube.com/watch?v=b2G5-1msxhY',
#   "{'Adjective': ['suffering from xenophobia; having abnormal fear or hatred of the strange or foreign']}"],
#  ['25',
#   'squander',
#   'https://www.youtube.com/watch?v=ZIOqxdC5N-s',
#   "{'Verb': ['spend thoughtlessly; throw away', 'spend extravagantly']}"],
#  ['26',
#   'cajole',
#   'https://www.youtube.com/watch?v=rwI2zntsHvk',
#   "{'Verb': ['influence or urge by gentle urging, caressing, or flattering']}"],
#  ['27',
#   'unalloyed',
#   'https://www.youtube.com/watch?v=reVOMEXhurU',
#   "{'Adjective': ['free from admixture']}"],
#  ['28',
#   'heady',
#   'https://www.youtube.com/watch?v=69ljrv271V8',
#   "{'Adjective': ['marked by the exercise of good judgment or common sense in practical matters', 'extremely exciting as if by alcohol or a narcotic', 'marked by defiant disregard for danger or consequences']}"],
#  ['29',
#   'exigent',
#   'https://www.youtube.com/watch?v=84dh2xCydys',
#   "{'Adjective': ['demanding attention', 'requiring precise accuracy']}"],
#  ['', '', '', ''],
#  ['', 'Group 28', 'Links 28', 'Meaning 28'],
#  ['0',
#   'hysterical',
#   'https://www.youtube.com/watch?v=zBet4LjvBuU',
#   "{'Adjective': ['characterized by or arising from psychoneurotic hysteria', 'marked by excessive or uncontrollable emotion']}"],
#  ['1',
#   'endemic',
#   'https://www.youtube.com/watch?v=SgQkW_7oz8s',
#   "{'Noun': ['a disease that is constantly present to a greater or lesser degree in people of a certain class or in people living in a particular location', 'a plant that is native to a certain limited area'], 'Adjective': ['of or relating to a disease (or anything resembling a disease', 'native to or confined to a certain region', 'originating where it is found']}"],
#  ['2',
#   'disdain',
#   'https://www.youtube.com/watch?v=60yn9_r1s4g',
#   "{'Noun': ['lack of respect accompanied by a feeling of intense dislike', 'a communication that indicates lack of respect by patronizing the recipient'], 'Verb': ['look down on with disdain', 'reject with contempt']}"],
#  ['3',
#   'quash',
#   'https://www.youtube.com/watch?v=WbBdp60BNfs',
#   "{'Verb': ['put down by force or intimidation', 'declare invalid']}"],
#  ['4',
#   'august',
#   'https://www.youtube.com/watch?v=bGOzQ3m_tTo',
#   "{'Noun': ['the month following July and preceding September'], 'Adjective': ['of or befitting a lord', 'profoundly honored']}"],
#  ['5',
#   'quibble',
#   'https://www.youtube.com/watch?v=NwklsDclWfg',
#   "{'Noun': ['an evasion of the point of an argument by raising irrelevant distinctions or objections'], 'Verb': ['evade the truth of a point or question by raising irrelevant objections', 'argue over petty things']}"],
#  ['6',
#   'recant',
#   'https://www.youtube.com/watch?v=qKvzA0XSnEw',
#   "{'Verb': ['formally reject or disavow a formerly held belief, usually under pressure']}"],
#  ['7',
#   'inchoate',
#   'https://www.youtube.com/watch?v=gGuFXJI-dvs',
#   "{'Adjective': ['only partly in existence; imperfectly formed']}"],
#  ['8',
#   'abeyance',
#   'https://www.youtube.com/watch?v=JLJUV4bYTos',
#   "{'Noun': ['temporary cessation or suspension']}"],
#  ['9',
#   'redoubtable',
#   'https://www.youtube.com/watch?v=1TQs8ykJC-M',
#   "{'Adjective': ['inspiring fear', 'worthy of respect or honor']}"],
#  ['10',
#   'coy',
#   'https://www.youtube.com/watch?v=ff9PzFFAWzU',
#   "{'Adjective': ['affectedly modest or shy especially in a playful or provocative way', 'showing marked and often playful or irritating evasiveness or reluctance to make a definite or committing statement', 'modestly or warily rejecting approaches or overtures']}"],
#  ['11',
#   'disperse',
#   'https://www.youtube.com/watch?v=zqA8MxG3ISU',
#   "{'Verb': ['distribute loosely', 'to cause to separate and go in different directions', 'cause to separate', 'move away from each other', 'separate (light', 'cause to become widely known']}"],
#  ['12',
#   'shrill',
#   'https://www.youtube.com/watch?v=pbWn3W6TAME',
#   "{'Verb': ['utter a shrill cry'], 'Adjective': ['having or emitting a high-pitched and sharp tone or tones', 'being sharply insistent on being heard', 'of colors that are bright and gaudy']}"],
#  ['13',
#   'impudent',
#   'https://www.youtube.com/watch?v=5AHIoDKTqFg',
#   "{'Adjective': ['marked by casual disrespect', 'improperly forward or bold']}"],
#  ['14',
#   'burnish',
#   'https://www.youtube.com/watch?v=T39-uDw0QVk',
#   "{'Noun': ['the property of being smooth and shiny'], 'Verb': ['polish and make shiny']}"],
#  ['15',
#   'wily',
#   'https://www.youtube.com/watch?v=62urIPrERUs',
#   "{'Adjective': ['marked by skill in deception']}"],
#  ['16',
#   'quandary',
#   'https://www.youtube.com/watch?v=XjL3M6y6T0E',
#   "{'Noun': ['a situation from which extrication is difficult especially an unpleasant or trying one', 'state of uncertainty or perplexity especially as requiring a choice between equally unfavorable options']}"],
#  ['17',
#   'enmity',
#   'https://www.youtube.com/watch?v=iJjBbh1yV-M',
#   "{'Noun': ['a state of deep-seated ill-will', 'the feeling of a hostile person']}"],
#  ['18',
#   'substantiate',
#   'https://www.youtube.com/watch?v=HmmuTHkQ0iI',
#   "{'Verb': ['establish or strengthen as with new evidence or facts', 'represent in bodily form', 'make real or concrete; give reality or substance to', 'solidify, firm, or strengthen']}"],
#  ['19',
#   'agitate',
#   'https://www.youtube.com/watch?v=5X0b1a3awaI',
#   "{'Verb': ['try to stir up public opinion', 'cause to be agitated, excited, or roused', 'exert oneself continuously, vigorously, or obtrusively to gain an end or engage in a crusade for a certain cause or person; be an advocate for', 'move very slightly', 'move or cause to move back and forth', 'change the arrangement or position of']}"],
#  ['20',
#   'abstract',
#   'https://www.youtube.com/watch?v=EdLZiEtVrQk',
#   "{'Noun': ['a concept or idea not associated with any specific instance', 'a sketchy summary of the main points of an argument or theory'], 'Verb': ['consider a concept without thinking of a specific example; consider abstractly or theoretically', 'make off with belongings of others', 'consider apart from a particular case or instance', 'give an abstract (of'], 'Adjective': ['existing only in the mind; separated from embodiment', 'not representing or imitating external reality or the objects of nature', 'dealing with a subject in the abstract without practical purpose or intention']}"],
#  ['21',
#   'retiring',
#   'https://www.youtube.com/watch?v=bv22x0oI6gM',
#   '{\'Verb\': ["go into retirement; stop performing one\'s work or withdraw from one\'s position", \'withdraw from active participation\', \'pull back or move away or backward\', \'withdraw from circulation or from the market, as of bills, shares, and bonds\', \'break from a meeting or gathering\', \'make (someone\', \'dispose of (something no longer useful or needed\', \'lose interest\', \'cause to be out on a fielding play\', \'cause to get out\', \'prepare for sleep\'], \'Adjective\': [\'not arrogant or presuming\', \'of a person who has held and relinquished a position or office\', \'reluctant to draw attention to yourself\']}'],
#  ['22',
#   'quarantine',
#   'https://www.youtube.com/watch?v=bZf6YaJ4DHk',
#   "{'Noun': ['enforced isolation of patients suffering from a contagious disease in order to prevent the spread of disease', 'isolation to prevent the spread of infectious disease'], 'Verb': ['place into enforced isolation, as for medical reasons']}"],
#  ['23',
#   'distend',
#   'https://www.youtube.com/watch?v=i_CGIZoB_lQ',
#   "{'Verb': ['become wider', 'cause to expand as it by internal pressure', 'swell from or as if from internal pressure']}"],
#  ['24',
#   'ravage',
#   'https://www.youtube.com/watch?v=P4tKcrdDMnM',
#   "{'Noun': ['(usually plural'], 'Verb': ['make a pillaging or destructive raid on (a place', 'cause extensive destruction or ruin utterly']}"],
#  ['25',
#   'sophistry',
#   'https://www.youtube.com/watch?v=mAWfj4b3A48',
#   "{'Noun': ['a deliberately invalid argument displaying ingenuity in reasoning in the hope of deceiving someone']}"],
#  ['26',
#   'penchant',
#   'https://www.youtube.com/watch?v=SowOiz1IzTg',
#   "{'Noun': ['a strong liking']}"],
#  ['27',
#   'gauche',
#   'https://www.youtube.com/watch?v=vbeQFMmGkXU',
#   "{'Adjective': ['lacking social polish']}"],
#  ['28',
#   'deprecate',
#   'https://www.youtube.com/watch?v=Qtd6biGGx2g',
#   "{'Verb': ['express strong disapproval of; deplore', 'belittle']}"]]

# %%
values_list = worksheet.get_all_records() #dict

# %%
len(values_list)
# Out:
# 894

# %% [markdown]
# # search value

# %%
cell_list = worksheet.findall("3人")
cell_list
# Out:
# [<Cell R2C3 '3人'>, <Cell R13C3 '3人'>]

# %% [markdown]
# # 在最後一列插入值

# %%
values_list = worksheet.get_all_records()
last_row = 2+len(values_list)
worksheet.update('A'+str(last_row), 'values_list')
# Out:
# {'spreadsheetId': '1LMoh8cbY2-KdP40Z98DYGWs6r5Dd0aDJWSgxo2f6AII',
#  'updatedRange': 'Sheet1!A895',
#  'updatedRows': 1,
#  'updatedColumns': 1,
#  'updatedCells': 1}

# %%
import random

# %%
def get_question():
    i = random.randint(1,len(values_list))
    if values_list[i]['CLICK ME!'] == '':
        get_question()
    else:
        print(i)
        print(worksheet.acell('B'+str(i)).value)
        worksheet.update('A896', i)

# %%
get_question()
# Out:
# 881
# wily

# %%
def get_ans():
    i = worksheet.acell('A896').value
    meaning = worksheet.acell('D'+str(i)).value
    link = worksheet.acell('C'+str(i)).value
    print(meaning)
    print(link)
get_ans()
# Out:
# {'Adjective': ['marked by skill in deception']}
# https://www.youtube.com/watch?v=62urIPrERUs
